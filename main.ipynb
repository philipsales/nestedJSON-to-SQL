# %%
import numpy as np
import pandas as pd
import json
from pandas.io.json import json_normalize 
import logging

from functools import reduce


import itertools
import random
import psycopg2
from psycopg2.extras import Json
from sqlalchemy import create_engine, MetaData
import io
import pandas_profiling
# Out:
# /Users/ghost/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
#logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

#logging.basicConfig
fh = logging.FileHandler('logs/logs.txt')
fh.setLevel(logging.DEBUG)
fh.setFormatter(formatter)
logger.addHandler(fh)

#For streaming only
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)
ch.setFormatter(formatter)
logger.addHandler(ch)

# %%
#TODOS
#get input JSON schema --done
#get dataset -- done

#flatten object type --done
#flatten array type --done

#create function to get columns only in JSON schema --

#create postgress DDL table creator relative to columns

#create mapping
#create clean string manipulation function per column
#create clean match manipulation function per column

#create flow from input schema to postgresql

#create recursion to get properties
#create recursion to get array

# %% [markdown]
# ### Get input JSON Schema

# %%
input_schema = json_schema.schema
#input_schema['properties'].limit(2)

# %% [markdown]
# ### Get dataset

# %%
awh_json = pd.read_json("data/source.53-items.json")
awh_json.head(3)
# Out:
#                                              address child_healths  \
# 0  {'barangay': 'burgos gengos', 'country': 'Phil...           NaN
# 1  {'barangay': 'Rizal-Tuguisan', 'country': 'Phi...           NaN
# 2  {'barangay': 'Sta. Rosa - Laguna', 'country': ...           NaN
#
#                              date_visits email_address  \
# 0                                    NaN          None
# 1        [05/09/2018 at 10:08:20 PM EDT]          None
# 2  [04/13/2018 at 12:04:12 PM GMT+08:00]          None
#
#                                       family_members  \
# 0  [9c4de471-a33a-4bfa-899c-3fd63613042e, e8fc744...
# 1  [2cdd1eaf-48f6-4756-8450-e38de57e3f49, 28c1854...
# 2  [5b4a908f-eab4-4f4d-bf93-321840b85714, fd219c9...
#
#   family_planning_and_maternal_healths family_planning_male  \
# 0                                  NaN                  NaN
# 1                                  NaN                  NaN
# 2                                  NaN                  NaN
#
#                                  health_informations  \
# 0                                                 []
# 1  [{'allergies': '', 'blood_pressure': {'first_r...
# 2                                                 []
#
#                                           households  \
# 0                                                 []
# 1  [{'amenities_present_in_house': ['Electricity'...
# 2  [{'amenities_present_in_house': ['Electricity'...
#
#                                      id  \
# 0  0004d599-f8c8-46c4-9476-b51debae7271
# 1  00066299-81c1-4311-970b-8f82dca8640b
# 2  000799a5-7aeb-47d2-963c-30c566b3e0da
#
#                                       identification organization  \
# 0  {'id1': {'identifier': None, 'type': '4Ps'}, '...  Guimbal RHU
# 1  {'id1': {'identifier': None, 'type': '4Ps'}, '...  Guimbal RHU
# 2  {'id1': {'identifier': None, 'type': '4Ps'}, '...  Guimbal RHU
#
#                                      profile_picture profiles  \
# 0  {'name': '6e74d789-00f3-4800-8528-ab22cbea7ba4...       []
# 1  {'name': '7c472a01-fa08-4903-8d0d-d09a39ac7c69...       []
# 2  {'name': '2b8c8414-6103-431b-8c53-38b6b1c82aa3...       []
#
#         registered_at                                symptoms_collection  \
# 0 2018-05-17 17:23:07                                                NaN
# 1 2018-05-09 18:08:20  [{'abdomen': {'abdomen': []}, 'arms': {'elbow'...
# 2 2018-04-13 20:04:12                                                NaN
#
#             type                                           user_cam
# 0  user-resident  {'id': 'burgos-gengos@gmail.com', 'owner': 'bu...
# 1  user-resident  {'id': 'rizal-tuguisan@gmail.com', 'owner': 'r...
# 2  user-resident  {'id': 'starosalaguna@gmail.com', 'owner': 'st...

# %% [markdown]
# ### Flatten object type

# %%
with open("data/source.53-items.json") as f:
    d = json.load(f)

awhcuris = json_normalize(d)
awhcuris.head(2)
# Out:
#   address.barangay address.country address.email_address  \
# 0    burgos gengos     Philippines                   NaN
# 1   Rizal-Tuguisan     Philippines                   NaN
#
#   address.lot_or_house_number address.postal_code address.province  \
# 0                                            5022           iloilo
# 1                                            5022           Iloilo
#
#   child_healths                      date_visits email_address  \
# 0           NaN                              NaN          None
# 1           NaN  [05/09/2018 at 10:08:20 PM EDT]          None
#
#                                       family_members  \
# 0  [9c4de471-a33a-4bfa-899c-3fd63613042e, e8fc744...
# 1  [2cdd1eaf-48f6-4756-8450-e38de57e3f49, 28c1854...
#
#              ...            identification.id3.type organization  \
# 0            ...                                4Ps  Guimbal RHU
# 1            ...                                4Ps  Guimbal RHU
#
#                    profile_picture.name  \
# 0  6e74d789-00f3-4800-8528-ab22cbea7ba4
# 1  7c472a01-fa08-4903-8d0d-d09a39ac7c69
#
#                                 profile_picture.path profiles  \
# 0  /data/data/com.awh.health.curis/app_images/ima...       []
# 1  /data/data/com.awh.health.curis/app_images/ima...       []
#
#                          registered_at  \
# 0  05/17/2018 at 09:23:07 am GMT+08:00
# 1  05/09/2018 at 10:08:20 PM GMT-04:00
#
#                                  symptoms_collection           type  \
# 0                                                NaN  user-resident
# 1  [{'abdomen': {'abdomen': []}, 'arms': {'elbow'...  user-resident
#
#                 user_cam.id            user_cam.owner
# 0   burgos-gengos@gmail.com   burgos-gengos@gmail.com
# 1  rizal-tuguisan@gmail.com  rizal-tuguisan@gmail.com
#
# [2 rows x 30 columns]

# %% [markdown]
# ## Profiling

# %%
df_profile = awhcuris.fillna(0).replace('\n', '',regex=True)
profile = pandas_profiling.ProfileReport(df_profile)
profile
# Out:
# /Users/ghost/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/matplotlib/axes/_base.py:3152: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=-0.5, right=-0.5
#   'left=%s, right=%s') % (left, right))
# /Users/ghost/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/matplotlib/axes/_base.py:3471: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=-0.5, top=-0.5
#   'bottom=%s, top=%s') % (bottom, top))
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-21-fadd688e02c1> in <module>()
#       1 df_profile = awhcuris.fillna(0).replace('\n', '',regex=True)
# ----> 2 profile = pandas_profiling.ProfileReport(df_profile)
#       3 profile
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas_profiling/__init__.py in __init__(self, df, **kwargs)
#      67
#      68         self.html = to_html(sample,
# ---> 69                             description_set)
#      70
#      71         self.description_set = description_set
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas_profiling/report.py in to_html(sample, stats_object)
#     192
#     193     # Add plot of matrix correlation
# --> 194     pearson_matrix = plot.correlation_matrix(stats_object['correlations']['pearson'], 'Pearson')
#     195     spearman_matrix = plot.correlation_matrix(stats_object['correlations']['spearman'], 'Spearman')
#     196     correlations_html = templates.template('correlations').render(
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas_profiling/plot.py in correlation_matrix(corrdf, title, **kwargs)
#     134     plt.title(title, size=18)
#     135     plt.colorbar(matrix_image)
# --> 136     axes_cor.set_xticks(np.arange(0, corrdf.shape[0], corrdf.shape[0] * 1.0 / len(labels)))
#     137     axes_cor.set_yticks(np.arange(0, corrdf.shape[1], corrdf.shape[1] * 1.0 / len(labels)))
#     138     axes_cor.set_xticklabels(labels, rotation=90)
#
# ZeroDivisionError: float division by zero

# %%
#barbar = awhcuris.fillna(np.nan).replace('\n', '',regex=True)
#barbar.iloc[3493]

# %% [markdown]
# ### Columnar View for Flatten Address

# %%
awhcuris.T.head(6)
# Out:
#                                         0               1   \
# address.barangay             burgos gengos  Rizal-Tuguisan
# address.country                Philippines     Philippines
# address.email_address                  NaN             NaN
# address.lot_or_house_number
# address.postal_code                   5022            5022
# address.province                    iloilo          Iloilo
#
#                                              2            3            4   \
# address.barangay             Sta. Rosa - Laguna        Nanga       Putian
# address.country                     Philippines  Philippines  Philippines
# address.email_address                       NaN          NaN          NaN
# address.lot_or_house_number
# address.postal_code                        5022         5022         5811
# address.province                         Iloilo       Iloilo        Capiz
#
#                                           5            6            7   \
# address.barangay             Tuburan Pototan       Batuan       mainit
# address.country                  Philippines  Philippines  Philippines
# address.email_address                    NaN          NaN          NaN
# address.lot_or_house_number                          None
# address.postal_code                     5008         None         5811
# address.province                      Iloilo         None        capiz
#
#                                       8            9      ...       \
# address.barangay                  batuan      Anono-o     ...
# address.country              Philippines  Philippines     ...
# address.email_address                NaN          NaN     ...
# address.lot_or_house_number                               ...
# address.postal_code                              5022     ...
# address.province                               Iloilo     ...
#
#                                            43  \
# address.barangay             Dapitan, Pototan
# address.country                   Philippines
# address.email_address                     NaN
# address.lot_or_house_number
# address.postal_code                      5008
# address.province                       Iloilo
#
#                                                             44  \
# address.barangay             Mainit, Sitio Agsagoksok Cuartero
# address.country                                    Philippines
# address.email_address                                      NaN
# address.lot_or_house_number
# address.postal_code                                       5811
# address.province                                         Capiz
#
#                                            45           46               47  \
# address.barangay             Tuburan Pototan      Malusgod         Igcocolo
# address.country                   Philippines  Philippines      Philippines
# address.email_address                     NaN          NaN              NaN
# address.lot_or_house_number              None
# address.postal_code                      5008         5008             5022
# address.province                       Iloilo       Iloilo  Guimbal, Iloilo
#
#                                       48           49           50  \
# address.barangay                  Mainit   Bagumbayan   Camangahan
# address.country              Philippines  Philippines  Philippines
# address.email_address                NaN          NaN          NaN
# address.lot_or_house_number         0160
# address.postal_code                 5811         5022         5022
# address.province                   Capiz       Iloilo       Iloilo
#
#                                       51           52
# address.barangay                  Cabasi      Nito-an
# address.country              Philippines  Philippines
# address.email_address                NaN          NaN
# address.lot_or_house_number
# address.postal_code                 5022         5022
# address.province                  Iloilo       Iloilo
#
# [6 rows x 53 columns]

# %% [markdown]
# ### Iterate array type ['address']

# %%
test_data = awhcuris.loc[26]
test_data
# Out:
# address.barangay                                                                   Mainit
# address.country                                                               Philippines
# address.email_address
# address.lot_or_house_number
# address.postal_code                                                                  5811
# address.province                                                           Cuartero,Capiz
# child_healths                                                                         NaN
# date_visits                             [04/30/2018 at 04:34:51 PM GMT+08:00, 05/01/20...
# email_address                                                                        None
# family_members                          [0112c0ee-0cb6-4908-8fb0-a4a9bfbaee46, 006e7df...
# family_planning_and_maternal_healths    [{'are_you_pregnant': False, 'date_updated': '...
# family_planning_male                                                                  NaN
# health_informations                     [{'allergies': '', 'blood_pressure': {'first_r...
# households                              [{'amenities_present_in_house': ['Electricity'...
# id                                                   006e7df7-87b7-42ce-9dd9-cf29e58890ac
# identification.id1.identifier                                        061901014-6935-00005
# identification.id1.type                                                               4Ps
# identification.id2.identifier
# identification.id2.type                                                               4Ps
# identification.id3.identifier
# identification.id3.type                                                               4Ps
# organization                                                                 Cuartero RHU
# profile_picture.name                                 d4879499-31cf-4c23-8bb6-6129e414abea
# profile_picture.path                    /data/data/com.awh.health.curis/app_images/ima...
# profiles                                [{'civil_status': 'Married', 'date_updated': '...
# registered_at                                         04/30/2018 at 04:34:48 PM GMT+08:00
# symptoms_collection                                                                   NaN
# type                                                                        user-resident
# user_cam.id                                                             aniguel@gmail.com
# user_cam.owner                                                          aniguel@gmail.com
# Name: 26, dtype: object

# %% [markdown]
# ### Iterate array type ['family_planning_and_maternal_healths']

# %%
category = 'family_planning_and_maternal_healths'
test_data = awhcuris.loc[26][category]
test_data
# Out:
# [{'are_you_pregnant': False,
#   'date_updated': '05/01/2018 at 06:20:12 AM GMT+08:00',
#   'not_pregnant': {'are_you_both_using_any_family_method': False,
#    'are_you_willing_to_use_any_family_planning_method': False,
#    'did_you_experience_any_of_the_following_after_delivery': [],
#    'do_you_have_spouse_right_now': False,
#    'family_planning_methods_you_are_using': [],
#    'family_planning_you_are_willing_to_use': [],
#    'have_you_been_pregnant_ever_since': False,
#    'how_long_has_it_been_since_your_last_delivery': '',
#    'what_childbirth_support_did_you_received': 'empty',
#    'what_type_is_the_place_of_delivery': 'empty',
#    'when_was_your_last_delivery_date': ''}}]

# %% [markdown]
# ### Iterate array type ['profiles']

# %%
category = 'profiles'
test_data = awhcuris.loc[26][category]
test_data
# Out:
# [{'civil_status': 'Married',
#   'date_updated': '04/30/2018 at 04:34:51 PM GMT+08:00',
#   'education': 'College Level',
#   'employment': {'is_employed': False,
#    'monthly_income': '',
#    'nature': 'empty'},
#   'religion': 'Catholic'},
#  {'civil_status': 'Married',
#   'date_updated': '05/01/2018 at 06:31:25 AM GMT+08:00',
#   'education': 'College Level',
#   'employment': {'is_employed': False,
#    'monthly_income': '',
#    'nature': 'empty'},
#   'religion': 'Catholic'}]

# %% [markdown]
# ### Iterate array type ['health_information']

# %%
category = 'health_informations'
test_data = awhcuris.loc[26][category]
test_data
# Out:
# [{'allergies': '',
#   'blood_pressure': {'first_reading': {'diastole': '', 'systole': ''},
#    'second_reading': {'diastole': '', 'systole': ''},
#    'third_reading': {'diastole': '', 'systole': ''}},
#   'blood_sign': "I don't know",
#   'blood_sugar': 0,
#   'blood_type': 'O',
#   'date_updated': '04/30/2018 at 04:34:51 PM GMT+08:00',
#   'diagnosed': [],
#   'exercise_in_a_week': '0 to 1 hour',
#   'family_history': ['Hypertension'],
#   'fruits_in_a_week': '1',
#   'height': 52,
#   'high_cost_medicine': 'No',
#   'maintenance_drugs': 'No',
#   'smoking_habit': 'Never',
#   'vegetables_in_a_week': '2',
#   'waist_circumference': 29,
#   'weight': 45},
#  {'allergies': '',
#   'blood_pressure': {'first_reading': {'diastole': '', 'systole': ''},
#    'second_reading': {'diastole': '', 'systole': ''},
#    'third_reading': {'diastole': '', 'systole': ''}},
#   'blood_sign': "I don't know",
#   'blood_sugar': 0,
#   'blood_type': 'O',
#   'date_updated': '05/02/2018 at 07:55:21 PM GMT+08:00',
#   'diagnosed': [],
#   'exercise_in_a_week': '0 to 1 hour',
#   'family_history': ['Hypertension'],
#   'fruits_in_a_week': '1',
#   'height': 160.02,
#   'high_cost_medicine': 'No',
#   'maintenance_drugs': 'No',
#   'smoking_habit': 'Never',
#   'vegetables_in_a_week': '2',
#   'waist_circumference': 29,
#   'weight': 45},
#  {'allergies': '',
#   'blood_pressure': {'first_reading': {'diastole': '', 'systole': ''},
#    'second_reading': {'diastole': '', 'systole': ''},
#    'third_reading': {'diastole': '', 'systole': ''}},
#   'blood_sign': "I don't know",
#   'blood_sugar': 0,
#   'blood_type': 'O',
#   'date_updated': '05/03/2018 at 06:33:18 AM GMT+08:00',
#   'diagnosed': [],
#   'exercise_in_a_week': '0 to 1 hour',
#   'family_history': ['Hypertension', 'Tuberculosis'],
#   'fruits_in_a_week': '1',
#   'height': 160.02,
#   'high_cost_medicine': 'No',
#   'maintenance_drugs': 'No',
#   'smoking_habit': 'Never',
#   'vegetables_in_a_week': '2',
#   'waist_circumference': 29,
#   'weight': 45}]

# %% [markdown]
# ### Iterate array type ['child_health']

# %%
category = 'child_healths'
test_data = awhcuris.loc[30]['child_healths']
test_data
# Out:
# [{'child': {'eating_solid_food': True,
#    'exclusive_breast_feeding': False,
#    'following_experience': ['Cough', 'Diarrhea', 'Fever'],
#    'following_received': ['Vitamin A supplements', 'Deworming tablets'],
#    'mid_upper_arm_circumference': ''},
#   'date_updated': '03/26/2018 at 11:07:37 PM GMT+08:00',
#   'infant': {'eating_solid_food': False,
#    'exclusive_breast_feeding': False,
#    'following_experience': [],
#    'following_received': [],
#    'mid_upper_arm_circumference': ''},
#   'newborn': {'exclusive_breast_feeding': False,
#    'experience_any': [],
#    'provided_with_the_following': []}}]

# %% [markdown]
# ### Iterate array type ['household']

# %%
category = 'households'
test_data = awhcuris.loc[27][category]
test_data
# Out:
# [{'amenities_present_in_house': ['Electricity',
#    'Proper Ventilation',
#    'Water Supply'],
#   'date_updated': '04/26/2018 at 12:56:56 AM EDT',
#   'house_ownership': 'Owned',
#   'neighborhood_description': 'Rural',
#   'no_of_families_in_the_household': 3,
#   'no_of_people_in_the_household': 9,
#   'sanitary_ownership': 'Owned',
#   'sanitary_type': ['Pail'],
#   'type_of_house': 'Concrete-based'}]

# %% [markdown]
# ### Iterate array type ['symptoms_collection']

# %%
with open("data/source.53-items.json") as f:
    d = json.load(f)

awhcuris = json_normalize(d)
awhcuris.head(2)
testdata = []
category = 'symptoms_collection'
test_data = awhcuris.loc[1][category]
test_data
# Out:
# [{'abdomen': {'abdomen': []},
#   'arms': {'elbow': ['Weakness'],
#    'fingers': [],
#    'hand_and_palm': [],
#    'lower_arm': [],
#    'upper_arm': [],
#    'wrist': []},
#   'chest': {'chest': ['Chest pain', 'Muscle pain', 'Weakness'],
#    'lungs_and_breathing': ['Shortness of breath', 'Difficulty of breathing']},
#   'date_updated': '03/11/2018 at 09:43:48 AM GMT+08:00',
#   'head': {'chin_and_jaw': [],
#    'ears': [],
#    'eyes': [],
#    'head': [],
#    'mouth': [],
#    'nose': []},
#   'legs': {'foot': ['Foot pain'],
#    'knee': ['Knee pain', 'Knee weakness'],
#    'shin': [],
#    'thigh': [],
#    'toes': []},
#   'neck': {'lowerback': [],
#    'neck': [],
#    'shoulders': [],
#    'throat': [],
#    'upperback': []},
#   'pelvis': {'genitals': [], 'hip': [], 'pelvis': []},
#   'skin': {'skin': []}},
#  {'abdomen': {'abdomen': []},
#   'arms': {'elbow': ['Muscle pain', 'Weakness'],
#    'fingers': [],
#    'hand_and_palm': [],
#    'lower_arm': [],
#    'upper_arm': [],
#    'wrist': []},
#   'chest': {'chest': ['Chest pain', 'Muscle pain'],
#    'lungs_and_breathing': ['Shortness of breath']},
#   'date_updated': '03/11/2018 at 09:43:48 AM GMT+08:00',
#   'head': {'chin_and_jaw': [],
#    'ears': [],
#    'eyes': [],
#    'head': [],
#    'mouth': [],
#    'nose': []},
#   'legs': {'foot': ['Joint pain'],
#    'knee': ['Joint pain'],
#    'shin': [],
#    'thigh': [],
#    'toes': []},
#   'neck': {'lowerback': [],
#    'neck': [],
#    'shoulders': [],
#    'throat': [],
#    'upperback': []},
#   'pelvis': {'genitals': [], 'hip': [], 'pelvis': []},
#   'skin': {'skin': []}}]

# %% [markdown]
# ### Flatten array type

# %%
#json_normalize(test_data).T
data = json_normalize(test_data)
data_list = list(data)
data.T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-765cde854427> in <module>()
#       1 #json_normalize(test_data).T
# ----> 2 data = json_normalize(test_data)
#       3 data_list = list(data)
#       4 data.T
#
# NameError: name 'test_data' is not defined

# %%
### get columns in dataset
s = pd.Series(list(data))
bar = category + '.' + s
bar
bar.to_csv('postgres_columns.csv', mode='a', header=False)
#bar.to_csv( category+ '.csv', header=False, index=False)

# %% [markdown]
# ## Create dynamic mapping NoSQL to SQL

# %%
### get columns in input JSON schema
from input import json_schema 
json_schema = json_schema.schema
json_schema
# Out:
# {'definitions': {},
#  '$schema': 'http://json-schema.org/draft-07/schema#',
#  '$id': 'http://example.com/root.json',
#  'type': 'object',
#  'title': 'The Root Schema',
#  'required': ['cb_id',
#   'address',
#   'birthdate',
#   'contact_number',
#   'date_visits',
#   'email_address',
#   'family_members',
#   'first_name',
#   'gender',
#   'health_informations',
#   'households',
#   'identification',
#   'last_name',
#   'last_name_suffix',
#   'middle_name',
#   'nhid',
#   'organization',
#   'profile_picture',
#   'profiles',
#   'registered_at',
#   'symptoms_collection',
#   'child_healths',
#   'family_planning_and_maternal_healths',
#   'dental_health',
#   'disability',
#   'type',
#   'user-cam',
#   'date_completed'],
#  'properties': {'cb_id': {'$id': '#/properties/cb_id',
#    'type': 'string',
#    'title': 'The Cb_id Schema',
#    'default': '',
#    'examples': [''],
#    'pattern': '^(.*)$'},
#   'address': {'$id': '#/properties/address',
#    'type': 'object',
#    'title': 'The Address Schema',
#    'required': ['barangay',
#     'country',
#     'lot_or_house_number',
#     'postal_code',
#     'province'],
#    'properties': {'barangay': {'$id': '#/properties/address/properties/barangay',
#      'type': 'string',
#      'title': 'The Barangay Schema',
#      'default': '',
#      'examples': [''],
#      'pattern': '^(.*)$'},
#     'country': {'$id': '#/properties/address/properties/country',
#      'type': 'string',
#      'title': 'The Country Schema',
#      'default': '',
#      'examples': [''],
#      'pattern': '^(.*)$'},
#     'lot_or_house_number': {'$id': '#/properties/address/properties/lot_or_house_number',
#      'type': 'string',
#      'title': 'The Lot_or_house_number Schema',
#      'default': '',
#      'examples': [''],
#      'pattern': '^(.*)$'},
#     'postal_code': {'$id': '#/properties/address/properties/postal_code',
#      'type': 'string',
#      'title': 'The Postal_code Schema',
#      'default': '',
#      'examples': [''],
#      'pattern': '^(.*)$'},
#     'province': {'$id': '#/properties/address/properties/province',
#      'type': 'string',
#      'title': 'The Province Schema',
#      'default': '',
#      'examples': [''],
#      'pattern': '^(.*)$'}}},
#   'birthdate': {'$id': '#/properties/birthdate',
#    'type': 'string',
#    'title': 'The Birthdate Schema',
#    'default': '',
#    'examples': [''],
#    'pattern': '^(.*)$'},
#   'contact_number': {'$id': '#/properties/contact_number',
#    'type': 'object',
#    'title': 'The Contact_number Schema',
#    'required': ['country_code', 'number'],
#    'properties': {'country_code': {'$id': '#/properties/contact_number/properties/country_code',
#      'type': 'string',
#      'title': 'The Country_code Schema',
#      'default': '',
#      'examples': [''],
#      'pattern': '^(.*)$'},
#     'number': {'$id': '#/properties/contact_number/properties/number',
#      'type': 'string',
#      'title': 'The Number Schema',
#      'default': '',
#      'examples': ['']}}},
#   'date_visits': {'$id': '#/properties/date_visits',
#    'type': 'array',
#    'title': 'The Date_visits Schema'},
#   'email_address': {'$id': '#/properties/email_address',
#    'type': 'string',
#    'title': 'The Email_address Schema',
#    'default': '',
#    'examples': [''],
#    'pattern': '^(.*)$'},
#   'family_members': {'$id': '#/properties/family_members',
#    'type': 'array',
#    'title': 'The Family_members Schema'},
#   'first_name': {'$id': '#/properties/first_name',
#    'type': 'string',
#    'title': 'The First_name Schema',
#    'default': '',
#    'examples': [''],
#    'pattern': '^(.*)$'},
#   'gender': {'$id': '#/properties/gender',
#    'type': 'string',
#    'title': 'The Gender Schema',
#    'default': '',
#    'examples': [''],
#    'pattern': '^(.*)$'},
#   'health_informations': {'$id': '#/properties/health_informations',
#    'type': 'array',
#    'title': 'The Health_informations Schema',
#    'items': {'$id': '#/properties/health_informations/items',
#     'type': 'object',
#     'title': 'The Items Schema',
#     'required': ['allergies',
#      'blood_pressure',
#      'blood_sign',
#      'blood_sugar',
#      'blood_type',
#      'diagnosed',
#      'exercise_in_a_week',
#      'family_history',
#      'fruits_in_a_week',
#      'height',
#      'high_cost_medicine',
#      'maintenance_drugs',
#      'medical_equipments',
#      'smoking_habit',
#      'vegetables_in_a_week',
#      'waist_circumference',
#      'weight',
#      'date_updated',
#      'alcohol_in_a_week',
#      'taking_long_term_medication',
#      'why_take_or_not_prescribed_dose',
#      'how_travel_for_long_term_meds',
#      'times_exposed_to_smoke',
#      'do_u_have_disability',
#      'do_u_have_health_insurance_plan',
#      'traditional_medicine'],
#     'properties': {'allergies': {'$id': '#/properties/health_informations/items/properties/allergies',
#       'type': 'string',
#       'title': 'The Allergies Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'blood_pressure': {'$id': '#/properties/health_informations/items/properties/blood_pressure',
#       'type': 'object',
#       'title': 'The Blood_pressure Schema',
#       'required': ['first_reading', 'second_reading', 'third_reading'],
#       'properties': {'first_reading': {'$id': '#/properties/health_informations/items/properties/blood_pressure/properties/first_reading',
#         'type': 'object',
#         'title': 'The First_reading Schema',
#         'required': ['diastole', 'systole'],
#         'properties': {'diastole': {'$id': '#/properties/health_informations/items/properties/blood_pressure/properties/first_reading/properties/diastole',
#           'type': 'integer',
#           'title': 'The Diastole Schema',
#           'default': 0,
#           'examples': [0]},
#          'systole': {'$id': '#/properties/health_informations/items/properties/blood_pressure/properties/first_reading/properties/systole',
#           'type': 'integer',
#           'title': 'The Systole Schema',
#           'default': 0,
#           'examples': [0]}}},
#        'second_reading': {'$id': '#/properties/health_informations/items/properties/blood_pressure/properties/second_reading',
#         'type': 'object',
#         'title': 'The Second_reading Schema',
#         'required': ['diastole', 'systole'],
#         'properties': {'diastole': {'$id': '#/properties/health_informations/items/properties/blood_pressure/properties/second_reading/properties/diastole',
#           'type': 'integer',
#           'title': 'The Diastole Schema',
#           'default': 0,
#           'examples': [0]},
#          'systole': {'$id': '#/properties/health_informations/items/properties/blood_pressure/properties/second_reading/properties/systole',
#           'type': 'integer',
#           'title': 'The Systole Schema',
#           'default': 0,
#           'examples': [0]}}},
#        'third_reading': {'$id': '#/properties/health_informations/items/properties/blood_pressure/properties/third_reading',
#         'type': 'object',
#         'title': 'The Third_reading Schema',
#         'required': ['diastole', 'systole'],
#         'properties': {'diastole': {'$id': '#/properties/health_informations/items/properties/blood_pressure/properties/third_reading/properties/diastole',
#           'type': 'integer',
#           'title': 'The Diastole Schema',
#           'default': 0,
#           'examples': [0]},
#          'systole': {'$id': '#/properties/health_informations/items/properties/blood_pressure/properties/third_reading/properties/systole',
#           'type': 'integer',
#           'title': 'The Systole Schema',
#           'default': 0,
#           'examples': [0]}}}}},
#      'blood_sign': {'$id': '#/properties/health_informations/items/properties/blood_sign',
#       'type': 'string',
#       'title': 'The Blood_sign Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'blood_sugar': {'$id': '#/properties/health_informations/items/properties/blood_sugar',
#       'type': 'string',
#       'title': 'The Blood_sugar Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'blood_type': {'$id': '#/properties/health_informations/items/properties/blood_type',
#       'type': 'string',
#       'title': 'The Blood_type Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'diagnosed': {'$id': '#/properties/health_informations/items/properties/diagnosed',
#       'type': 'array',
#       'title': 'The Diagnosed Schema'},
#      'exercise_in_a_week': {'$id': '#/properties/health_informations/items/properties/exercise_in_a_week',
#       'type': 'string',
#       'title': 'The Exercise_in_a_week Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'family_history': {'$id': '#/properties/health_informations/items/properties/family_history',
#       'type': 'array',
#       'title': 'The Family_history Schema'},
#      'fruits_in_a_week': {'$id': '#/properties/health_informations/items/properties/fruits_in_a_week',
#       'type': 'string',
#       'title': 'The Fruits_in_a_week Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'height': {'$id': '#/properties/health_informations/items/properties/height',
#       'type': 'integer',
#       'title': 'The Height Schema',
#       'default': 0,
#       'examples': [0]},
#      'high_cost_medicine': {'$id': '#/properties/health_informations/items/properties/high_cost_medicine',
#       'type': 'string',
#       'title': 'The High_cost_medicine Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'maintenance_drugs': {'$id': '#/properties/health_informations/items/properties/maintenance_drugs',
#       'type': 'string',
#       'title': 'The Maintenance_drugs Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'medical_equipments': {'$id': '#/properties/health_informations/items/properties/medical_equipments',
#       'type': 'string',
#       'title': 'The Medical_equipments Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'smoking_habit': {'$id': '#/properties/health_informations/items/properties/smoking_habit',
#       'type': 'string',
#       'title': 'The Smoking_habit Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'vegetables_in_a_week': {'$id': '#/properties/health_informations/items/properties/vegetables_in_a_week',
#       'type': 'string',
#       'title': 'The Vegetables_in_a_week Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'waist_circumference': {'$id': '#/properties/health_informations/items/properties/waist_circumference',
#       'type': 'integer',
#       'title': 'The Waist_circumference Schema',
#       'default': 0,
#       'examples': [0]},
#      'weight': {'$id': '#/properties/health_informations/items/properties/weight',
#       'type': 'integer',
#       'title': 'The Weight Schema',
#       'default': 0,
#       'examples': [0]},
#      'date_updated': {'$id': '#/properties/health_informations/items/properties/date_updated',
#       'type': 'string',
#       'title': 'The Date_updated Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'alcohol_in_a_week': {'$id': '#/properties/health_informations/items/properties/alcohol_in_a_week',
#       'type': 'string',
#       'title': 'The Alcohol_in_a_week Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'taking_long_term_medication': {'$id': '#/properties/health_informations/items/properties/taking_long_term_medication',
#       'type': 'string',
#       'title': 'The Taking_long_term_medication Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'why_take_or_not_prescribed_dose': {'$id': '#/properties/health_informations/items/properties/why_take_or_not_prescribed_dose',
#       'type': 'string',
#       'title': 'The Why_take_or_not_prescribed_dose Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'how_travel_for_long_term_meds': {'$id': '#/properties/health_informations/items/properties/how_travel_for_long_term_meds',
#       'type': 'string',
#       'title': 'The How_travel_for_long_term_meds Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'times_exposed_to_smoke': {'$id': '#/properties/health_informations/items/properties/times_exposed_to_smoke',
#       'type': 'string',
#       'title': 'The Times_exposed_to_smoke Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'do_u_have_disability': {'$id': '#/properties/health_informations/items/properties/do_u_have_disability',
#       'type': 'string',
#       'title': 'The Do_u_have_disability Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'do_u_have_health_insurance_plan': {'$id': '#/properties/health_informations/items/properties/do_u_have_health_insurance_plan',
#       'type': 'string',
#       'title': 'The Do_u_have_health_insurance_plan Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'traditional_medicine': {'$id': '#/properties/health_informations/items/properties/traditional_medicine',
#       'type': 'string',
#       'title': 'The Traditional_medicine Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'}}}},
#   'households': {'$id': '#/properties/households',
#    'type': 'array',
#    'title': 'The Households Schema',
#    'items': {'$id': '#/properties/households/items',
#     'type': 'object',
#     'title': 'The Items Schema',
#     'required': ['amenities_present_in_house',
#      'date_updated',
#      'house_ownership',
#      'neighborhood_description',
#      'no_of_families_in_the_household',
#      'no_of_people_in_the_household',
#      'sanitary_ownership',
#      'sanitary_type',
#      'type_of_house',
#      'what_u_se_to_wash_hands',
#      'water_sources',
#      'how_ensure_water_safe'],
#     'properties': {'amenities_present_in_house': {'$id': '#/properties/households/items/properties/amenities_present_in_house',
#       'type': 'array',
#       'title': 'The Amenities_present_in_house Schema'},
#      'date_updated': {'$id': '#/properties/households/items/properties/date_updated',
#       'type': 'string',
#       'title': 'The Date_updated Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'house_ownership': {'$id': '#/properties/households/items/properties/house_ownership',
#       'type': 'string',
#       'title': 'The House_ownership Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'neighborhood_description': {'$id': '#/properties/households/items/properties/neighborhood_description',
#       'type': 'string',
#       'title': 'The Neighborhood_description Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'no_of_families_in_the_household': {'$id': '#/properties/households/items/properties/no_of_families_in_the_household',
#       'type': 'integer',
#       'title': 'The No_of_families_in_the_household Schema',
#       'default': 0,
#       'examples': [0]},
#      'no_of_people_in_the_household': {'$id': '#/properties/households/items/properties/no_of_people_in_the_household',
#       'type': 'integer',
#       'title': 'The No_of_people_in_the_household Schema',
#       'default': 0,
#       'examples': [0]},
#      'sanitary_ownership': {'$id': '#/properties/households/items/properties/sanitary_ownership',
#       'type': 'string',
#       'title': 'The Sanitary_ownership Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'sanitary_type': {'$id': '#/properties/households/items/properties/sanitary_type',
#       'type': 'array',
#       'title': 'The Sanitary_type Schema'},
#      'type_of_house': {'$id': '#/properties/households/items/properties/type_of_house',
#       'type': 'string',
#       'title': 'The Type_of_house Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'what_u_se_to_wash_hands': {'$id': '#/properties/households/items/properties/what_u_se_to_wash_hands',
#       'type': 'string',
#       'title': 'The What_u_se_to_wash_hands Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'water_sources': {'$id': '#/properties/households/items/properties/water_sources',
#       'type': 'array',
#       'title': 'The Water_sources Schema'},
#      'how_ensure_water_safe': {'$id': '#/properties/households/items/properties/how_ensure_water_safe',
#       'type': 'array',
#       'title': 'The How_ensure_water_safe Schema'}}}},
#   'identification': {'$id': '#/properties/identification',
#    'type': 'object',
#    'title': 'The Identification Schema',
#    'required': ['id1', 'id2', 'id3'],
#    'properties': {'id1': {'$id': '#/properties/identification/properties/id1',
#      'type': 'object',
#      'title': 'The Id1 Schema',
#      'required': ['identifier', 'type'],
#      'properties': {'identifier': {'$id': '#/properties/identification/properties/id1/properties/identifier',
#        'type': 'string',
#        'title': 'The Identifier Schema',
#        'default': '',
#        'examples': ['']},
#       'type': {'$id': '#/properties/identification/properties/id1/properties/type',
#        'type': 'string',
#        'title': 'The Type Schema',
#        'default': '',
#        'examples': [''],
#        'pattern': '^(.*)$'}}},
#     'id2': {'$id': '#/properties/identification/properties/id2',
#      'type': 'object',
#      'title': 'The Id2 Schema',
#      'required': ['identifier', 'type'],
#      'properties': {'identifier': {'$id': '#/properties/identification/properties/id2/properties/identifier',
#        'type': 'string',
#        'title': 'The Identifier Schema',
#        'default': '',
#        'examples': ['']},
#       'type': {'$id': '#/properties/identification/properties/id2/properties/type',
#        'type': 'string',
#        'title': 'The Type Schema',
#        'default': '',
#        'examples': [''],
#        'pattern': '^(.*)$'}}},
#     'id3': {'$id': '#/properties/identification/properties/id3',
#      'type': 'object',
#      'title': 'The Id3 Schema',
#      'required': ['identifier', 'type'],
#      'properties': {'identifier': {'$id': '#/properties/identification/properties/id3/properties/identifier',
#        'type': 'string',
#        'title': 'The Identifier Schema',
#        'default': '',
#        'examples': ['']},
#       'type': {'$id': '#/properties/identification/properties/id3/properties/type',
#        'type': 'string',
#        'title': 'The Type Schema',
#        'default': '',
#        'examples': [''],
#        'pattern': '^(.*)$'}}}}},
#   'last_name': {'$id': '#/properties/last_name',
#    'type': 'string',
#    'title': 'The Last_name Schema',
#    'default': '',
#    'examples': [''],
#    'pattern': '^(.*)$'},
#   'last_name_suffix': {'$id': '#/properties/last_name_suffix',
#    'type': 'string',
#    'title': 'The Last_name_suffix Schema',
#    'default': '',
#    'examples': [''],
#    'pattern': '^(.*)$'},
#   'middle_name': {'$id': '#/properties/middle_name',
#    'type': 'string',
#    'title': 'The Middle_name Schema',
#    'default': '',
#    'examples': [''],
#    'pattern': '^(.*)$'},
#   'nhid': {'$id': '#/properties/nhid',
#    'type': 'string',
#    'title': 'The Nhid Schema',
#    'default': '',
#    'examples': [''],
#    'pattern': '^(.*)$'},
#   'organization': {'$id': '#/properties/organization',
#    'type': 'string',
#    'title': 'The Organization Schema',
#    'default': '',
#    'examples': [''],
#    'pattern': '^(.*)$'},
#   'profile_picture': {'$id': '#/properties/profile_picture',
#    'type': 'object',
#    'title': 'The Profile_picture Schema',
#    'required': ['name', 'path'],
#    'properties': {'name': {'$id': '#/properties/profile_picture/properties/name',
#      'type': 'string',
#      'title': 'The Name Schema',
#      'default': '',
#      'examples': [''],
#      'pattern': '^(.*)$'},
#     'path': {'$id': '#/properties/profile_picture/properties/path',
#      'type': 'string',
#      'title': 'The Path Schema',
#      'default': '',
#      'examples': [''],
#      'pattern': '^(.*)$'}}},
#   'profiles': {'$id': '#/properties/profiles',
#    'type': 'array',
#    'title': 'The Profiles Schema',
#    'items': {'$id': '#/properties/profiles/items',
#     'type': 'object',
#     'title': 'The Items Schema',
#     'required': ['civil_status',
#      'date_updated',
#      'education',
#      'employment',
#      'are_you_currently_earning',
#      'where_income_from',
#      'religion'],
#     'properties': {'civil_status': {'$id': '#/properties/profiles/items/properties/civil_status',
#       'type': 'string',
#       'title': 'The Civil_status Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'date_updated': {'$id': '#/properties/profiles/items/properties/date_updated',
#       'type': 'string',
#       'title': 'The Date_updated Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'education': {'$id': '#/properties/profiles/items/properties/education',
#       'type': 'string',
#       'title': 'The Education Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'employment': {'$id': '#/properties/profiles/items/properties/employment',
#       'type': 'object',
#       'title': 'The Employment Schema',
#       'required': ['is_employed', 'monthly_income', 'nature', 'currency'],
#       'properties': {'is_employed': {'$id': '#/properties/profiles/items/properties/employment/properties/is_employed',
#         'type': 'boolean',
#         'title': 'The Is_employed Schema',
#         'default': False,
#         'examples': [False]},
#        'monthly_income': {'$id': '#/properties/profiles/items/properties/employment/properties/monthly_income',
#         'type': 'string',
#         'title': 'The Monthly_income Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'},
#        'nature': {'$id': '#/properties/profiles/items/properties/employment/properties/nature',
#         'type': 'string',
#         'title': 'The Nature Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'},
#        'currency': {'$id': '#/properties/profiles/items/properties/employment/properties/currency',
#         'type': 'string',
#         'title': 'The Currency Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'}}},
#      'are_you_currently_earning': {'$id': '#/properties/profiles/items/properties/are_you_currently_earning',
#       'type': 'string',
#       'title': 'The Are_you_currently_earning Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'where_income_from': {'$id': '#/properties/profiles/items/properties/where_income_from',
#       'type': 'string',
#       'title': 'The Where_income_from Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'religion': {'$id': '#/properties/profiles/items/properties/religion',
#       'type': 'string',
#       'title': 'The Religion Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'}}}},
#   'registered_at': {'$id': '#/properties/registered_at',
#    'type': 'string',
#    'title': 'The Registered_at Schema',
#    'default': '',
#    'examples': [''],
#    'pattern': '^(.*)$'},
#   'symptoms_collection': {'$id': '#/properties/symptoms_collection',
#    'type': 'array',
#    'title': 'The Symptoms_collection Schema',
#    'items': {'$id': '#/properties/symptoms_collection/items',
#     'type': 'object',
#     'title': 'The Items Schema',
#     'required': ['abdomen',
#      'arms',
#      'chest',
#      'date_updated',
#      'head',
#      'legs',
#      'neck',
#      'pelvis',
#      'skin'],
#     'properties': {'abdomen': {'$id': '#/properties/symptoms_collection/items/properties/abdomen',
#       'type': 'object',
#       'title': 'The Abdomen Schema',
#       'required': ['abdomen'],
#       'properties': {'abdomen': {'$id': '#/properties/symptoms_collection/items/properties/abdomen/properties/abdomen',
#         'type': 'array',
#         'title': 'The Abdomen Schema'}}},
#      'arms': {'$id': '#/properties/symptoms_collection/items/properties/arms',
#       'type': 'object',
#       'title': 'The Arms Schema',
#       'required': ['elbow',
#        'fingers',
#        'hand_and_palm',
#        'lower_arm',
#        'upper_arm',
#        'wrist'],
#       'properties': {'elbow': {'$id': '#/properties/symptoms_collection/items/properties/arms/properties/elbow',
#         'type': 'array',
#         'title': 'The Elbow Schema'},
#        'fingers': {'$id': '#/properties/symptoms_collection/items/properties/arms/properties/fingers',
#         'type': 'array',
#         'title': 'The Fingers Schema'},
#        'hand_and_palm': {'$id': '#/properties/symptoms_collection/items/properties/arms/properties/hand_and_palm',
#         'type': 'array',
#         'title': 'The Hand_and_palm Schema'},
#        'lower_arm': {'$id': '#/properties/symptoms_collection/items/properties/arms/properties/lower_arm',
#         'type': 'array',
#         'title': 'The Lower_arm Schema'},
#        'upper_arm': {'$id': '#/properties/symptoms_collection/items/properties/arms/properties/upper_arm',
#         'type': 'array',
#         'title': 'The Upper_arm Schema'},
#        'wrist': {'$id': '#/properties/symptoms_collection/items/properties/arms/properties/wrist',
#         'type': 'array',
#         'title': 'The Wrist Schema'}}},
#      'chest': {'$id': '#/properties/symptoms_collection/items/properties/chest',
#       'type': 'object',
#       'title': 'The Chest Schema',
#       'required': ['chest', 'lungs_and_breathing'],
#       'properties': {'chest': {'$id': '#/properties/symptoms_collection/items/properties/chest/properties/chest',
#         'type': 'array',
#         'title': 'The Chest Schema'},
#        'lungs_and_breathing': {'$id': '#/properties/symptoms_collection/items/properties/chest/properties/lungs_and_breathing',
#         'type': 'array',
#         'title': 'The Lungs_and_breathing Schema'}}},
#      'date_updated': {'$id': '#/properties/symptoms_collection/items/properties/date_updated',
#       'type': 'string',
#       'title': 'The Date_updated Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'head': {'$id': '#/properties/symptoms_collection/items/properties/head',
#       'type': 'object',
#       'title': 'The Head Schema',
#       'required': ['chin_and_jaw', 'ears', 'eyes', 'head', 'mouth', 'nose'],
#       'properties': {'chin_and_jaw': {'$id': '#/properties/symptoms_collection/items/properties/head/properties/chin_and_jaw',
#         'type': 'array',
#         'title': 'The Chin_and_jaw Schema'},
#        'ears': {'$id': '#/properties/symptoms_collection/items/properties/head/properties/ears',
#         'type': 'array',
#         'title': 'The Ears Schema'},
#        'eyes': {'$id': '#/properties/symptoms_collection/items/properties/head/properties/eyes',
#         'type': 'array',
#         'title': 'The Eyes Schema'},
#        'head': {'$id': '#/properties/symptoms_collection/items/properties/head/properties/head',
#         'type': 'array',
#         'title': 'The Head Schema'},
#        'mouth': {'$id': '#/properties/symptoms_collection/items/properties/head/properties/mouth',
#         'type': 'array',
#         'title': 'The Mouth Schema'},
#        'nose': {'$id': '#/properties/symptoms_collection/items/properties/head/properties/nose',
#         'type': 'array',
#         'title': 'The Nose Schema'}}},
#      'legs': {'$id': '#/properties/symptoms_collection/items/properties/legs',
#       'type': 'object',
#       'title': 'The Legs Schema',
#       'required': ['foot', 'knee', 'shin', 'thigh', 'toes'],
#       'properties': {'foot': {'$id': '#/properties/symptoms_collection/items/properties/legs/properties/foot',
#         'type': 'array',
#         'title': 'The Foot Schema'},
#        'knee': {'$id': '#/properties/symptoms_collection/items/properties/legs/properties/knee',
#         'type': 'array',
#         'title': 'The Knee Schema'},
#        'shin': {'$id': '#/properties/symptoms_collection/items/properties/legs/properties/shin',
#         'type': 'array',
#         'title': 'The Shin Schema'},
#        'thigh': {'$id': '#/properties/symptoms_collection/items/properties/legs/properties/thigh',
#         'type': 'array',
#         'title': 'The Thigh Schema'},
#        'toes': {'$id': '#/properties/symptoms_collection/items/properties/legs/properties/toes',
#         'type': 'array',
#         'title': 'The Toes Schema'}}},
#      'neck': {'$id': '#/properties/symptoms_collection/items/properties/neck',
#       'type': 'object',
#       'title': 'The Neck Schema',
#       'required': ['lowerback', 'neck', 'shoulders', 'throat', 'upperback'],
#       'properties': {'lowerback': {'$id': '#/properties/symptoms_collection/items/properties/neck/properties/lowerback',
#         'type': 'array',
#         'title': 'The Lowerback Schema'},
#        'neck': {'$id': '#/properties/symptoms_collection/items/properties/neck/properties/neck',
#         'type': 'array',
#         'title': 'The Neck Schema'},
#        'shoulders': {'$id': '#/properties/symptoms_collection/items/properties/neck/properties/shoulders',
#         'type': 'array',
#         'title': 'The Shoulders Schema'},
#        'throat': {'$id': '#/properties/symptoms_collection/items/properties/neck/properties/throat',
#         'type': 'array',
#         'title': 'The Throat Schema'},
#        'upperback': {'$id': '#/properties/symptoms_collection/items/properties/neck/properties/upperback',
#         'type': 'array',
#         'title': 'The Upperback Schema'}}},
#      'pelvis': {'$id': '#/properties/symptoms_collection/items/properties/pelvis',
#       'type': 'object',
#       'title': 'The Pelvis Schema',
#       'required': ['genitals', 'hip', 'pelvis'],
#       'properties': {'genitals': {'$id': '#/properties/symptoms_collection/items/properties/pelvis/properties/genitals',
#         'type': 'array',
#         'title': 'The Genitals Schema'},
#        'hip': {'$id': '#/properties/symptoms_collection/items/properties/pelvis/properties/hip',
#         'type': 'array',
#         'title': 'The Hip Schema'},
#        'pelvis': {'$id': '#/properties/symptoms_collection/items/properties/pelvis/properties/pelvis',
#         'type': 'array',
#         'title': 'The Pelvis Schema'}}},
#      'skin': {'$id': '#/properties/symptoms_collection/items/properties/skin',
#       'type': 'object',
#       'title': 'The Skin Schema',
#       'required': ['skin'],
#       'properties': {'skin': {'$id': '#/properties/symptoms_collection/items/properties/skin/properties/skin',
#         'type': 'array',
#         'title': 'The Skin Schema'}}}}}},
#   'child_healths': {'$id': '#/properties/child_healths',
#    'type': 'array',
#    'title': 'The Child_healths Schema',
#    'items': {'$id': '#/properties/child_healths/items',
#     'type': 'object',
#     'title': 'The Items Schema',
#     'required': ['newborn', 'infant', 'child', 'date_updated'],
#     'properties': {'newborn': {'$id': '#/properties/child_healths/items/properties/newborn',
#       'type': 'object',
#       'title': 'The Newborn Schema',
#       'required': ['provided_with_the_following',
#        'exclusive_breast_feeding',
#        'experience_any',
#        'provide_colostrum_or_breast_milk_after_delivery',
#        'how_soon_colostrum_br_milk_after_delivery',
#        'ANC_visits',
#        'place_receive_ANC',
#        'why_not_deliver_in_health_center',
#        'where_was_baby_delivered',
#        'provided_first_breast_milk'],
#       'properties': {'provided_with_the_following': {'$id': '#/properties/child_healths/items/properties/newborn/properties/provided_with_the_following',
#         'type': 'array',
#         'title': 'The Provided_with_the_following Schema'},
#        'exclusive_breast_feeding': {'$id': '#/properties/child_healths/items/properties/newborn/properties/exclusive_breast_feeding',
#         'type': 'boolean',
#         'title': 'The Exclusive_breast_feeding Schema',
#         'default': False,
#         'examples': [False]},
#        'experience_any': {'$id': '#/properties/child_healths/items/properties/newborn/properties/experience_any',
#         'type': 'array',
#         'title': 'The Experience_any Schema'},
#        'provide_colostrum_or_breast_milk_after_delivery': {'$id': '#/properties/child_healths/items/properties/newborn/properties/provide_colostrum_or_breast_milk_after_delivery',
#         'type': 'string',
#         'title': 'The Provide_colostrum_or_breast_milk_after_delivery Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'},
#        'how_soon_colostrum_br_milk_after_delivery': {'$id': '#/properties/child_healths/items/properties/newborn/properties/how_soon_colostrum_br_milk_after_delivery',
#         'type': 'string',
#         'title': 'The How_soon_colostrum_br_milk_after_delivery Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'},
#        'ANC_visits': {'$id': '#/properties/child_healths/items/properties/newborn/properties/ANC_visits',
#         'type': 'integer',
#         'title': 'The Anc_visits Schema',
#         'default': 0,
#         'examples': [1]},
#        'place_receive_ANC': {'$id': '#/properties/child_healths/items/properties/newborn/properties/place_receive_ANC',
#         'type': 'string',
#         'title': 'The Place_receive_anc Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'},
#        'why_not_deliver_in_health_center': {'$id': '#/properties/child_healths/items/properties/newborn/properties/why_not_deliver_in_health_center',
#         'type': 'string',
#         'title': 'The Why_not_deliver_in_health_center Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'},
#        'where_was_baby_delivered': {'$id': '#/properties/child_healths/items/properties/newborn/properties/where_was_baby_delivered',
#         'type': 'string',
#         'title': 'The Where_was_baby_delivered Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'},
#        'provided_first_breast_milk': {'$id': '#/properties/child_healths/items/properties/newborn/properties/provided_first_breast_milk',
#         'type': 'string',
#         'title': 'The Provided_first_breast_milk Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'}}},
#      'infant': {'$id': '#/properties/child_healths/items/properties/infant',
#       'type': 'object',
#       'title': 'The Infant Schema',
#       'required': ['mid_upper_arm_circumference',
#        'exclusive_breast_feeding',
#        'eating_solid_food',
#        'kind_of_solid_food',
#        'following_received',
#        'following_experience',
#        'provided_first_breast_milk',
#        'how_soon_colostrum_br_milk_after_delivery',
#        'months_of_exclusive_breast_feeding',
#        'ANC_visits',
#        'place_receive_ANC',
#        'why_not_deliver_in_health_center',
#        'where_was_baby_delivered'],
#       'properties': {'mid_upper_arm_circumference': {'$id': '#/properties/child_healths/items/properties/infant/properties/mid_upper_arm_circumference',
#         'type': 'array',
#         'title': 'The Mid_upper_arm_circumference Schema'},
#        'exclusive_breast_feeding': {'$id': '#/properties/child_healths/items/properties/infant/properties/exclusive_breast_feeding',
#         'type': 'boolean',
#         'title': 'The Exclusive_breast_feeding Schema',
#         'default': False,
#         'examples': [False]},
#        'eating_solid_food': {'$id': '#/properties/child_healths/items/properties/infant/properties/eating_solid_food',
#         'type': 'boolean',
#         'title': 'The Eating_solid_food Schema',
#         'default': False,
#         'examples': [False]},
#        'kind_of_solid_food': {'$id': '#/properties/child_healths/items/properties/infant/properties/kind_of_solid_food',
#         'type': 'string',
#         'title': 'The Kind_of_solid_food Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'},
#        'following_received': {'$id': '#/properties/child_healths/items/properties/infant/properties/following_received',
#         'type': 'array',
#         'title': 'The Following_received Schema'},
#        'following_experience': {'$id': '#/properties/child_healths/items/properties/infant/properties/following_experience',
#         'type': 'array',
#         'title': 'The Following_experience Schema'},
#        'provided_first_breast_milk': {'$id': '#/properties/child_healths/items/properties/infant/properties/provided_first_breast_milk',
#         'type': 'string',
#         'title': 'The Provided_first_breast_milk Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'},
#        'how_soon_colostrum_br_milk_after_delivery': {'$id': '#/properties/child_healths/items/properties/infant/properties/how_soon_colostrum_br_milk_after_delivery',
#         'type': 'string',
#         'title': 'The How_soon_colostrum_br_milk_after_delivery Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'},
#        'months_of_exclusive_breast_feeding': {'$id': '#/properties/child_healths/items/properties/infant/properties/months_of_exclusive_breast_feeding',
#         'type': 'string',
#         'title': 'The Months_of_exclusive_breast_feeding Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'},
#        'ANC_visits': {'$id': '#/properties/child_healths/items/properties/infant/properties/ANC_visits',
#         'type': 'integer',
#         'title': 'The Anc_visits Schema',
#         'default': 0,
#         'examples': [1]},
#        'place_receive_ANC': {'$id': '#/properties/child_healths/items/properties/infant/properties/place_receive_ANC',
#         'type': 'string',
#         'title': 'The Place_receive_anc Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'},
#        'why_not_deliver_in_health_center': {'$id': '#/properties/child_healths/items/properties/infant/properties/why_not_deliver_in_health_center',
#         'type': 'string',
#         'title': 'The Why_not_deliver_in_health_center Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'},
#        'where_was_baby_delivered': {'$id': '#/properties/child_healths/items/properties/infant/properties/where_was_baby_delivered',
#         'type': 'string',
#         'title': 'The Where_was_baby_delivered Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'}}},
#      'child': {'$id': '#/properties/child_healths/items/properties/child',
#       'type': 'object',
#       'title': 'The Child Schema',
#       'required': ['mid_upper_arm_circumference',
#        'exclusive_breast_feeding',
#        'eating_solid_food',
#        'following_received',
#        'following_experience',
#        'times_struggled_to_provide_food_for_child',
#        'treatment_for_malnutrition',
#        'if_yes_what_treatment'],
#       'properties': {'mid_upper_arm_circumference': {'$id': '#/properties/child_healths/items/properties/child/properties/mid_upper_arm_circumference',
#         'type': 'array',
#         'title': 'The Mid_upper_arm_circumference Schema'},
#        'exclusive_breast_feeding': {'$id': '#/properties/child_healths/items/properties/child/properties/exclusive_breast_feeding',
#         'type': 'boolean',
#         'title': 'The Exclusive_breast_feeding Schema',
#         'default': False,
#         'examples': [False]},
#        'eating_solid_food': {'$id': '#/properties/child_healths/items/properties/child/properties/eating_solid_food',
#         'type': 'boolean',
#         'title': 'The Eating_solid_food Schema',
#         'default': False,
#         'examples': [False]},
#        'following_received': {'$id': '#/properties/child_healths/items/properties/child/properties/following_received',
#         'type': 'array',
#         'title': 'The Following_received Schema'},
#        'following_experience': {'$id': '#/properties/child_healths/items/properties/child/properties/following_experience',
#         'type': 'array',
#         'title': 'The Following_experience Schema'},
#        'times_struggled_to_provide_food_for_child': {'$id': '#/properties/child_healths/items/properties/child/properties/times_struggled_to_provide_food_for_child',
#         'type': 'string',
#         'title': 'The Times_struggled_to_provide_food_for_child Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'},
#        'treatment_for_malnutrition': {'$id': '#/properties/child_healths/items/properties/child/properties/treatment_for_malnutrition',
#         'type': 'string',
#         'title': 'The Treatment_for_malnutrition Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'},
#        'if_yes_what_treatment': {'$id': '#/properties/child_healths/items/properties/child/properties/if_yes_what_treatment',
#         'type': 'string',
#         'title': 'The If_yes_what_treatment Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'}}},
#      'date_updated': {'$id': '#/properties/child_healths/items/properties/date_updated',
#       'type': 'string',
#       'title': 'The Date_updated Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'}}}},
#   'family_planning_and_maternal_healths': {'$id': '#/properties/family_planning_and_maternal_healths',
#    'type': 'array',
#    'title': 'The Family_planning_and_maternal_healths Schema',
#    'items': {'$id': '#/properties/family_planning_and_maternal_healths/items',
#     'type': 'object',
#     'title': 'The Items Schema',
#     'required': ['are_you_pregnant',
#      'is_pregnant_or_have_children',
#      'ANC_visits',
#      'place_receive_ANC',
#      'no_ANC_why_not',
#      'how_many_children_do_you_have',
#      'why_not_deliver_in_health_center',
#      'is_pregnant',
#      'not_pregnant',
#      'date_updated'],
#     'properties': {'are_you_pregnant': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/are_you_pregnant',
#       'type': 'boolean',
#       'title': 'The Are_you_pregnant Schema',
#       'default': False,
#       'examples': [False]},
#      'is_pregnant_or_have_children': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/is_pregnant_or_have_children',
#       'type': 'string',
#       'title': 'The Is_pregnant_or_have_children Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'ANC_visits': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/ANC_visits',
#       'type': 'integer',
#       'title': 'The Anc_visits Schema',
#       'default': 0,
#       'examples': [1]},
#      'place_receive_ANC': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/place_receive_ANC',
#       'type': 'string',
#       'title': 'The Place_receive_anc Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'no_ANC_why_not': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/no_ANC_why_not',
#       'type': 'string',
#       'title': 'The No_anc_why_not Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'how_many_children_do_you_have': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/how_many_children_do_you_have',
#       'type': 'integer',
#       'title': 'The How_many_children_do_you_have Schema',
#       'default': 0,
#       'examples': [1]},
#      'why_not_deliver_in_health_center': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/why_not_deliver_in_health_center',
#       'type': 'string',
#       'title': 'The Why_not_deliver_in_health_center Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'is_pregnant': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/is_pregnant',
#       'type': 'object',
#       'title': 'The Is_pregnant Schema',
#       'required': ['how_many_months_are_you_pregnant',
#        'how_many_parental_visit_did_you_have',
#        'where_do_you_plan_to_deliver_baby',
#        'are_you_taking_ferrous_sulfate_with_folic_acid',
#        'were_you_vaccinated_with_tetanus_toxoid',
#        'is_this_your_first_pregnancy',
#        'did_you_give_birth_less_than_6_weeks_ago',
#        'did_you_experience_the_following',
#        'do_you_intend_to_practice_family_planning'],
#       'properties': {'how_many_months_are_you_pregnant': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/is_pregnant/properties/how_many_months_are_you_pregnant',
#         'type': 'string',
#         'title': 'The How_many_months_are_you_pregnant Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'},
#        'how_many_parental_visit_did_you_have': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/is_pregnant/properties/how_many_parental_visit_did_you_have',
#         'type': 'string',
#         'title': 'The How_many_parental_visit_did_you_have Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'},
#        'where_do_you_plan_to_deliver_baby': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/is_pregnant/properties/where_do_you_plan_to_deliver_baby',
#         'type': 'string',
#         'title': 'The Where_do_you_plan_to_deliver_baby Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'},
#        'are_you_taking_ferrous_sulfate_with_folic_acid': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/is_pregnant/properties/are_you_taking_ferrous_sulfate_with_folic_acid',
#         'type': 'boolean',
#         'title': 'The Are_you_taking_ferrous_sulfate_with_folic_acid Schema',
#         'default': False,
#         'examples': [False]},
#        'were_you_vaccinated_with_tetanus_toxoid': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/is_pregnant/properties/were_you_vaccinated_with_tetanus_toxoid',
#         'type': 'array',
#         'title': 'The Were_you_vaccinated_with_tetanus_toxoid Schema'},
#        'is_this_your_first_pregnancy': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/is_pregnant/properties/is_this_your_first_pregnancy',
#         'type': 'boolean',
#         'title': 'The Is_this_your_first_pregnancy Schema',
#         'default': False,
#         'examples': [False]},
#        'did_you_give_birth_less_than_6_weeks_ago': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/is_pregnant/properties/did_you_give_birth_less_than_6_weeks_ago',
#         'type': 'boolean',
#         'title': 'The Did_you_give_birth_less_than_6_weeks_ago Schema',
#         'default': False,
#         'examples': [False]},
#        'did_you_experience_the_following': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/is_pregnant/properties/did_you_experience_the_following',
#         'type': 'array',
#         'title': 'The Did_you_experience_the_following Schema'},
#        'do_you_intend_to_practice_family_planning': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/is_pregnant/properties/do_you_intend_to_practice_family_planning',
#         'type': 'boolean',
#         'title': 'The Do_you_intend_to_practice_family_planning Schema',
#         'default': False,
#         'examples': [False]}}},
#      'not_pregnant': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/not_pregnant',
#       'type': 'object',
#       'title': 'The Not_pregnant Schema',
#       'required': ['have_you_been_pregnant_ever_since',
#        'how_long_has_it_been_since_your_last_delivery',
#        'when_was_your_last_delivery_date',
#        'what_type_is_the_place_of_delivery',
#        'what_childbirth_support_did_you_received',
#        'did_you_experience_any_of_the_following_after_delivery',
#        'do_you_have_spouse_right_now',
#        'are_you_both_using_any_family_method',
#        'family_planning_methods_you_are_using',
#        'are_you_willing_to_use_any_family_planning_method'],
#       'properties': {'have_you_been_pregnant_ever_since': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/not_pregnant/properties/have_you_been_pregnant_ever_since',
#         'type': 'boolean',
#         'title': 'The Have_you_been_pregnant_ever_since Schema',
#         'default': False,
#         'examples': [False]},
#        'how_long_has_it_been_since_your_last_delivery': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/not_pregnant/properties/how_long_has_it_been_since_your_last_delivery',
#         'type': 'string',
#         'title': 'The How_long_has_it_been_since_your_last_delivery Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'},
#        'when_was_your_last_delivery_date': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/not_pregnant/properties/when_was_your_last_delivery_date',
#         'type': 'string',
#         'title': 'The When_was_your_last_delivery_date Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'},
#        'what_type_is_the_place_of_delivery': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/not_pregnant/properties/what_type_is_the_place_of_delivery',
#         'type': 'string',
#         'title': 'The What_type_is_the_place_of_delivery Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'},
#        'what_childbirth_support_did_you_received': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/not_pregnant/properties/what_childbirth_support_did_you_received',
#         'type': 'string',
#         'title': 'The What_childbirth_support_did_you_received Schema',
#         'default': '',
#         'examples': [''],
#         'pattern': '^(.*)$'},
#        'did_you_experience_any_of_the_following_after_delivery': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/not_pregnant/properties/did_you_experience_any_of_the_following_after_delivery',
#         'type': 'array',
#         'title': 'The Did_you_experience_any_of_the_following_after_delivery Schema'},
#        'do_you_have_spouse_right_now': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/not_pregnant/properties/do_you_have_spouse_right_now',
#         'type': 'boolean',
#         'title': 'The Do_you_have_spouse_right_now Schema',
#         'default': False,
#         'examples': [False]},
#        'are_you_both_using_any_family_method': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/not_pregnant/properties/are_you_both_using_any_family_method',
#         'type': 'boolean',
#         'title': 'The Are_you_both_using_any_family_method Schema',
#         'default': False,
#         'examples': [False]},
#        'family_planning_methods_you_are_using': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/not_pregnant/properties/family_planning_methods_you_are_using',
#         'type': 'array',
#         'title': 'The Family_planning_methods_you_are_using Schema'},
#        'are_you_willing_to_use_any_family_planning_method': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/not_pregnant/properties/are_you_willing_to_use_any_family_planning_method',
#         'type': 'boolean',
#         'title': 'The Are_you_willing_to_use_any_family_planning_method Schema',
#         'default': False,
#         'examples': [False]}}},
#      'date_updated': {'$id': '#/properties/family_planning_and_maternal_healths/items/properties/date_updated',
#       'type': 'string',
#       'title': 'The Date_updated Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'}}}},
#   'dental_health': {'$id': '#/properties/dental_health',
#    'type': 'array',
#    'title': 'The Dental_health Schema',
#    'items': {'$id': '#/properties/dental_health/items',
#     'type': 'object',
#     'title': 'The Items Schema',
#     'required': ['do_you_own_toothbrush',
#      'times_clean_teeth_daily',
#      'what_problems',
#      'family_members_d_problems_last_6_months',
#      'what_do_u_use_to_clean_teeth',
#      'date_updated'],
#     'properties': {'do_you_own_toothbrush': {'$id': '#/properties/dental_health/items/properties/do_you_own_toothbrush',
#       'type': 'boolean',
#       'title': 'The Do_you_own_toothbrush Schema',
#       'default': False,
#       'examples': [True]},
#      'times_clean_teeth_daily': {'$id': '#/properties/dental_health/items/properties/times_clean_teeth_daily',
#       'type': 'string',
#       'title': 'The Times_clean_teeth_daily Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'what_problems': {'$id': '#/properties/dental_health/items/properties/what_problems',
#       'type': 'array',
#       'title': 'The What_problems Schema'},
#      'family_members_d_problems_last_6_months': {'$id': '#/properties/dental_health/items/properties/family_members_d_problems_last_6_months',
#       'type': 'string',
#       'title': 'The Family_members_d_problems_last_6_months Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'what_do_u_use_to_clean_teeth': {'$id': '#/properties/dental_health/items/properties/what_do_u_use_to_clean_teeth',
#       'type': 'string',
#       'title': 'The What_do_u_use_to_clean_teeth Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'date_updated': {'$id': '#/properties/dental_health/items/properties/date_updated',
#       'type': 'string',
#       'title': 'The Date_updated Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'}}}},
#   'disability': {'$id': '#/properties/disability',
#    'type': 'array',
#    'title': 'The Disability Schema',
#    'items': {'$id': '#/properties/disability/items',
#     'type': 'object',
#     'title': 'The Items Schema',
#     'required': ['do_you_have_types_disability', 'date_updated'],
#     'properties': {'do_you_have_types_disability': {'$id': '#/properties/disability/items/properties/do_you_have_types_disability',
#       'type': 'string',
#       'title': 'The Do_you_have_types_disability Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'},
#      'date_updated': {'$id': '#/properties/disability/items/properties/date_updated',
#       'type': 'string',
#       'title': 'The Date_updated Schema',
#       'default': '',
#       'examples': [''],
#       'pattern': '^(.*)$'}}}},
#   'type': {'$id': '#/properties/type',
#    'type': 'string',
#    'title': 'The Type Schema',
#    'default': '',
#    'examples': ['user-resident'],
#    'pattern': '^(.*)$'},
#   'user-cam': {'$id': '#/properties/user-cam',
#    'type': 'object',
#    'title': 'The User-cam Schema',
#    'required': ['id', 'owner'],
#    'properties': {'id': {'$id': '#/properties/user-cam/properties/id',
#      'type': 'string',
#      'title': 'The Id Schema',
#      'default': '',
#      'examples': [''],
#      'pattern': '^(.*)$'},
#     'owner': {'$id': '#/properties/user-cam/properties/owner',
#      'type': 'string',
#      'title': 'The Owner Schema',
#      'default': '',
#      'examples': [''],
#      'pattern': '^(.*)$'}}},
#   'date_completed': {'$id': '#/properties/date_completed',
#    'type': 'string',
#    'title': 'The Date_completed Schema',
#    'default': '',
#    'examples': [''],
#    'pattern': '^(.*)$'}}}

# %%
def id_generators(dict_var):
    print(dict_var)
    for k, v in dict_var.items():
        if k == "properties":
            print(v)
            yield v
            
        elif isinstance(v, dict):
            for id_val in id_generator(v):
                yield id_val

list(json_schema['properties'])
props = json_schema['properties']
#props.get('cb_id')


def flattenDict(d, result=None):
    if result is None:
        result = {}
    for key in d:
        value = d[key]
        if isinstance(value, dict):
        #if d['type'] =='object':
            value1 = {}
            for keyIn in value:
                value1[".".join([key,keyIn])]=value[keyIn]
            flattenDict(value1, result)
        elif isinstance(value, (list, tuple)):   
            for indexB, element in enumerate(value):
                if isinstance(element, dict):
                    value1 = {}
                    index = 0
                    for keyIn in element:
                        newkey = ".".join([key,keyIn])        
                        value1[".".join([key,keyIn])]=value[indexB][keyIn]
                        index += 1
                    for keyA in value1:
                        flattenDict(value1, result)   
        else:
            result[key]=value
    return result

type(props)
flattenDict(props)


#json2flat(props)
# Out:
# {'cb_id.$id': '#/properties/cb_id',
#  'cb_id.type': 'string',
#  'cb_id.title': 'The Cb_id Schema',
#  'cb_id.default': '',
#  'cb_id.pattern': '^(.*)$',
#  'address.$id': '#/properties/address',
#  'address.type': 'object',
#  'address.title': 'The Address Schema',
#  'address.properties.barangay.$id': '#/properties/address/properties/barangay',
#  'address.properties.barangay.type': 'string',
#  'address.properties.barangay.title': 'The Barangay Schema',
#  'address.properties.barangay.default': '',
#  'address.properties.barangay.pattern': '^(.*)$',
#  'address.properties.country.$id': '#/properties/address/properties/country',
#  'address.properties.country.type': 'string',
#  'address.properties.country.title': 'The Country Schema',
#  'address.properties.country.default': '',
#  'address.properties.country.pattern': '^(.*)$',
#  'address.properties.lot_or_house_number.$id': '#/properties/address/properties/lot_or_house_number',
#  'address.properties.lot_or_house_number.type': 'string',
#  'address.properties.lot_or_house_number.title': 'The Lot_or_house_number Schema',
#  'address.properties.lot_or_house_number.default': '',
#  'address.properties.lot_or_house_number.pattern': '^(.*)$',
#  'address.properties.postal_code.$id': '#/properties/address/properties/postal_code',
#  'address.properties.postal_code.type': 'string',
#  'address.properties.postal_code.title': 'The Postal_code Schema',
#  'address.properties.postal_code.default': '',
#  'address.properties.postal_code.pattern': '^(.*)$',
#  'address.properties.province.$id': '#/properties/address/properties/province',
#  'address.properties.province.type': 'string',
#  'address.properties.province.title': 'The Province Schema',
#  'address.properties.province.default': '',
#  'address.properties.province.pattern': '^(.*)$',
#  'birthdate.$id': '#/properties/birthdate',
#  'birthdate.type': 'string',
#  'birthdate.title': 'The Birthdate Schema',
#  'birthdate.default': '',
#  'birthdate.pattern': '^(.*)$',
#  'contact_number.$id': '#/properties/contact_number',
#  'contact_number.type': 'object',
#  'contact_number.title': 'The Contact_number Schema',
#  'contact_number.properties.country_code.$id': '#/properties/contact_number/properties/country_code',
#  'contact_number.properties.country_code.type': 'string',
#  'contact_number.properties.country_code.title': 'The Country_code Schema',
#  'contact_number.properties.country_code.default': '',
#  'contact_number.properties.country_code.pattern': '^(.*)$',
#  'contact_number.properties.number.$id': '#/properties/contact_number/properties/number',
#  'contact_number.properties.number.type': 'string',
#  'contact_number.properties.number.title': 'The Number Schema',
#  'contact_number.properties.number.default': '',
#  'date_visits.$id': '#/properties/date_visits',
#  'date_visits.type': 'array',
#  'date_visits.title': 'The Date_visits Schema',
#  'email_address.$id': '#/properties/email_address',
#  'email_address.type': 'string',
#  'email_address.title': 'The Email_address Schema',
#  'email_address.default': '',
#  'email_address.pattern': '^(.*)$',
#  'family_members.$id': '#/properties/family_members',
#  'family_members.type': 'array',
#  'family_members.title': 'The Family_members Schema',
#  'first_name.$id': '#/properties/first_name',
#  'first_name.type': 'string',
#  'first_name.title': 'The First_name Schema',
#  'first_name.default': '',
#  'first_name.pattern': '^(.*)$',
#  'gender.$id': '#/properties/gender',
#  'gender.type': 'string',
#  'gender.title': 'The Gender Schema',
#  'gender.default': '',
#  'gender.pattern': '^(.*)$',
#  'health_informations.$id': '#/properties/health_informations',
#  'health_informations.type': 'array',
#  'health_informations.title': 'The Health_informations Schema',
#  'health_informations.items.$id': '#/properties/health_informations/items',
#  'health_informations.items.type': 'object',
#  'health_informations.items.title': 'The Items Schema',
#  'health_informations.items.properties.allergies.$id': '#/properties/health_informations/items/properties/allergies',
#  'health_informations.items.properties.allergies.type': 'string',
#  'health_informations.items.properties.allergies.title': 'The Allergies Schema',
#  'health_informations.items.properties.allergies.default': '',
#  'health_informations.items.properties.allergies.pattern': '^(.*)$',
#  'health_informations.items.properties.blood_pressure.$id': '#/properties/health_informations/items/properties/blood_pressure',
#  'health_informations.items.properties.blood_pressure.type': 'object',
#  'health_informations.items.properties.blood_pressure.title': 'The Blood_pressure Schema',
#  'health_informations.items.properties.blood_pressure.properties.first_reading.$id': '#/properties/health_informations/items/properties/blood_pressure/properties/first_reading',
#  'health_informations.items.properties.blood_pressure.properties.first_reading.type': 'object',
#  'health_informations.items.properties.blood_pressure.properties.first_reading.title': 'The First_reading Schema',
#  'health_informations.items.properties.blood_pressure.properties.first_reading.properties.diastole.$id': '#/properties/health_informations/items/properties/blood_pressure/properties/first_reading/properties/diastole',
#  'health_informations.items.properties.blood_pressure.properties.first_reading.properties.diastole.type': 'integer',
#  'health_informations.items.properties.blood_pressure.properties.first_reading.properties.diastole.title': 'The Diastole Schema',
#  'health_informations.items.properties.blood_pressure.properties.first_reading.properties.diastole.default': 0,
#  'health_informations.items.properties.blood_pressure.properties.first_reading.properties.systole.$id': '#/properties/health_informations/items/properties/blood_pressure/properties/first_reading/properties/systole',
#  'health_informations.items.properties.blood_pressure.properties.first_reading.properties.systole.type': 'integer',
#  'health_informations.items.properties.blood_pressure.properties.first_reading.properties.systole.title': 'The Systole Schema',
#  'health_informations.items.properties.blood_pressure.properties.first_reading.properties.systole.default': 0,
#  'health_informations.items.properties.blood_pressure.properties.second_reading.$id': '#/properties/health_informations/items/properties/blood_pressure/properties/second_reading',
#  'health_informations.items.properties.blood_pressure.properties.second_reading.type': 'object',
#  'health_informations.items.properties.blood_pressure.properties.second_reading.title': 'The Second_reading Schema',
#  'health_informations.items.properties.blood_pressure.properties.second_reading.properties.diastole.$id': '#/properties/health_informations/items/properties/blood_pressure/properties/second_reading/properties/diastole',
#  'health_informations.items.properties.blood_pressure.properties.second_reading.properties.diastole.type': 'integer',
#  'health_informations.items.properties.blood_pressure.properties.second_reading.properties.diastole.title': 'The Diastole Schema',
#  'health_informations.items.properties.blood_pressure.properties.second_reading.properties.diastole.default': 0,
#  'health_informations.items.properties.blood_pressure.properties.second_reading.properties.systole.$id': '#/properties/health_informations/items/properties/blood_pressure/properties/second_reading/properties/systole',
#  'health_informations.items.properties.blood_pressure.properties.second_reading.properties.systole.type': 'integer',
#  'health_informations.items.properties.blood_pressure.properties.second_reading.properties.systole.title': 'The Systole Schema',
#  'health_informations.items.properties.blood_pressure.properties.second_reading.properties.systole.default': 0,
#  'health_informations.items.properties.blood_pressure.properties.third_reading.$id': '#/properties/health_informations/items/properties/blood_pressure/properties/third_reading',
#  'health_informations.items.properties.blood_pressure.properties.third_reading.type': 'object',
#  'health_informations.items.properties.blood_pressure.properties.third_reading.title': 'The Third_reading Schema',
#  'health_informations.items.properties.blood_pressure.properties.third_reading.properties.diastole.$id': '#/properties/health_informations/items/properties/blood_pressure/properties/third_reading/properties/diastole',
#  'health_informations.items.properties.blood_pressure.properties.third_reading.properties.diastole.type': 'integer',
#  'health_informations.items.properties.blood_pressure.properties.third_reading.properties.diastole.title': 'The Diastole Schema',
#  'health_informations.items.properties.blood_pressure.properties.third_reading.properties.diastole.default': 0,
#  'health_informations.items.properties.blood_pressure.properties.third_reading.properties.systole.$id': '#/properties/health_informations/items/properties/blood_pressure/properties/third_reading/properties/systole',
#  'health_informations.items.properties.blood_pressure.properties.third_reading.properties.systole.type': 'integer',
#  'health_informations.items.properties.blood_pressure.properties.third_reading.properties.systole.title': 'The Systole Schema',
#  'health_informations.items.properties.blood_pressure.properties.third_reading.properties.systole.default': 0,
#  'health_informations.items.properties.blood_sign.$id': '#/properties/health_informations/items/properties/blood_sign',
#  'health_informations.items.properties.blood_sign.type': 'string',
#  'health_informations.items.properties.blood_sign.title': 'The Blood_sign Schema',
#  'health_informations.items.properties.blood_sign.default': '',
#  'health_informations.items.properties.blood_sign.pattern': '^(.*)$',
#  'health_informations.items.properties.blood_sugar.$id': '#/properties/health_informations/items/properties/blood_sugar',
#  'health_informations.items.properties.blood_sugar.type': 'string',
#  'health_informations.items.properties.blood_sugar.title': 'The Blood_sugar Schema',
#  'health_informations.items.properties.blood_sugar.default': '',
#  'health_informations.items.properties.blood_sugar.pattern': '^(.*)$',
#  'health_informations.items.properties.blood_type.$id': '#/properties/health_informations/items/properties/blood_type',
#  'health_informations.items.properties.blood_type.type': 'string',
#  'health_informations.items.properties.blood_type.title': 'The Blood_type Schema',
#  'health_informations.items.properties.blood_type.default': '',
#  'health_informations.items.properties.blood_type.pattern': '^(.*)$',
#  'health_informations.items.properties.diagnosed.$id': '#/properties/health_informations/items/properties/diagnosed',
#  'health_informations.items.properties.diagnosed.type': 'array',
#  'health_informations.items.properties.diagnosed.title': 'The Diagnosed Schema',
#  'health_informations.items.properties.exercise_in_a_week.$id': '#/properties/health_informations/items/properties/exercise_in_a_week',
#  'health_informations.items.properties.exercise_in_a_week.type': 'string',
#  'health_informations.items.properties.exercise_in_a_week.title': 'The Exercise_in_a_week Schema',
#  'health_informations.items.properties.exercise_in_a_week.default': '',
#  'health_informations.items.properties.exercise_in_a_week.pattern': '^(.*)$',
#  'health_informations.items.properties.family_history.$id': '#/properties/health_informations/items/properties/family_history',
#  'health_informations.items.properties.family_history.type': 'array',
#  'health_informations.items.properties.family_history.title': 'The Family_history Schema',
#  'health_informations.items.properties.fruits_in_a_week.$id': '#/properties/health_informations/items/properties/fruits_in_a_week',
#  'health_informations.items.properties.fruits_in_a_week.type': 'string',
#  'health_informations.items.properties.fruits_in_a_week.title': 'The Fruits_in_a_week Schema',
#  'health_informations.items.properties.fruits_in_a_week.default': '',
#  'health_informations.items.properties.fruits_in_a_week.pattern': '^(.*)$',
#  'health_informations.items.properties.height.$id': '#/properties/health_informations/items/properties/height',
#  'health_informations.items.properties.height.type': 'integer',
#  'health_informations.items.properties.height.title': 'The Height Schema',
#  'health_informations.items.properties.height.default': 0,
#  'health_informations.items.properties.high_cost_medicine.$id': '#/properties/health_informations/items/properties/high_cost_medicine',
#  'health_informations.items.properties.high_cost_medicine.type': 'string',
#  'health_informations.items.properties.high_cost_medicine.title': 'The High_cost_medicine Schema',
#  'health_informations.items.properties.high_cost_medicine.default': '',
#  'health_informations.items.properties.high_cost_medicine.pattern': '^(.*)$',
#  'health_informations.items.properties.maintenance_drugs.$id': '#/properties/health_informations/items/properties/maintenance_drugs',
#  'health_informations.items.properties.maintenance_drugs.type': 'string',
#  'health_informations.items.properties.maintenance_drugs.title': 'The Maintenance_drugs Schema',
#  'health_informations.items.properties.maintenance_drugs.default': '',
#  'health_informations.items.properties.maintenance_drugs.pattern': '^(.*)$',
#  'health_informations.items.properties.medical_equipments.$id': '#/properties/health_informations/items/properties/medical_equipments',
#  'health_informations.items.properties.medical_equipments.type': 'string',
#  'health_informations.items.properties.medical_equipments.title': 'The Medical_equipments Schema',
#  'health_informations.items.properties.medical_equipments.default': '',
#  'health_informations.items.properties.medical_equipments.pattern': '^(.*)$',
#  'health_informations.items.properties.smoking_habit.$id': '#/properties/health_informations/items/properties/smoking_habit',
#  'health_informations.items.properties.smoking_habit.type': 'string',
#  'health_informations.items.properties.smoking_habit.title': 'The Smoking_habit Schema',
#  'health_informations.items.properties.smoking_habit.default': '',
#  'health_informations.items.properties.smoking_habit.pattern': '^(.*)$',
#  'health_informations.items.properties.vegetables_in_a_week.$id': '#/properties/health_informations/items/properties/vegetables_in_a_week',
#  'health_informations.items.properties.vegetables_in_a_week.type': 'string',
#  'health_informations.items.properties.vegetables_in_a_week.title': 'The Vegetables_in_a_week Schema',
#  'health_informations.items.properties.vegetables_in_a_week.default': '',
#  'health_informations.items.properties.vegetables_in_a_week.pattern': '^(.*)$',
#  'health_informations.items.properties.waist_circumference.$id': '#/properties/health_informations/items/properties/waist_circumference',
#  'health_informations.items.properties.waist_circumference.type': 'integer',
#  'health_informations.items.properties.waist_circumference.title': 'The Waist_circumference Schema',
#  'health_informations.items.properties.waist_circumference.default': 0,
#  'health_informations.items.properties.weight.$id': '#/properties/health_informations/items/properties/weight',
#  'health_informations.items.properties.weight.type': 'integer',
#  'health_informations.items.properties.weight.title': 'The Weight Schema',
#  'health_informations.items.properties.weight.default': 0,
#  'health_informations.items.properties.date_updated.$id': '#/properties/health_informations/items/properties/date_updated',
#  'health_informations.items.properties.date_updated.type': 'string',
#  'health_informations.items.properties.date_updated.title': 'The Date_updated Schema',
#  'health_informations.items.properties.date_updated.default': '',
#  'health_informations.items.properties.date_updated.pattern': '^(.*)$',
#  'health_informations.items.properties.alcohol_in_a_week.$id': '#/properties/health_informations/items/properties/alcohol_in_a_week',
#  'health_informations.items.properties.alcohol_in_a_week.type': 'string',
#  'health_informations.items.properties.alcohol_in_a_week.title': 'The Alcohol_in_a_week Schema',
#  'health_informations.items.properties.alcohol_in_a_week.default': '',
#  'health_informations.items.properties.alcohol_in_a_week.pattern': '^(.*)$',
#  'health_informations.items.properties.taking_long_term_medication.$id': '#/properties/health_informations/items/properties/taking_long_term_medication',
#  'health_informations.items.properties.taking_long_term_medication.type': 'string',
#  'health_informations.items.properties.taking_long_term_medication.title': 'The Taking_long_term_medication Schema',
#  'health_informations.items.properties.taking_long_term_medication.default': '',
#  'health_informations.items.properties.taking_long_term_medication.pattern': '^(.*)$',
#  'health_informations.items.properties.why_take_or_not_prescribed_dose.$id': '#/properties/health_informations/items/properties/why_take_or_not_prescribed_dose',
#  'health_informations.items.properties.why_take_or_not_prescribed_dose.type': 'string',
#  'health_informations.items.properties.why_take_or_not_prescribed_dose.title': 'The Why_take_or_not_prescribed_dose Schema',
#  'health_informations.items.properties.why_take_or_not_prescribed_dose.default': '',
#  'health_informations.items.properties.why_take_or_not_prescribed_dose.pattern': '^(.*)$',
#  'health_informations.items.properties.how_travel_for_long_term_meds.$id': '#/properties/health_informations/items/properties/how_travel_for_long_term_meds',
#  'health_informations.items.properties.how_travel_for_long_term_meds.type': 'string',
#  'health_informations.items.properties.how_travel_for_long_term_meds.title': 'The How_travel_for_long_term_meds Schema',
#  'health_informations.items.properties.how_travel_for_long_term_meds.default': '',
#  'health_informations.items.properties.how_travel_for_long_term_meds.pattern': '^(.*)$',
#  'health_informations.items.properties.times_exposed_to_smoke.$id': '#/properties/health_informations/items/properties/times_exposed_to_smoke',
#  'health_informations.items.properties.times_exposed_to_smoke.type': 'string',
#  'health_informations.items.properties.times_exposed_to_smoke.title': 'The Times_exposed_to_smoke Schema',
#  'health_informations.items.properties.times_exposed_to_smoke.default': '',
#  'health_informations.items.properties.times_exposed_to_smoke.pattern': '^(.*)$',
#  'health_informations.items.properties.do_u_have_disability.$id': '#/properties/health_informations/items/properties/do_u_have_disability',
#  'health_informations.items.properties.do_u_have_disability.type': 'string',
#  'health_informations.items.properties.do_u_have_disability.title': 'The Do_u_have_disability Schema',
#  'health_informations.items.properties.do_u_have_disability.default': '',
#  'health_informations.items.properties.do_u_have_disability.pattern': '^(.*)$',
#  'health_informations.items.properties.do_u_have_health_insurance_plan.$id': '#/properties/health_informations/items/properties/do_u_have_health_insurance_plan',
#  'health_informations.items.properties.do_u_have_health_insurance_plan.type': 'string',
#  'health_informations.items.properties.do_u_have_health_insurance_plan.title': 'The Do_u_have_health_insurance_plan Schema',
#  'health_informations.items.properties.do_u_have_health_insurance_plan.default': '',
#  'health_informations.items.properties.do_u_have_health_insurance_plan.pattern': '^(.*)$',
#  'health_informations.items.properties.traditional_medicine.$id': '#/properties/health_informations/items/properties/traditional_medicine',
#  'health_informations.items.properties.traditional_medicine.type': 'string',
#  'health_informations.items.properties.traditional_medicine.title': 'The Traditional_medicine Schema',
#  'health_informations.items.properties.traditional_medicine.default': '',
#  'health_informations.items.properties.traditional_medicine.pattern': '^(.*)$',
#  'households.$id': '#/properties/households',
#  'households.type': 'array',
#  'households.title': 'The Households Schema',
#  'households.items.$id': '#/properties/households/items',
#  'households.items.type': 'object',
#  'households.items.title': 'The Items Schema',
#  'households.items.properties.amenities_present_in_house.$id': '#/properties/households/items/properties/amenities_present_in_house',
#  'households.items.properties.amenities_present_in_house.type': 'array',
#  'households.items.properties.amenities_present_in_house.title': 'The Amenities_present_in_house Schema',
#  'households.items.properties.date_updated.$id': '#/properties/households/items/properties/date_updated',
#  'households.items.properties.date_updated.type': 'string',
#  'households.items.properties.date_updated.title': 'The Date_updated Schema',
#  'households.items.properties.date_updated.default': '',
#  'households.items.properties.date_updated.pattern': '^(.*)$',
#  'households.items.properties.house_ownership.$id': '#/properties/households/items/properties/house_ownership',
#  'households.items.properties.house_ownership.type': 'string',
#  'households.items.properties.house_ownership.title': 'The House_ownership Schema',
#  'households.items.properties.house_ownership.default': '',
#  'households.items.properties.house_ownership.pattern': '^(.*)$',
#  'households.items.properties.neighborhood_description.$id': '#/properties/households/items/properties/neighborhood_description',
#  'households.items.properties.neighborhood_description.type': 'string',
#  'households.items.properties.neighborhood_description.title': 'The Neighborhood_description Schema',
#  'households.items.properties.neighborhood_description.default': '',
#  'households.items.properties.neighborhood_description.pattern': '^(.*)$',
#  'households.items.properties.no_of_families_in_the_household.$id': '#/properties/households/items/properties/no_of_families_in_the_household',
#  'households.items.properties.no_of_families_in_the_household.type': 'integer',
#  'households.items.properties.no_of_families_in_the_household.title': 'The No_of_families_in_the_household Schema',
#  'households.items.properties.no_of_families_in_the_household.default': 0,
#  'households.items.properties.no_of_people_in_the_household.$id': '#/properties/households/items/properties/no_of_people_in_the_household',
#  'households.items.properties.no_of_people_in_the_household.type': 'integer',
#  'households.items.properties.no_of_people_in_the_household.title': 'The No_of_people_in_the_household Schema',
#  'households.items.properties.no_of_people_in_the_household.default': 0,
#  'households.items.properties.sanitary_ownership.$id': '#/properties/households/items/properties/sanitary_ownership',
#  'households.items.properties.sanitary_ownership.type': 'string',
#  'households.items.properties.sanitary_ownership.title': 'The Sanitary_ownership Schema',
#  'households.items.properties.sanitary_ownership.default': '',
#  'households.items.properties.sanitary_ownership.pattern': '^(.*)$',
#  'households.items.properties.sanitary_type.$id': '#/properties/households/items/properties/sanitary_type',
#  'households.items.properties.sanitary_type.type': 'array',
#  'households.items.properties.sanitary_type.title': 'The Sanitary_type Schema',
#  'households.items.properties.type_of_house.$id': '#/properties/households/items/properties/type_of_house',
#  'households.items.properties.type_of_house.type': 'string',
#  'households.items.properties.type_of_house.title': 'The Type_of_house Schema',
#  'households.items.properties.type_of_house.default': '',
#  'households.items.properties.type_of_house.pattern': '^(.*)$',
#  'households.items.properties.what_u_se_to_wash_hands.$id': '#/properties/households/items/properties/what_u_se_to_wash_hands',
#  'households.items.properties.what_u_se_to_wash_hands.type': 'string',
#  'households.items.properties.what_u_se_to_wash_hands.title': 'The What_u_se_to_wash_hands Schema',
#  'households.items.properties.what_u_se_to_wash_hands.default': '',
#  'households.items.properties.what_u_se_to_wash_hands.pattern': '^(.*)$',
#  'households.items.properties.water_sources.$id': '#/properties/households/items/properties/water_sources',
#  'households.items.properties.water_sources.type': 'array',
#  'households.items.properties.water_sources.title': 'The Water_sources Schema',
#  'households.items.properties.how_ensure_water_safe.$id': '#/properties/households/items/properties/how_ensure_water_safe',
#  'households.items.properties.how_ensure_water_safe.type': 'array',
#  'households.items.properties.how_ensure_water_safe.title': 'The How_ensure_water_safe Schema',
#  'identification.$id': '#/properties/identification',
#  'identification.type': 'object',
#  'identification.title': 'The Identification Schema',
#  'identification.properties.id1.$id': '#/properties/identification/properties/id1',
#  'identification.properties.id1.type': 'object',
#  'identification.properties.id1.title': 'The Id1 Schema',
#  'identification.properties.id1.properties.identifier.$id': '#/properties/identification/properties/id1/properties/identifier',
#  'identification.properties.id1.properties.identifier.type': 'string',
#  'identification.properties.id1.properties.identifier.title': 'The Identifier Schema',
#  'identification.properties.id1.properties.identifier.default': '',
#  'identification.properties.id1.properties.type.$id': '#/properties/identification/properties/id1/properties/type',
#  'identification.properties.id1.properties.type.type': 'string',
#  'identification.properties.id1.properties.type.title': 'The Type Schema',
#  'identification.properties.id1.properties.type.default': '',
#  'identification.properties.id1.properties.type.pattern': '^(.*)$',
#  'identification.properties.id2.$id': '#/properties/identification/properties/id2',
#  'identification.properties.id2.type': 'object',
#  'identification.properties.id2.title': 'The Id2 Schema',
#  'identification.properties.id2.properties.identifier.$id': '#/properties/identification/properties/id2/properties/identifier',
#  'identification.properties.id2.properties.identifier.type': 'string',
#  'identification.properties.id2.properties.identifier.title': 'The Identifier Schema',
#  'identification.properties.id2.properties.identifier.default': '',
#  'identification.properties.id2.properties.type.$id': '#/properties/identification/properties/id2/properties/type',
#  'identification.properties.id2.properties.type.type': 'string',
#  'identification.properties.id2.properties.type.title': 'The Type Schema',
#  'identification.properties.id2.properties.type.default': '',
#  'identification.properties.id2.properties.type.pattern': '^(.*)$',
#  'identification.properties.id3.$id': '#/properties/identification/properties/id3',
#  'identification.properties.id3.type': 'object',
#  'identification.properties.id3.title': 'The Id3 Schema',
#  'identification.properties.id3.properties.identifier.$id': '#/properties/identification/properties/id3/properties/identifier',
#  'identification.properties.id3.properties.identifier.type': 'string',
#  'identification.properties.id3.properties.identifier.title': 'The Identifier Schema',
#  'identification.properties.id3.properties.identifier.default': '',
#  'identification.properties.id3.properties.type.$id': '#/properties/identification/properties/id3/properties/type',
#  'identification.properties.id3.properties.type.type': 'string',
#  'identification.properties.id3.properties.type.title': 'The Type Schema',
#  'identification.properties.id3.properties.type.default': '',
#  'identification.properties.id3.properties.type.pattern': '^(.*)$',
#  'last_name.$id': '#/properties/last_name',
#  'last_name.type': 'string',
#  'last_name.title': 'The Last_name Schema',
#  'last_name.default': '',
#  'last_name.pattern': '^(.*)$',
#  'last_name_suffix.$id': '#/properties/last_name_suffix',
#  'last_name_suffix.type': 'string',
#  'last_name_suffix.title': 'The Last_name_suffix Schema',
#  'last_name_suffix.default': '',
#  'last_name_suffix.pattern': '^(.*)$',
#  'middle_name.$id': '#/properties/middle_name',
#  'middle_name.type': 'string',
#  'middle_name.title': 'The Middle_name Schema',
#  'middle_name.default': '',
#  'middle_name.pattern': '^(.*)$',
#  'nhid.$id': '#/properties/nhid',
#  'nhid.type': 'string',
#  'nhid.title': 'The Nhid Schema',
#  'nhid.default': '',
#  'nhid.pattern': '^(.*)$',
#  'organization.$id': '#/properties/organization',
#  'organization.type': 'string',
#  'organization.title': 'The Organization Schema',
#  'organization.default': '',
#  'organization.pattern': '^(.*)$',
#  'profile_picture.$id': '#/properties/profile_picture',
#  'profile_picture.type': 'object',
#  'profile_picture.title': 'The Profile_picture Schema',
#  'profile_picture.properties.name.$id': '#/properties/profile_picture/properties/name',
#  'profile_picture.properties.name.type': 'string',
#  'profile_picture.properties.name.title': 'The Name Schema',
#  'profile_picture.properties.name.default': '',
#  'profile_picture.properties.name.pattern': '^(.*)$',
#  'profile_picture.properties.path.$id': '#/properties/profile_picture/properties/path',
#  'profile_picture.properties.path.type': 'string',
#  'profile_picture.properties.path.title': 'The Path Schema',
#  'profile_picture.properties.path.default': '',
#  'profile_picture.properties.path.pattern': '^(.*)$',
#  'profiles.$id': '#/properties/profiles',
#  'profiles.type': 'array',
#  'profiles.title': 'The Profiles Schema',
#  'profiles.items.$id': '#/properties/profiles/items',
#  'profiles.items.type': 'object',
#  'profiles.items.title': 'The Items Schema',
#  'profiles.items.properties.civil_status.$id': '#/properties/profiles/items/properties/civil_status',
#  'profiles.items.properties.civil_status.type': 'string',
#  'profiles.items.properties.civil_status.title': 'The Civil_status Schema',
#  'profiles.items.properties.civil_status.default': '',
#  'profiles.items.properties.civil_status.pattern': '^(.*)$',
#  'profiles.items.properties.date_updated.$id': '#/properties/profiles/items/properties/date_updated',
#  'profiles.items.properties.date_updated.type': 'string',
#  'profiles.items.properties.date_updated.title': 'The Date_updated Schema',
#  'profiles.items.properties.date_updated.default': '',
#  'profiles.items.properties.date_updated.pattern': '^(.*)$',
#  'profiles.items.properties.education.$id': '#/properties/profiles/items/properties/education',
#  'profiles.items.properties.education.type': 'string',
#  'profiles.items.properties.education.title': 'The Education Schema',
#  'profiles.items.properties.education.default': '',
#  'profiles.items.properties.education.pattern': '^(.*)$',
#  'profiles.items.properties.employment.$id': '#/properties/profiles/items/properties/employment',
#  'profiles.items.properties.employment.type': 'object',
#  'profiles.items.properties.employment.title': 'The Employment Schema',
#  'profiles.items.properties.employment.properties.is_employed.$id': '#/properties/profiles/items/properties/employment/properties/is_employed',
#  'profiles.items.properties.employment.properties.is_employed.type': 'boolean',
#  'profiles.items.properties.employment.properties.is_employed.title': 'The Is_employed Schema',
#  'profiles.items.properties.employment.properties.is_employed.default': False,
#  'profiles.items.properties.employment.properties.monthly_income.$id': '#/properties/profiles/items/properties/employment/properties/monthly_income',
#  'profiles.items.properties.employment.properties.monthly_income.type': 'string',
#  'profiles.items.properties.employment.properties.monthly_income.title': 'The Monthly_income Schema',
#  'profiles.items.properties.employment.properties.monthly_income.default': '',
#  'profiles.items.properties.employment.properties.monthly_income.pattern': '^(.*)$',
#  'profiles.items.properties.employment.properties.nature.$id': '#/properties/profiles/items/properties/employment/properties/nature',
#  'profiles.items.properties.employment.properties.nature.type': 'string',
#  'profiles.items.properties.employment.properties.nature.title': 'The Nature Schema',
#  'profiles.items.properties.employment.properties.nature.default': '',
#  'profiles.items.properties.employment.properties.nature.pattern': '^(.*)$',
#  'profiles.items.properties.employment.properties.currency.$id': '#/properties/profiles/items/properties/employment/properties/currency',
#  'profiles.items.properties.employment.properties.currency.type': 'string',
#  'profiles.items.properties.employment.properties.currency.title': 'The Currency Schema',
#  'profiles.items.properties.employment.properties.currency.default': '',
#  'profiles.items.properties.employment.properties.currency.pattern': '^(.*)$',
#  'profiles.items.properties.are_you_currently_earning.$id': '#/properties/profiles/items/properties/are_you_currently_earning',
#  'profiles.items.properties.are_you_currently_earning.type': 'string',
#  'profiles.items.properties.are_you_currently_earning.title': 'The Are_you_currently_earning Schema',
#  'profiles.items.properties.are_you_currently_earning.default': '',
#  'profiles.items.properties.are_you_currently_earning.pattern': '^(.*)$',
#  'profiles.items.properties.where_income_from.$id': '#/properties/profiles/items/properties/where_income_from',
#  'profiles.items.properties.where_income_from.type': 'string',
#  'profiles.items.properties.where_income_from.title': 'The Where_income_from Schema',
#  'profiles.items.properties.where_income_from.default': '',
#  'profiles.items.properties.where_income_from.pattern': '^(.*)$',
#  'profiles.items.properties.religion.$id': '#/properties/profiles/items/properties/religion',
#  'profiles.items.properties.religion.type': 'string',
#  'profiles.items.properties.religion.title': 'The Religion Schema',
#  'profiles.items.properties.religion.default': '',
#  'profiles.items.properties.religion.pattern': '^(.*)$',
#  'registered_at.$id': '#/properties/registered_at',
#  'registered_at.type': 'string',
#  'registered_at.title': 'The Registered_at Schema',
#  'registered_at.default': '',
#  'registered_at.pattern': '^(.*)$',
#  'symptoms_collection.$id': '#/properties/symptoms_collection',
#  'symptoms_collection.type': 'array',
#  'symptoms_collection.title': 'The Symptoms_collection Schema',
#  'symptoms_collection.items.$id': '#/properties/symptoms_collection/items',
#  'symptoms_collection.items.type': 'object',
#  'symptoms_collection.items.title': 'The Items Schema',
#  'symptoms_collection.items.properties.abdomen.$id': '#/properties/symptoms_collection/items/properties/abdomen',
#  'symptoms_collection.items.properties.abdomen.type': 'object',
#  'symptoms_collection.items.properties.abdomen.title': 'The Abdomen Schema',
#  'symptoms_collection.items.properties.abdomen.properties.abdomen.$id': '#/properties/symptoms_collection/items/properties/abdomen/properties/abdomen',
#  'symptoms_collection.items.properties.abdomen.properties.abdomen.type': 'array',
#  'symptoms_collection.items.properties.abdomen.properties.abdomen.title': 'The Abdomen Schema',
#  'symptoms_collection.items.properties.arms.$id': '#/properties/symptoms_collection/items/properties/arms',
#  'symptoms_collection.items.properties.arms.type': 'object',
#  'symptoms_collection.items.properties.arms.title': 'The Arms Schema',
#  'symptoms_collection.items.properties.arms.properties.elbow.$id': '#/properties/symptoms_collection/items/properties/arms/properties/elbow',
#  'symptoms_collection.items.properties.arms.properties.elbow.type': 'array',
#  'symptoms_collection.items.properties.arms.properties.elbow.title': 'The Elbow Schema',
#  'symptoms_collection.items.properties.arms.properties.fingers.$id': '#/properties/symptoms_collection/items/properties/arms/properties/fingers',
#  'symptoms_collection.items.properties.arms.properties.fingers.type': 'array',
#  'symptoms_collection.items.properties.arms.properties.fingers.title': 'The Fingers Schema',
#  'symptoms_collection.items.properties.arms.properties.hand_and_palm.$id': '#/properties/symptoms_collection/items/properties/arms/properties/hand_and_palm',
#  'symptoms_collection.items.properties.arms.properties.hand_and_palm.type': 'array',
#  'symptoms_collection.items.properties.arms.properties.hand_and_palm.title': 'The Hand_and_palm Schema',
#  'symptoms_collection.items.properties.arms.properties.lower_arm.$id': '#/properties/symptoms_collection/items/properties/arms/properties/lower_arm',
#  'symptoms_collection.items.properties.arms.properties.lower_arm.type': 'array',
#  'symptoms_collection.items.properties.arms.properties.lower_arm.title': 'The Lower_arm Schema',
#  'symptoms_collection.items.properties.arms.properties.upper_arm.$id': '#/properties/symptoms_collection/items/properties/arms/properties/upper_arm',
#  'symptoms_collection.items.properties.arms.properties.upper_arm.type': 'array',
#  'symptoms_collection.items.properties.arms.properties.upper_arm.title': 'The Upper_arm Schema',
#  'symptoms_collection.items.properties.arms.properties.wrist.$id': '#/properties/symptoms_collection/items/properties/arms/properties/wrist',
#  'symptoms_collection.items.properties.arms.properties.wrist.type': 'array',
#  'symptoms_collection.items.properties.arms.properties.wrist.title': 'The Wrist Schema',
#  'symptoms_collection.items.properties.chest.$id': '#/properties/symptoms_collection/items/properties/chest',
#  'symptoms_collection.items.properties.chest.type': 'object',
#  'symptoms_collection.items.properties.chest.title': 'The Chest Schema',
#  'symptoms_collection.items.properties.chest.properties.chest.$id': '#/properties/symptoms_collection/items/properties/chest/properties/chest',
#  'symptoms_collection.items.properties.chest.properties.chest.type': 'array',
#  'symptoms_collection.items.properties.chest.properties.chest.title': 'The Chest Schema',
#  'symptoms_collection.items.properties.chest.properties.lungs_and_breathing.$id': '#/properties/symptoms_collection/items/properties/chest/properties/lungs_and_breathing',
#  'symptoms_collection.items.properties.chest.properties.lungs_and_breathing.type': 'array',
#  'symptoms_collection.items.properties.chest.properties.lungs_and_breathing.title': 'The Lungs_and_breathing Schema',
#  'symptoms_collection.items.properties.date_updated.$id': '#/properties/symptoms_collection/items/properties/date_updated',
#  'symptoms_collection.items.properties.date_updated.type': 'string',
#  'symptoms_collection.items.properties.date_updated.title': 'The Date_updated Schema',
#  'symptoms_collection.items.properties.date_updated.default': '',
#  'symptoms_collection.items.properties.date_updated.pattern': '^(.*)$',
#  'symptoms_collection.items.properties.head.$id': '#/properties/symptoms_collection/items/properties/head',
#  'symptoms_collection.items.properties.head.type': 'object',
#  'symptoms_collection.items.properties.head.title': 'The Head Schema',
#  'symptoms_collection.items.properties.head.properties.chin_and_jaw.$id': '#/properties/symptoms_collection/items/properties/head/properties/chin_and_jaw',
#  'symptoms_collection.items.properties.head.properties.chin_and_jaw.type': 'array',
#  'symptoms_collection.items.properties.head.properties.chin_and_jaw.title': 'The Chin_and_jaw Schema',
#  'symptoms_collection.items.properties.head.properties.ears.$id': '#/properties/symptoms_collection/items/properties/head/properties/ears',
#  'symptoms_collection.items.properties.head.properties.ears.type': 'array',
#  'symptoms_collection.items.properties.head.properties.ears.title': 'The Ears Schema',
#  'symptoms_collection.items.properties.head.properties.eyes.$id': '#/properties/symptoms_collection/items/properties/head/properties/eyes',
#  'symptoms_collection.items.properties.head.properties.eyes.type': 'array',
#  'symptoms_collection.items.properties.head.properties.eyes.title': 'The Eyes Schema',
#  'symptoms_collection.items.properties.head.properties.head.$id': '#/properties/symptoms_collection/items/properties/head/properties/head',
#  'symptoms_collection.items.properties.head.properties.head.type': 'array',
#  'symptoms_collection.items.properties.head.properties.head.title': 'The Head Schema',
#  'symptoms_collection.items.properties.head.properties.mouth.$id': '#/properties/symptoms_collection/items/properties/head/properties/mouth',
#  'symptoms_collection.items.properties.head.properties.mouth.type': 'array',
#  'symptoms_collection.items.properties.head.properties.mouth.title': 'The Mouth Schema',
#  'symptoms_collection.items.properties.head.properties.nose.$id': '#/properties/symptoms_collection/items/properties/head/properties/nose',
#  'symptoms_collection.items.properties.head.properties.nose.type': 'array',
#  'symptoms_collection.items.properties.head.properties.nose.title': 'The Nose Schema',
#  'symptoms_collection.items.properties.legs.$id': '#/properties/symptoms_collection/items/properties/legs',
#  'symptoms_collection.items.properties.legs.type': 'object',
#  'symptoms_collection.items.properties.legs.title': 'The Legs Schema',
#  'symptoms_collection.items.properties.legs.properties.foot.$id': '#/properties/symptoms_collection/items/properties/legs/properties/foot',
#  'symptoms_collection.items.properties.legs.properties.foot.type': 'array',
#  'symptoms_collection.items.properties.legs.properties.foot.title': 'The Foot Schema',
#  'symptoms_collection.items.properties.legs.properties.knee.$id': '#/properties/symptoms_collection/items/properties/legs/properties/knee',
#  'symptoms_collection.items.properties.legs.properties.knee.type': 'array',
#  'symptoms_collection.items.properties.legs.properties.knee.title': 'The Knee Schema',
#  'symptoms_collection.items.properties.legs.properties.shin.$id': '#/properties/symptoms_collection/items/properties/legs/properties/shin',
#  'symptoms_collection.items.properties.legs.properties.shin.type': 'array',
#  'symptoms_collection.items.properties.legs.properties.shin.title': 'The Shin Schema',
#  'symptoms_collection.items.properties.legs.properties.thigh.$id': '#/properties/symptoms_collection/items/properties/legs/properties/thigh',
#  'symptoms_collection.items.properties.legs.properties.thigh.type': 'array',
#  'symptoms_collection.items.properties.legs.properties.thigh.title': 'The Thigh Schema',
#  'symptoms_collection.items.properties.legs.properties.toes.$id': '#/properties/symptoms_collection/items/properties/legs/properties/toes',
#  'symptoms_collection.items.properties.legs.properties.toes.type': 'array',
#  'symptoms_collection.items.properties.legs.properties.toes.title': 'The Toes Schema',
#  'symptoms_collection.items.properties.neck.$id': '#/properties/symptoms_collection/items/properties/neck',
#  'symptoms_collection.items.properties.neck.type': 'object',
#  'symptoms_collection.items.properties.neck.title': 'The Neck Schema',
#  'symptoms_collection.items.properties.neck.properties.lowerback.$id': '#/properties/symptoms_collection/items/properties/neck/properties/lowerback',
#  'symptoms_collection.items.properties.neck.properties.lowerback.type': 'array',
#  'symptoms_collection.items.properties.neck.properties.lowerback.title': 'The Lowerback Schema',
#  'symptoms_collection.items.properties.neck.properties.neck.$id': '#/properties/symptoms_collection/items/properties/neck/properties/neck',
#  'symptoms_collection.items.properties.neck.properties.neck.type': 'array',
#  'symptoms_collection.items.properties.neck.properties.neck.title': 'The Neck Schema',
#  'symptoms_collection.items.properties.neck.properties.shoulders.$id': '#/properties/symptoms_collection/items/properties/neck/properties/shoulders',
#  'symptoms_collection.items.properties.neck.properties.shoulders.type': 'array',
#  'symptoms_collection.items.properties.neck.properties.shoulders.title': 'The Shoulders Schema',
#  'symptoms_collection.items.properties.neck.properties.throat.$id': '#/properties/symptoms_collection/items/properties/neck/properties/throat',
#  'symptoms_collection.items.properties.neck.properties.throat.type': 'array',
#  'symptoms_collection.items.properties.neck.properties.throat.title': 'The Throat Schema',
#  'symptoms_collection.items.properties.neck.properties.upperback.$id': '#/properties/symptoms_collection/items/properties/neck/properties/upperback',
#  'symptoms_collection.items.properties.neck.properties.upperback.type': 'array',
#  'symptoms_collection.items.properties.neck.properties.upperback.title': 'The Upperback Schema',
#  'symptoms_collection.items.properties.pelvis.$id': '#/properties/symptoms_collection/items/properties/pelvis',
#  'symptoms_collection.items.properties.pelvis.type': 'object',
#  'symptoms_collection.items.properties.pelvis.title': 'The Pelvis Schema',
#  'symptoms_collection.items.properties.pelvis.properties.genitals.$id': '#/properties/symptoms_collection/items/properties/pelvis/properties/genitals',
#  'symptoms_collection.items.properties.pelvis.properties.genitals.type': 'array',
#  'symptoms_collection.items.properties.pelvis.properties.genitals.title': 'The Genitals Schema',
#  'symptoms_collection.items.properties.pelvis.properties.hip.$id': '#/properties/symptoms_collection/items/properties/pelvis/properties/hip',
#  'symptoms_collection.items.properties.pelvis.properties.hip.type': 'array',
#  'symptoms_collection.items.properties.pelvis.properties.hip.title': 'The Hip Schema',
#  'symptoms_collection.items.properties.pelvis.properties.pelvis.$id': '#/properties/symptoms_collection/items/properties/pelvis/properties/pelvis',
#  'symptoms_collection.items.properties.pelvis.properties.pelvis.type': 'array',
#  'symptoms_collection.items.properties.pelvis.properties.pelvis.title': 'The Pelvis Schema',
#  'symptoms_collection.items.properties.skin.$id': '#/properties/symptoms_collection/items/properties/skin',
#  'symptoms_collection.items.properties.skin.type': 'object',
#  'symptoms_collection.items.properties.skin.title': 'The Skin Schema',
#  'symptoms_collection.items.properties.skin.properties.skin.$id': '#/properties/symptoms_collection/items/properties/skin/properties/skin',
#  'symptoms_collection.items.properties.skin.properties.skin.type': 'array',
#  'symptoms_collection.items.properties.skin.properties.skin.title': 'The Skin Schema',
#  'child_healths.$id': '#/properties/child_healths',
#  'child_healths.type': 'array',
#  'child_healths.title': 'The Child_healths Schema',
#  'child_healths.items.$id': '#/properties/child_healths/items',
#  'child_healths.items.type': 'object',
#  'child_healths.items.title': 'The Items Schema',
#  'child_healths.items.properties.newborn.$id': '#/properties/child_healths/items/properties/newborn',
#  'child_healths.items.properties.newborn.type': 'object',
#  'child_healths.items.properties.newborn.title': 'The Newborn Schema',
#  'child_healths.items.properties.newborn.properties.provided_with_the_following.$id': '#/properties/child_healths/items/properties/newborn/properties/provided_with_the_following',
#  'child_healths.items.properties.newborn.properties.provided_with_the_following.type': 'array',
#  'child_healths.items.properties.newborn.properties.provided_with_the_following.title': 'The Provided_with_the_following Schema',
#  'child_healths.items.properties.newborn.properties.exclusive_breast_feeding.$id': '#/properties/child_healths/items/properties/newborn/properties/exclusive_breast_feeding',
#  'child_healths.items.properties.newborn.properties.exclusive_breast_feeding.type': 'boolean',
#  'child_healths.items.properties.newborn.properties.exclusive_breast_feeding.title': 'The Exclusive_breast_feeding Schema',
#  'child_healths.items.properties.newborn.properties.exclusive_breast_feeding.default': False,
#  'child_healths.items.properties.newborn.properties.experience_any.$id': '#/properties/child_healths/items/properties/newborn/properties/experience_any',
#  'child_healths.items.properties.newborn.properties.experience_any.type': 'array',
#  'child_healths.items.properties.newborn.properties.experience_any.title': 'The Experience_any Schema',
#  'child_healths.items.properties.newborn.properties.provide_colostrum_or_breast_milk_after_delivery.$id': '#/properties/child_healths/items/properties/newborn/properties/provide_colostrum_or_breast_milk_after_delivery',
#  'child_healths.items.properties.newborn.properties.provide_colostrum_or_breast_milk_after_delivery.type': 'string',
#  'child_healths.items.properties.newborn.properties.provide_colostrum_or_breast_milk_after_delivery.title': 'The Provide_colostrum_or_breast_milk_after_delivery Schema',
#  'child_healths.items.properties.newborn.properties.provide_colostrum_or_breast_milk_after_delivery.default': '',
#  'child_healths.items.properties.newborn.properties.provide_colostrum_or_breast_milk_after_delivery.pattern': '^(.*)$',
# ...
#  'family_planning_and_maternal_healths.items.properties.is_pregnant.properties.were_you_vaccinated_with_tetanus_toxoid.title': 'The Were_you_vaccinated_with_tetanus_toxoid Schema',
#  'family_planning_and_maternal_healths.items.properties.is_pregnant.properties.is_this_your_first_pregnancy.$id': '#/properties/family_planning_and_maternal_healths/items/properties/is_pregnant/properties/is_this_your_first_pregnancy',
#  'family_planning_and_maternal_healths.items.properties.is_pregnant.properties.is_this_your_first_pregnancy.type': 'boolean',
#  'family_planning_and_maternal_healths.items.properties.is_pregnant.properties.is_this_your_first_pregnancy.title': 'The Is_this_your_first_pregnancy Schema',
#  'family_planning_and_maternal_healths.items.properties.is_pregnant.properties.is_this_your_first_pregnancy.default': False,
#  'family_planning_and_maternal_healths.items.properties.is_pregnant.properties.did_you_give_birth_less_than_6_weeks_ago.$id': '#/properties/family_planning_and_maternal_healths/items/properties/is_pregnant/properties/did_you_give_birth_less_than_6_weeks_ago',
#  'family_planning_and_maternal_healths.items.properties.is_pregnant.properties.did_you_give_birth_less_than_6_weeks_ago.type': 'boolean',
#  'family_planning_and_maternal_healths.items.properties.is_pregnant.properties.did_you_give_birth_less_than_6_weeks_ago.title': 'The Did_you_give_birth_less_than_6_weeks_ago Schema',
#  'family_planning_and_maternal_healths.items.properties.is_pregnant.properties.did_you_give_birth_less_than_6_weeks_ago.default': False,
#  'family_planning_and_maternal_healths.items.properties.is_pregnant.properties.did_you_experience_the_following.$id': '#/properties/family_planning_and_maternal_healths/items/properties/is_pregnant/properties/did_you_experience_the_following',
#  'family_planning_and_maternal_healths.items.properties.is_pregnant.properties.did_you_experience_the_following.type': 'array',
#  'family_planning_and_maternal_healths.items.properties.is_pregnant.properties.did_you_experience_the_following.title': 'The Did_you_experience_the_following Schema',
#  'family_planning_and_maternal_healths.items.properties.is_pregnant.properties.do_you_intend_to_practice_family_planning.$id': '#/properties/family_planning_and_maternal_healths/items/properties/is_pregnant/properties/do_you_intend_to_practice_family_planning',
#  'family_planning_and_maternal_healths.items.properties.is_pregnant.properties.do_you_intend_to_practice_family_planning.type': 'boolean',
#  'family_planning_and_maternal_healths.items.properties.is_pregnant.properties.do_you_intend_to_practice_family_planning.title': 'The Do_you_intend_to_practice_family_planning Schema',
#  'family_planning_and_maternal_healths.items.properties.is_pregnant.properties.do_you_intend_to_practice_family_planning.default': False,
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.$id': '#/properties/family_planning_and_maternal_healths/items/properties/not_pregnant',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.type': 'object',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.title': 'The Not_pregnant Schema',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.have_you_been_pregnant_ever_since.$id': '#/properties/family_planning_and_maternal_healths/items/properties/not_pregnant/properties/have_you_been_pregnant_ever_since',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.have_you_been_pregnant_ever_since.type': 'boolean',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.have_you_been_pregnant_ever_since.title': 'The Have_you_been_pregnant_ever_since Schema',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.have_you_been_pregnant_ever_since.default': False,
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.how_long_has_it_been_since_your_last_delivery.$id': '#/properties/family_planning_and_maternal_healths/items/properties/not_pregnant/properties/how_long_has_it_been_since_your_last_delivery',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.how_long_has_it_been_since_your_last_delivery.type': 'string',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.how_long_has_it_been_since_your_last_delivery.title': 'The How_long_has_it_been_since_your_last_delivery Schema',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.how_long_has_it_been_since_your_last_delivery.default': '',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.how_long_has_it_been_since_your_last_delivery.pattern': '^(.*)$',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.when_was_your_last_delivery_date.$id': '#/properties/family_planning_and_maternal_healths/items/properties/not_pregnant/properties/when_was_your_last_delivery_date',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.when_was_your_last_delivery_date.type': 'string',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.when_was_your_last_delivery_date.title': 'The When_was_your_last_delivery_date Schema',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.when_was_your_last_delivery_date.default': '',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.when_was_your_last_delivery_date.pattern': '^(.*)$',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.what_type_is_the_place_of_delivery.$id': '#/properties/family_planning_and_maternal_healths/items/properties/not_pregnant/properties/what_type_is_the_place_of_delivery',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.what_type_is_the_place_of_delivery.type': 'string',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.what_type_is_the_place_of_delivery.title': 'The What_type_is_the_place_of_delivery Schema',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.what_type_is_the_place_of_delivery.default': '',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.what_type_is_the_place_of_delivery.pattern': '^(.*)$',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.what_childbirth_support_did_you_received.$id': '#/properties/family_planning_and_maternal_healths/items/properties/not_pregnant/properties/what_childbirth_support_did_you_received',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.what_childbirth_support_did_you_received.type': 'string',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.what_childbirth_support_did_you_received.title': 'The What_childbirth_support_did_you_received Schema',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.what_childbirth_support_did_you_received.default': '',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.what_childbirth_support_did_you_received.pattern': '^(.*)$',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.did_you_experience_any_of_the_following_after_delivery.$id': '#/properties/family_planning_and_maternal_healths/items/properties/not_pregnant/properties/did_you_experience_any_of_the_following_after_delivery',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.did_you_experience_any_of_the_following_after_delivery.type': 'array',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.did_you_experience_any_of_the_following_after_delivery.title': 'The Did_you_experience_any_of_the_following_after_delivery Schema',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.do_you_have_spouse_right_now.$id': '#/properties/family_planning_and_maternal_healths/items/properties/not_pregnant/properties/do_you_have_spouse_right_now',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.do_you_have_spouse_right_now.type': 'boolean',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.do_you_have_spouse_right_now.title': 'The Do_you_have_spouse_right_now Schema',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.do_you_have_spouse_right_now.default': False,
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.are_you_both_using_any_family_method.$id': '#/properties/family_planning_and_maternal_healths/items/properties/not_pregnant/properties/are_you_both_using_any_family_method',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.are_you_both_using_any_family_method.type': 'boolean',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.are_you_both_using_any_family_method.title': 'The Are_you_both_using_any_family_method Schema',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.are_you_both_using_any_family_method.default': False,
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.family_planning_methods_you_are_using.$id': '#/properties/family_planning_and_maternal_healths/items/properties/not_pregnant/properties/family_planning_methods_you_are_using',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.family_planning_methods_you_are_using.type': 'array',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.family_planning_methods_you_are_using.title': 'The Family_planning_methods_you_are_using Schema',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.are_you_willing_to_use_any_family_planning_method.$id': '#/properties/family_planning_and_maternal_healths/items/properties/not_pregnant/properties/are_you_willing_to_use_any_family_planning_method',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.are_you_willing_to_use_any_family_planning_method.type': 'boolean',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.are_you_willing_to_use_any_family_planning_method.title': 'The Are_you_willing_to_use_any_family_planning_method Schema',
#  'family_planning_and_maternal_healths.items.properties.not_pregnant.properties.are_you_willing_to_use_any_family_planning_method.default': False,
#  'family_planning_and_maternal_healths.items.properties.date_updated.$id': '#/properties/family_planning_and_maternal_healths/items/properties/date_updated',
#  'family_planning_and_maternal_healths.items.properties.date_updated.type': 'string',
#  'family_planning_and_maternal_healths.items.properties.date_updated.title': 'The Date_updated Schema',
#  'family_planning_and_maternal_healths.items.properties.date_updated.default': '',
#  'family_planning_and_maternal_healths.items.properties.date_updated.pattern': '^(.*)$',
#  'dental_health.$id': '#/properties/dental_health',
#  'dental_health.type': 'array',
#  'dental_health.title': 'The Dental_health Schema',
#  'dental_health.items.$id': '#/properties/dental_health/items',
#  'dental_health.items.type': 'object',
#  'dental_health.items.title': 'The Items Schema',
#  'dental_health.items.properties.do_you_own_toothbrush.$id': '#/properties/dental_health/items/properties/do_you_own_toothbrush',
#  'dental_health.items.properties.do_you_own_toothbrush.type': 'boolean',
#  'dental_health.items.properties.do_you_own_toothbrush.title': 'The Do_you_own_toothbrush Schema',
#  'dental_health.items.properties.do_you_own_toothbrush.default': False,
#  'dental_health.items.properties.times_clean_teeth_daily.$id': '#/properties/dental_health/items/properties/times_clean_teeth_daily',
#  'dental_health.items.properties.times_clean_teeth_daily.type': 'string',
#  'dental_health.items.properties.times_clean_teeth_daily.title': 'The Times_clean_teeth_daily Schema',
#  'dental_health.items.properties.times_clean_teeth_daily.default': '',
#  'dental_health.items.properties.times_clean_teeth_daily.pattern': '^(.*)$',
#  'dental_health.items.properties.what_problems.$id': '#/properties/dental_health/items/properties/what_problems',
#  'dental_health.items.properties.what_problems.type': 'array',
#  'dental_health.items.properties.what_problems.title': 'The What_problems Schema',
#  'dental_health.items.properties.family_members_d_problems_last_6_months.$id': '#/properties/dental_health/items/properties/family_members_d_problems_last_6_months',
#  'dental_health.items.properties.family_members_d_problems_last_6_months.type': 'string',
#  'dental_health.items.properties.family_members_d_problems_last_6_months.title': 'The Family_members_d_problems_last_6_months Schema',
#  'dental_health.items.properties.family_members_d_problems_last_6_months.default': '',
#  'dental_health.items.properties.family_members_d_problems_last_6_months.pattern': '^(.*)$',
#  'dental_health.items.properties.what_do_u_use_to_clean_teeth.$id': '#/properties/dental_health/items/properties/what_do_u_use_to_clean_teeth',
#  'dental_health.items.properties.what_do_u_use_to_clean_teeth.type': 'string',
#  'dental_health.items.properties.what_do_u_use_to_clean_teeth.title': 'The What_do_u_use_to_clean_teeth Schema',
#  'dental_health.items.properties.what_do_u_use_to_clean_teeth.default': '',
#  'dental_health.items.properties.what_do_u_use_to_clean_teeth.pattern': '^(.*)$',
#  'dental_health.items.properties.date_updated.$id': '#/properties/dental_health/items/properties/date_updated',
#  'dental_health.items.properties.date_updated.type': 'string',
#  'dental_health.items.properties.date_updated.title': 'The Date_updated Schema',
#  'dental_health.items.properties.date_updated.default': '',
#  'dental_health.items.properties.date_updated.pattern': '^(.*)$',
#  'disability.$id': '#/properties/disability',
#  'disability.type': 'array',
#  'disability.title': 'The Disability Schema',
#  'disability.items.$id': '#/properties/disability/items',
#  'disability.items.type': 'object',
#  'disability.items.title': 'The Items Schema',
#  'disability.items.properties.do_you_have_types_disability.$id': '#/properties/disability/items/properties/do_you_have_types_disability',
#  'disability.items.properties.do_you_have_types_disability.type': 'string',
#  'disability.items.properties.do_you_have_types_disability.title': 'The Do_you_have_types_disability Schema',
#  'disability.items.properties.do_you_have_types_disability.default': '',
#  'disability.items.properties.do_you_have_types_disability.pattern': '^(.*)$',
#  'disability.items.properties.date_updated.$id': '#/properties/disability/items/properties/date_updated',
#  'disability.items.properties.date_updated.type': 'string',
#  'disability.items.properties.date_updated.title': 'The Date_updated Schema',
#  'disability.items.properties.date_updated.default': '',
#  'disability.items.properties.date_updated.pattern': '^(.*)$',
#  'type.$id': '#/properties/type',
#  'type.type': 'string',
#  'type.title': 'The Type Schema',
#  'type.default': '',
#  'type.pattern': '^(.*)$',
#  'user-cam.$id': '#/properties/user-cam',
#  'user-cam.type': 'object',
#  'user-cam.title': 'The User-cam Schema',
#  'user-cam.properties.id.$id': '#/properties/user-cam/properties/id',
#  'user-cam.properties.id.type': 'string',
#  'user-cam.properties.id.title': 'The Id Schema',
#  'user-cam.properties.id.default': '',
#  'user-cam.properties.id.pattern': '^(.*)$',
#  'user-cam.properties.owner.$id': '#/properties/user-cam/properties/owner',
#  'user-cam.properties.owner.type': 'string',
#  'user-cam.properties.owner.title': 'The Owner Schema',
#  'user-cam.properties.owner.default': '',
#  'user-cam.properties.owner.pattern': '^(.*)$',
#  'date_completed.$id': '#/properties/date_completed',
#  'date_completed.type': 'string',
#  'date_completed.title': 'The Date_completed Schema',
#  'date_completed.default': '',
#  'date_completed.pattern': '^(.*)$'}

# %%
for health_information in test_data:
    print(health_information)
    print('------')
# Out:
# {'abdomen': {'abdomen': []}, 'arms': {'elbow': ['Weakness'], 'fingers': [], 'hand_and_palm': [], 'lower_arm': [], 'upper_arm': [], 'wrist': []}, 'chest': {'chest': ['Chest pain', 'Muscle pain', 'Weakness'], 'lungs_and_breathing': ['Shortness of breath', 'Difficulty of breathing']}, 'date_updated': '03/11/2018 at 09:43:48 AM GMT+08:00', 'head': {'chin_and_jaw': [], 'ears': [], 'eyes': [], 'head': [], 'mouth': [], 'nose': []}, 'legs': {'foot': ['Foot pain'], 'knee': ['Knee pain', 'Knee weakness'], 'shin': [], 'thigh': [], 'toes': []}, 'neck': {'lowerback': [], 'neck': [], 'shoulders': [], 'throat': [], 'upperback': []}, 'pelvis': {'genitals': [], 'hip': [], 'pelvis': []}, 'skin': {'skin': []}}
# ------
# {'abdomen': {'abdomen': []}, 'arms': {'elbow': ['Muscle pain', 'Weakness'], 'fingers': [], 'hand_and_palm': [], 'lower_arm': [], 'upper_arm': [], 'wrist': []}, 'chest': {'chest': ['Chest pain', 'Muscle pain'], 'lungs_and_breathing': ['Shortness of breath']}, 'date_updated': '03/11/2018 at 09:43:48 AM GMT+08:00', 'head': {'chin_and_jaw': [], 'ears': [], 'eyes': [], 'head': [], 'mouth': [], 'nose': []}, 'legs': {'foot': ['Joint pain'], 'knee': ['Joint pain'], 'shin': [], 'thigh': [], 'toes': []}, 'neck': {'lowerback': [], 'neck': [], 'shoulders': [], 'throat': [], 'upperback': []}, 'pelvis': {'genitals': [], 'hip': [], 'pelvis': []}, 'skin': {'skin': []}}
# ------

# %% [markdown]
# ### Flatten array type

# %% [markdown]
# ## TODO: Read kobo_data.schema to create Postgres Table schema

# %%
CREATE TABLE public.household
(
    id serial NOT NULL,
    name character varying,
    CONSTRAINT household_id PRIMARY KEY (id)
)
WITH (
    OIDS = FALSE
);

ALTER TABLE public.household
    OWNER to postgres;
# Out:
#   File "<ipython-input-22-832a74fedd7d>", line 1
#     CREATE TABLE public.household
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Insert data into Postgres DB

# %%
def insert(name):
    """ insert a new vendor into the vendors table """
    sql = """INSERT INTO demographics(name)
             VALUES(%s) RETURNING id;"""
    conn = None
    vendor_id = None
    try:
        # read database configuration
        #params = config()
       
        # connect to the PostgreSQL database
        conn = psycopg2.connect(database='kobo', user='postgres', password='password', host='localhost')
        # create a new cursor
        cur = conn.cursor()
        # execute the INSERT statement
        cur.execute(sql, (name,))
        # get the generated id back
        vendor_id = cur.fetchone()[0]
        # commit the changes to the database
        conn.commit()
        # close communication with the database
        cur.close()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
 
    return vendor_id

# %%
insert("3M Co.")

# %%
def insert_list(name_list):
    """ insert multiple vendors into the vendors table  """
    sql = "INSERT INTO demographics(name) VALUES(%s)"
    conn = None
    try:
        # read database configuration
        
        # connect to the PostgreSQL database
        #conn = psycopg2.connect(**params)
        conn = psycopg2.connect(database='kobo', user='postgres', password='password', host='localhost')
        
        # create a new cursor
        cur = conn.cursor()
        # execute the INSERT statement
        cur.executemany(sql,name_list)
        # commit the changes to the database
        conn.commit()
        # close communication with the database
        cur.close()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()

# %%
insert_list([
        ('AKM Semiconductor Inc.',),
        ('Asahi Glass Co Ltd.',),
        ('Daikin Industries Ltd.',),
        ('Dynacast International Inc.',),
        ('Foster Electric Co. Ltd.',),
        ('Murata Manufacturing Co. Ltd.',)
    ])

# %%
def insert_lists(name_list):
    """ insert multiple vendors into the vendors table  """
    sql = 'INSERT INTO demographics(' \
          ' "demographics.address.barangay", ' \
          ' "demographics.address.country") ' \
          'VALUES(%s, %s);'
    conn = None
    try:
        # read database configuration
        
        # connect to the PostgreSQL database
        #conn = psycopg2.connect(**params)
        conn = psycopg2.connect(database='kobo', user='postgres', password='password', host='localhost')
        
        # create a new cursor
        cur = conn.cursor()
        # execute the INSERT statement
        cur.executemany(sql,name_list)
        # commit the changes to the database
        conn.commit()
        # close communication with the database
        cur.close()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()

# %%
insert_lists([
        ('AKM Semiconductor Inc.', 'PH',),
        ('Asahi Glass Co Ltd.','PH',),
        ('Daikin Industries Ltd.','PH',),
        ('Dynacast International Inc.','PH',),
        ('Foster Electric Co. Ltd.','PH',),
        ('Murata Manufacturing Co. Ltd.','PH',)
    ])

# %% [markdown]
# ## TODO: Map awhcurisdb.json to insert_list

# %%
test_data = awhcuris.loc[26]
test_df = pd.DataFrame(test_data)
type(test_df)
# Out:
# pandas.core.frame.DataFrame

# %%
engine = create_engine('postgresql://postgres:password@localhost:5432/kobo')

col_names =  ['Cuartero', 'PH']
index_names = ['demographics.address.barangay', 'demographics.address.country']
test_df = pd.DataFrame(col_names,index_names)
test_df

# %%
engine = create_engine('postgresql://postgres:password@localhost:5432/kobo')

foo_df = awhcuris.head(2)

#foo_df.to_sql('test_to_sql',con=engine, if_exists='append', chunksize=1000)

for fi in foo_df.itertuples(name='x', index=True):
    print(fi[0])
    print(fi)
    
    bar = pd.DataFrame()
   
    print('--------')
    #row.to_sql('test_to_sql',con=engine, if_exists='append', chunksize=1000)

#get_ipython().magic(u"timeit awhcuris.to_sql(con=engine, name='test_to_sql', if_exists='replace', index=False)")
#pandas.core.frame.DataFrame
# Out:
# 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-3a8eba57be5d> in <module>()
#       7 for fi in foo_df.itertuples(name='x', index=True):
#       8     print(fi[0])
# ----> 9     print(fi.x)
#      10
#      11     bar = pd.DataFrame()
#
# AttributeError: 'x' object has no attribute 'x'

# %%
#from postPass import loginDict
#dw = 'postgresql://...'
#dw = create_engine(dw)


#df = pd.DataFrame()
#dfLen = 10000
#dfCols = 10
#for x in range(0, dfCols):
#    colName = 'a' + str(x)
#    df[colName] = [random.randint(0, 99) for x in range(1,dfLen)]
def cleanColumns(columns):
    cols = []
    for col in columns:
        col = col.replace(' ', '_')
        cols.append(col)
    return cols

def to_pg(df, table_name, con):
    data = io.StringIO()
    df.columns = cleanColumns(df.columns)
    #df.to_csv('data.tab.txt', sep='|', header=False, index=False)
    df.to_csv(data, sep='|', header=False, index=False)
    data.getvalue()
    data.seek(0)
    
    #conn = psycopg2.connect(database='kobo', user='postgres', password='password', host='localhost')
    #curs = conn.cursor()
    #curs.execute(sql, (name,))
        
    raw = con.raw_connection()
    curs = raw.cursor()
    curs.execute("DROP TABLE " + table_name)
    empty_table = pd.io.sql.get_schema(df, table_name, con = con)
    #empty_table = empty_table.replace('"', '')
    curs.execute(empty_table)
    curs.copy_from(data, table_name, sep = '|', null="")
    curs.connection.commit()

dw = create_engine('postgresql://postgres:password@localhost:5432/kobo')
#df = awhcuris.head(3)

df = awhcuris.fillna(np.nan).replace('\n', '',regex=True)
get_ipython().magic(u"timeit to_pg(df, 'test_to_pg', dw)")

#get_ipython().magic(u"timeit df.to_sql(con=dw, name='test_to_sql', if_exists='replace', index=False)")
# Out:
# 2.05 s ± 362 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
to_pg(awhcuris.head(1),'test3')
#awhcuris

# %%
data = io.StringIO()
df.columns = cleanColumns(df.columns)
df.to_csv(data, header=False, index=False)
df.T
# Out:
#                                                                                       0
# address.barangay                                                          burgos gengos
# address.country                                                             Philippines
# address.email_address                                                               NaN
# address.lot_or_house_number
# address.postal_code                                                                5022
# address.province                                                                 iloilo
# child_healths                                                                       NaN
# date_visits                                                                         NaN
# email_address                                                                      None
# family_members                        [9c4de471-a33a-4bfa-899c-3fd63613042e, e8fc744...
# family_planning_and_maternal_healths                                                NaN
# family_planning_male                                                                NaN
# health_informations                                                                  []
# households                                                                           []
# id                                                 0004d599-f8c8-46c4-9476-b51debae7271
# identification.id1.identifier                                                      None
# identification.id1.type                                                             4Ps
# identification.id2.identifier                                                      None
# identification.id2.type                                                             4Ps
# identification.id3.identifier                                                      None
# identification.id3.type                                                             4Ps
# organization                                                                Guimbal RHU
# profile_picture.name                               6e74d789-00f3-4800-8528-ab22cbea7ba4
# profile_picture.path                  /data/data/com.awh.health.curis/app_images/ima...
# profiles                                                                             []
# registered_at                                       05/17/2018 at 09:23:07 am GMT+08:00
# symptoms_collection                                                                 NaN
# type                                                                      user-resident
# user_cam.id                                                     burgos-gengos@gmail.com
# user_cam.owner                                                  burgos-gengos@gmail.com

# %%
#conn = create_engine('postgresql://postgres:password@localhost:5432/kobo')
conn = psycopg2.connect(database='kobo', user='postgres', password='password', host='localhost')
table_name = 'test3'
table = pd.io.sql.get_schema(df, table_name, con = conn)
#table = table.replace('"', '')
print(table)

curs = conn.cursor()
curs.execute("DROP TABLE " + table_name)
curs.execute(table)
