# %%
import numpy as np
import pandas as pd
import json
from pandas.io.json import json_normalize 
from pandas import read_csv
import logging
from functools import reduce
import csv

# %% [markdown]
# ## Configuration

# %%
#etl = 'kobo2elastic'
etl = 'curis2elastic'
#etl = 'oldcuris2newcuris'

input_schema_file = ''
input_data_file = ''
mapping_file = ''
    
if etl == 'curis2elastic':
    #old curis to elasticsearch
    input_schema_file = 'schema/input/curisSchema.1-item.json'
    input_data_file = 'data/curisData.1-items.json'
    mapping_file = 'schema/map/couchbase2elastic.map.csv'
elif etl == 'kobo2elastic':
    #kobo to elasticsearch
    input_schema_file = 'schema/input/aqmSchema.complete.json'
    input_data_file = 'data/aqmData.2-items.json'
    mapping_file = 'schema/map/kobo2elastic.map.csv'
elif etl == 'oldcuris2newcuris':
    #kobo to elasticsearch
    input_schema_file = 'schema/input/curisData.1-Schema.avro.json'
    input_data_file = 'data/curisData.1-items.json'
    mapping_file = 'schema/map/kobo2elastic.map.csv'

# %%
def flatten_json(nested_json):
    """
        Flatten json object with nested keys into a single level.
        Args:
            nested_json: A nested json object.
        Returns:
            The flattened json object if successful, None otherwise.
    """
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '.')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + '[' + str(i) + '].')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(nested_json)
    return out

# %%
def flattenDict(d, result=None):
    if result is None:
        result = {}
    for key in d:
        value = d[key]
        if isinstance(value, str):
            if "\n" in value:
                print('----------------',value) 
                value = value.replace("\n", ' and ')
                print('----------------',value) 

        if isinstance(value, dict):
        #if d['type'] =='object':
            value1 = {}
            for keyIn in value:
                value1[".".join([key,keyIn])]=value[keyIn]
            flattenDict(value1, result)
        elif isinstance(value, (list, tuple)):   
            for indexB, element in enumerate(value):
                if isinstance(element, dict):
                    value1 = {}
                    index = 0
                    for keyIn in element:
                        newkey = ".".join([key,keyIn])        
                        value1[".".join([key,keyIn])]=value[indexB][keyIn]
                        index += 1
                    for keyA in value1:
                        flattenDict(value1, result)   
        else:
            result[key]=value
    return result

# %% [markdown]
# ## Get input JSON SChema

# %%
d = {}
with open(input_schema_file) as f:
    d = json.load(f)

#d['items']['fields']
schema_df = pd.DataFrame()
schema_df = json_normalize(d)
schema_df.T
# Out:
#                                                                                                     0
# $id                                                                      http://example.com/root.json
# $schema                                                       http://json-schema.org/draft-07/schema#
# properties.address.$id                                                           #/properties/address
# properties.address.items.$id                                               #/properties/address/items
# properties.address.items.properties.barangay.$id       #/properties/address/items/properties/barangay
# properties.address.items.properties.barangay.pa...                                             ^(.*)$
# properties.address.items.properties.barangay.title                                The Barangay Schema
# properties.address.items.properties.barangay.type                                              string
# properties.address.items.properties.country.$id         #/properties/address/items/properties/country
# properties.address.items.properties.country.pat...                                             ^(.*)$
# properties.address.items.properties.country.title                                  The Country Schema
# properties.address.items.properties.country.type                                               string
# properties.address.items.properties.fax_number.$id   #/properties/address/items/properties/fax_number
# properties.address.items.properties.fax_number....  #/properties/address/items/properties/fax_numb...
# properties.address.items.properties.fax_number....  #/properties/address/items/properties/fax_numb...
# properties.address.items.properties.fax_number....                                             ^(.*)$
# properties.address.items.properties.fax_number....                            The Country_code Schema
# properties.address.items.properties.fax_number....                                             string
# properties.address.items.properties.fax_number....  #/properties/address/items/properties/fax_numb...
# properties.address.items.properties.fax_number....                                             ^(.*)$
# properties.address.items.properties.fax_number....                                  The Number Schema
# properties.address.items.properties.fax_number....                                             string
# properties.address.items.properties.fax_number....                                   The Items Schema
# properties.address.items.properties.fax_number....                                             object
# properties.address.items.properties.fax_number....                              The Fax_number Schema
# properties.address.items.properties.fax_number....                                              array
# properties.address.items.properties.landline_nu...  #/properties/address/items/properties/landline...
# properties.address.items.properties.landline_nu...  #/properties/address/items/properties/landline...
# properties.address.items.properties.landline_nu...  #/properties/address/items/properties/landline...
# properties.address.items.properties.landline_nu...                                             ^(.*)$
# ...                                                                                               ...
# properties.profiles.items.properties.employment...                                             object
# properties.profiles.items.properties.religion.$id     #/properties/profiles/items/properties/religion
# properties.profiles.items.properties.religion.p...                                             ^(.*)$
# properties.profiles.items.properties.religion.t...                                The Religion Schema
# properties.profiles.items.properties.religion.type                                             string
# properties.profiles.items.title                                                      The Items Schema
# properties.profiles.items.type                                                                 object
# properties.profiles.title                                                         The Profiles Schema
# properties.profiles.type                                                                        array
# properties.registered_at.$id                                               #/properties/registered_at
# properties.registered_at.pattern                                                               ^(.*)$
# properties.registered_at.title                                               The Registered_at Schema
# properties.registered_at.type                                                                  string
# properties.type.$id                                                                 #/properties/type
# properties.type.pattern                                                                        ^(.*)$
# properties.type.title                                                                 The Type Schema
# properties.type.type                                                                           string
# properties.user-cam.$id                                                         #/properties/user-cam
# properties.user-cam.properties.id.$id                             #/properties/user-cam/properties/id
# properties.user-cam.properties.id.pattern                                                      ^(.*)$
# properties.user-cam.properties.id.title                                                 The Id Schema
# properties.user-cam.properties.id.type                                                         string
# properties.user-cam.properties.owner.$id                       #/properties/user-cam/properties/owner
# properties.user-cam.properties.owner.pattern                                                   ^(.*)$
# properties.user-cam.properties.owner.title                                           The Owner Schema
# properties.user-cam.properties.owner.type                                                      string
# properties.user-cam.title                                                         The User-cam Schema
# properties.user-cam.type                                                                       object
# title                                                                                 The Root Schema
# type                                                                                           object
#
# [371 rows x 1 columns]

# %%
#flattenDict(d)
flatten_json(d)
# Out:
# {'$schema': 'http://json-schema.org/draft-07/schema#',
#  '$id': 'http://example.com/root.json',
#  'type': 'object',
#  'title': 'The Root Schema',
#  'properties.id.$id': '#/properties/id',
#  'properties.id.type': 'string',
#  'properties.id.title': 'The Id Schema',
#  'properties.id.pattern': '^(.*)$',
#  'properties.address.$id': '#/properties/address',
#  'properties.address.type': 'array',
#  'properties.address.title': 'The Address Schema',
#  'properties.address.items.$id': '#/properties/address/items',
#  'properties.address.items.type': 'object',
#  'properties.address.items.title': 'The Items Schema',
#  'properties.address.items.properties.barangay.$id': '#/properties/address/items/properties/barangay',
#  'properties.address.items.properties.barangay.type': 'string',
#  'properties.address.items.properties.barangay.title': 'The Barangay Schema',
#  'properties.address.items.properties.barangay.pattern': '^(.*)$',
#  'properties.address.items.properties.country.$id': '#/properties/address/items/properties/country',
#  'properties.address.items.properties.country.type': 'string',
#  'properties.address.items.properties.country.title': 'The Country Schema',
#  'properties.address.items.properties.country.pattern': '^(.*)$',
#  'properties.address.items.properties.lot_or_house_number.$id': '#/properties/address/items/properties/lot_or_house_number',
#  'properties.address.items.properties.lot_or_house_number.type': 'string',
#  'properties.address.items.properties.lot_or_house_number.title': 'The Lot_or_house_number Schema',
#  'properties.address.items.properties.lot_or_house_number.pattern': '^(.*)$',
#  'properties.address.items.properties.postal_code.$id': '#/properties/address/items/properties/postal_code',
#  'properties.address.items.properties.postal_code.type': 'string',
#  'properties.address.items.properties.postal_code.title': 'The Postal_code Schema',
#  'properties.address.items.properties.postal_code.pattern': '^(.*)$',
#  'properties.address.items.properties.province.$id': '#/properties/address/items/properties/province',
#  'properties.address.items.properties.province.type': 'string',
#  'properties.address.items.properties.province.title': 'The Province Schema',
#  'properties.address.items.properties.province.pattern': '^(.*)$',
#  'properties.address.items.properties.fax_number.$id': '#/properties/address/items/properties/fax_number',
#  'properties.address.items.properties.fax_number.type': 'array',
#  'properties.address.items.properties.fax_number.title': 'The Fax_number Schema',
#  'properties.address.items.properties.fax_number.items.$id': '#/properties/address/items/properties/fax_number/items',
#  'properties.address.items.properties.fax_number.items.type': 'object',
#  'properties.address.items.properties.fax_number.items.title': 'The Items Schema',
#  'properties.address.items.properties.fax_number.items.properties.country_code.$id': '#/properties/address/items/properties/fax_number/items/properties/country_code',
#  'properties.address.items.properties.fax_number.items.properties.country_code.type': 'string',
#  'properties.address.items.properties.fax_number.items.properties.country_code.title': 'The Country_code Schema',
#  'properties.address.items.properties.fax_number.items.properties.country_code.pattern': '^(.*)$',
#  'properties.address.items.properties.fax_number.items.properties.number.$id': '#/properties/address/items/properties/fax_number/items/properties/number',
#  'properties.address.items.properties.fax_number.items.properties.number.type': 'string',
#  'properties.address.items.properties.fax_number.items.properties.number.title': 'The Number Schema',
#  'properties.address.items.properties.fax_number.items.properties.number.pattern': '^(.*)$',
#  'properties.address.items.properties.mobile_number.$id': '#/properties/address/items/properties/mobile_number',
#  'properties.address.items.properties.mobile_number.type': 'array',
#  'properties.address.items.properties.mobile_number.title': 'The Mobile_number Schema',
#  'properties.address.items.properties.mobile_number.items.$id': '#/properties/address/items/properties/mobile_number/items',
#  'properties.address.items.properties.mobile_number.items.type': 'object',
#  'properties.address.items.properties.mobile_number.items.title': 'The Items Schema',
#  'properties.address.items.properties.mobile_number.items.properties.country_code.$id': '#/properties/address/items/properties/mobile_number/items/properties/country_code',
#  'properties.address.items.properties.mobile_number.items.properties.country_code.type': 'string',
#  'properties.address.items.properties.mobile_number.items.properties.country_code.title': 'The Country_code Schema',
#  'properties.address.items.properties.mobile_number.items.properties.country_code.pattern': '^(.*)$',
#  'properties.address.items.properties.mobile_number.items.properties.number.$id': '#/properties/address/items/properties/mobile_number/items/properties/number',
#  'properties.address.items.properties.mobile_number.items.properties.number.type': 'string',
#  'properties.address.items.properties.mobile_number.items.properties.number.title': 'The Number Schema',
#  'properties.address.items.properties.mobile_number.items.properties.number.pattern': '^(.*)$',
#  'properties.address.items.properties.landline_number.$id': '#/properties/address/items/properties/landline_number',
#  'properties.address.items.properties.landline_number.type': 'array',
#  'properties.address.items.properties.landline_number.title': 'The Landline_number Schema',
#  'properties.address.items.properties.landline_number.items.$id': '#/properties/address/items/properties/landline_number/items',
#  'properties.address.items.properties.landline_number.items.type': 'object',
#  'properties.address.items.properties.landline_number.items.title': 'The Items Schema',
#  'properties.address.items.properties.landline_number.items.properties.country_code.$id': '#/properties/address/items/properties/landline_number/items/properties/country_code',
#  'properties.address.items.properties.landline_number.items.properties.country_code.type': 'string',
#  'properties.address.items.properties.landline_number.items.properties.country_code.title': 'The Country_code Schema',
#  'properties.address.items.properties.landline_number.items.properties.country_code.pattern': '^(.*)$',
#  'properties.address.items.properties.landline_number.items.properties.number.$id': '#/properties/address/items/properties/landline_number/items/properties/number',
#  'properties.address.items.properties.landline_number.items.properties.number.type': 'string',
#  'properties.address.items.properties.landline_number.items.properties.number.title': 'The Number Schema',
#  'properties.address.items.properties.landline_number.items.properties.number.pattern': '^(.*)$',
#  'properties.birthdate.$id': '#/properties/birthdate',
#  'properties.birthdate.type': 'string',
#  'properties.birthdate.title': 'The Birthdate Schema',
#  'properties.birthdate.pattern': '^(.*)$',
#  'properties.email_address.$id': '#/properties/email_address',
#  'properties.email_address.type': 'null',
#  'properties.email_address.title': 'The Email_address Schema',
#  'properties.family_members.$id': '#/properties/family_members',
#  'properties.family_members.type': 'array',
#  'properties.family_members.title': 'The Family_members Schema',
#  'properties.family_members.items.$id': '#/properties/family_members/items',
#  'properties.family_members.items.type': 'string',
#  'properties.family_members.items.title': 'The Items Schema',
#  'properties.family_members.items.pattern': '^(.*)$',
#  'properties.first_name.$id': '#/properties/first_name',
#  'properties.first_name.type': 'string',
#  'properties.first_name.title': 'The First_name Schema',
#  'properties.first_name.pattern': '^(.*)$',
#  'properties.gender.$id': '#/properties/gender',
#  'properties.gender.type': 'string',
#  'properties.gender.title': 'The Gender Schema',
#  'properties.gender.pattern': '^(.*)$',
#  'properties.health_informations.$id': '#/properties/health_informations',
#  'properties.health_informations.type': 'array',
#  'properties.health_informations.title': 'The Health_informations Schema',
#  'properties.health_informations.items.$id': '#/properties/health_informations/items',
#  'properties.health_informations.items.type': 'object',
#  'properties.health_informations.items.title': 'The Items Schema',
#  'properties.health_informations.items.properties.allergies.$id': '#/properties/health_informations/items/properties/allergies',
#  'properties.health_informations.items.properties.allergies.type': 'string',
#  'properties.health_informations.items.properties.allergies.title': 'The Allergies Schema',
#  'properties.health_informations.items.properties.allergies.pattern': '^(.*)$',
#  'properties.health_informations.items.properties.blood_pressure.$id': '#/properties/health_informations/items/properties/blood_pressure',
#  'properties.health_informations.items.properties.blood_pressure.type': 'object',
#  'properties.health_informations.items.properties.blood_pressure.title': 'The Blood_pressure Schema',
#  'properties.health_informations.items.properties.blood_pressure.properties.first_reading.$id': '#/properties/health_informations/items/properties/blood_pressure/properties/first_reading',
#  'properties.health_informations.items.properties.blood_pressure.properties.first_reading.type': 'object',
#  'properties.health_informations.items.properties.blood_pressure.properties.first_reading.title': 'The First_reading Schema',
#  'properties.health_informations.items.properties.blood_pressure.properties.first_reading.properties.diastole.$id': '#/properties/health_informations/items/properties/blood_pressure/properties/first_reading/properties/diastole',
#  'properties.health_informations.items.properties.blood_pressure.properties.first_reading.properties.diastole.type': 'string',
#  'properties.health_informations.items.properties.blood_pressure.properties.first_reading.properties.diastole.title': 'The Diastole Schema',
#  'properties.health_informations.items.properties.blood_pressure.properties.first_reading.properties.diastole.pattern': '^(.*)$',
#  'properties.health_informations.items.properties.blood_pressure.properties.first_reading.properties.systole.$id': '#/properties/health_informations/items/properties/blood_pressure/properties/first_reading/properties/systole',
#  'properties.health_informations.items.properties.blood_pressure.properties.first_reading.properties.systole.type': 'string',
#  'properties.health_informations.items.properties.blood_pressure.properties.first_reading.properties.systole.title': 'The Systole Schema',
#  'properties.health_informations.items.properties.blood_pressure.properties.first_reading.properties.systole.pattern': '^(.*)$',
#  'properties.health_informations.items.properties.blood_pressure.properties.second_reading.$id': '#/properties/health_informations/items/properties/blood_pressure/properties/second_reading',
#  'properties.health_informations.items.properties.blood_pressure.properties.second_reading.type': 'object',
#  'properties.health_informations.items.properties.blood_pressure.properties.second_reading.title': 'The Second_reading Schema',
#  'properties.health_informations.items.properties.blood_pressure.properties.second_reading.properties.diastole.$id': '#/properties/health_informations/items/properties/blood_pressure/properties/second_reading/properties/diastole',
#  'properties.health_informations.items.properties.blood_pressure.properties.second_reading.properties.diastole.type': 'string',
#  'properties.health_informations.items.properties.blood_pressure.properties.second_reading.properties.diastole.title': 'The Diastole Schema',
#  'properties.health_informations.items.properties.blood_pressure.properties.second_reading.properties.diastole.pattern': '^(.*)$',
#  'properties.health_informations.items.properties.blood_pressure.properties.second_reading.properties.systole.$id': '#/properties/health_informations/items/properties/blood_pressure/properties/second_reading/properties/systole',
#  'properties.health_informations.items.properties.blood_pressure.properties.second_reading.properties.systole.type': 'string',
#  'properties.health_informations.items.properties.blood_pressure.properties.second_reading.properties.systole.title': 'The Systole Schema',
#  'properties.health_informations.items.properties.blood_pressure.properties.second_reading.properties.systole.pattern': '^(.*)$',
#  'properties.health_informations.items.properties.blood_pressure.properties.third_reading.$id': '#/properties/health_informations/items/properties/blood_pressure/properties/third_reading',
#  'properties.health_informations.items.properties.blood_pressure.properties.third_reading.type': 'object',
#  'properties.health_informations.items.properties.blood_pressure.properties.third_reading.title': 'The Third_reading Schema',
#  'properties.health_informations.items.properties.blood_pressure.properties.third_reading.properties.diastole.$id': '#/properties/health_informations/items/properties/blood_pressure/properties/third_reading/properties/diastole',
#  'properties.health_informations.items.properties.blood_pressure.properties.third_reading.properties.diastole.type': 'string',
#  'properties.health_informations.items.properties.blood_pressure.properties.third_reading.properties.diastole.title': 'The Diastole Schema',
#  'properties.health_informations.items.properties.blood_pressure.properties.third_reading.properties.diastole.pattern': '^(.*)$',
#  'properties.health_informations.items.properties.blood_pressure.properties.third_reading.properties.systole.$id': '#/properties/health_informations/items/properties/blood_pressure/properties/third_reading/properties/systole',
#  'properties.health_informations.items.properties.blood_pressure.properties.third_reading.properties.systole.type': 'string',
#  'properties.health_informations.items.properties.blood_pressure.properties.third_reading.properties.systole.title': 'The Systole Schema',
#  'properties.health_informations.items.properties.blood_pressure.properties.third_reading.properties.systole.pattern': '^(.*)$',
#  'properties.health_informations.items.properties.blood_sign.$id': '#/properties/health_informations/items/properties/blood_sign',
#  'properties.health_informations.items.properties.blood_sign.type': 'string',
#  'properties.health_informations.items.properties.blood_sign.title': 'The Blood_sign Schema',
#  'properties.health_informations.items.properties.blood_sign.pattern': '^(.*)$',
#  'properties.health_informations.items.properties.blood_sugar.$id': '#/properties/health_informations/items/properties/blood_sugar',
#  'properties.health_informations.items.properties.blood_sugar.type': 'integer',
#  'properties.health_informations.items.properties.blood_sugar.title': 'The Blood_sugar Schema',
#  'properties.health_informations.items.properties.blood_type.$id': '#/properties/health_informations/items/properties/blood_type',
#  'properties.health_informations.items.properties.blood_type.type': 'string',
#  'properties.health_informations.items.properties.blood_type.title': 'The Blood_type Schema',
#  'properties.health_informations.items.properties.blood_type.pattern': '^(.*)$',
#  'properties.health_informations.items.properties.date_updated.$id': '#/properties/health_informations/items/properties/date_updated',
#  'properties.health_informations.items.properties.date_updated.type': 'string',
#  'properties.health_informations.items.properties.date_updated.title': 'The Date_updated Schema',
#  'properties.health_informations.items.properties.date_updated.pattern': '^(.*)$',
#  'properties.health_informations.items.properties.diagnosed.$id': '#/properties/health_informations/items/properties/diagnosed',
#  'properties.health_informations.items.properties.diagnosed.type': 'array',
#  'properties.health_informations.items.properties.diagnosed.title': 'The Diagnosed Schema',
#  'properties.health_informations.items.properties.diagnosed.items.$id': '#/properties/health_informations/items/properties/diagnosed/items',
#  'properties.health_informations.items.properties.diagnosed.items.type': 'string',
#  'properties.health_informations.items.properties.diagnosed.items.title': 'The Items Schema',
#  'properties.health_informations.items.properties.diagnosed.items.pattern': '^(.*)$',
#  'properties.health_informations.items.properties.exercise_in_a_week.$id': '#/properties/health_informations/items/properties/exercise_in_a_week',
#  'properties.health_informations.items.properties.exercise_in_a_week.type': 'string',
#  'properties.health_informations.items.properties.exercise_in_a_week.title': 'The Exercise_in_a_week Schema',
#  'properties.health_informations.items.properties.exercise_in_a_week.pattern': '^(.*)$',
#  'properties.health_informations.items.properties.family_history.$id': '#/properties/health_informations/items/properties/family_history',
#  'properties.health_informations.items.properties.family_history.type': 'array',
#  'properties.health_informations.items.properties.family_history.title': 'The Family_history Schema',
#  'properties.health_informations.items.properties.family_history.items.$id': '#/properties/health_informations/items/properties/family_history/items',
#  'properties.health_informations.items.properties.family_history.items.type': 'string',
#  'properties.health_informations.items.properties.family_history.items.title': 'The Items Schema',
#  'properties.health_informations.items.properties.family_history.items.pattern': '^(.*)$',
#  'properties.health_informations.items.properties.fruits_in_a_week.$id': '#/properties/health_informations/items/properties/fruits_in_a_week',
#  'properties.health_informations.items.properties.fruits_in_a_week.type': 'string',
#  'properties.health_informations.items.properties.fruits_in_a_week.title': 'The Fruits_in_a_week Schema',
#  'properties.health_informations.items.properties.fruits_in_a_week.pattern': '^(.*)$',
#  'properties.health_informations.items.properties.height.$id': '#/properties/health_informations/items/properties/height',
#  'properties.health_informations.items.properties.height.type': 'integer',
#  'properties.health_informations.items.properties.height.title': 'The Height Schema',
#  'properties.health_informations.items.properties.high_cost_medicine.$id': '#/properties/health_informations/items/properties/high_cost_medicine',
#  'properties.health_informations.items.properties.high_cost_medicine.type': 'string',
#  'properties.health_informations.items.properties.high_cost_medicine.title': 'The High_cost_medicine Schema',
#  'properties.health_informations.items.properties.high_cost_medicine.pattern': '^(.*)$',
#  'properties.health_informations.items.properties.maintenance_drugs.$id': '#/properties/health_informations/items/properties/maintenance_drugs',
#  'properties.health_informations.items.properties.maintenance_drugs.type': 'string',
#  'properties.health_informations.items.properties.maintenance_drugs.title': 'The Maintenance_drugs Schema',
#  'properties.health_informations.items.properties.maintenance_drugs.pattern': '^(.*)$',
#  'properties.health_informations.items.properties.smoking_habit.$id': '#/properties/health_informations/items/properties/smoking_habit',
#  'properties.health_informations.items.properties.smoking_habit.type': 'string',
#  'properties.health_informations.items.properties.smoking_habit.title': 'The Smoking_habit Schema',
#  'properties.health_informations.items.properties.smoking_habit.pattern': '^(.*)$',
#  'properties.health_informations.items.properties.vegetables_in_a_week.$id': '#/properties/health_informations/items/properties/vegetables_in_a_week',
#  'properties.health_informations.items.properties.vegetables_in_a_week.type': 'string',
#  'properties.health_informations.items.properties.vegetables_in_a_week.title': 'The Vegetables_in_a_week Schema',
#  'properties.health_informations.items.properties.vegetables_in_a_week.pattern': '^(.*)$',
#  'properties.health_informations.items.properties.waist_circumference.$id': '#/properties/health_informations/items/properties/waist_circumference',
#  'properties.health_informations.items.properties.waist_circumference.type': 'integer',
#  'properties.health_informations.items.properties.waist_circumference.title': 'The Waist_circumference Schema',
#  'properties.health_informations.items.properties.weight.$id': '#/properties/health_informations/items/properties/weight',
#  'properties.health_informations.items.properties.weight.type': 'integer',
#  'properties.health_informations.items.properties.weight.title': 'The Weight Schema',
#  'properties.households.$id': '#/properties/households',
#  'properties.households.type': 'array',
#  'properties.households.title': 'The Households Schema',
#  'properties.households.items.$id': '#/properties/households/items',
#  'properties.households.items.type': 'object',
#  'properties.households.items.title': 'The Items Schema',
#  'properties.households.items.properties.amenities_present_in_house.$id': '#/properties/households/items/properties/amenities_present_in_house',
#  'properties.households.items.properties.amenities_present_in_house.type': 'array',
#  'properties.households.items.properties.amenities_present_in_house.title': 'The Amenities_present_in_house Schema',
#  'properties.households.items.properties.amenities_present_in_house.items.$id': '#/properties/households/items/properties/amenities_present_in_house/items',
#  'properties.households.items.properties.amenities_present_in_house.items.type': 'string',
#  'properties.households.items.properties.amenities_present_in_house.items.title': 'The Items Schema',
#  'properties.households.items.properties.amenities_present_in_house.items.pattern': '^(.*)$',
#  'properties.households.items.properties.date_updated.$id': '#/properties/households/items/properties/date_updated',
#  'properties.households.items.properties.date_updated.type': 'string',
#  'properties.households.items.properties.date_updated.title': 'The Date_updated Schema',
#  'properties.households.items.properties.date_updated.pattern': '^(.*)$',
#  'properties.households.items.properties.house_ownership.$id': '#/properties/households/items/properties/house_ownership',
#  'properties.households.items.properties.house_ownership.type': 'string',
#  'properties.households.items.properties.house_ownership.title': 'The House_ownership Schema',
#  'properties.households.items.properties.house_ownership.pattern': '^(.*)$',
#  'properties.households.items.properties.neighborhood_description.$id': '#/properties/households/items/properties/neighborhood_description',
#  'properties.households.items.properties.neighborhood_description.type': 'string',
#  'properties.households.items.properties.neighborhood_description.title': 'The Neighborhood_description Schema',
#  'properties.households.items.properties.neighborhood_description.pattern': '^(.*)$',
#  'properties.households.items.properties.no_of_families_in_the_household.$id': '#/properties/households/items/properties/no_of_families_in_the_household',
#  'properties.households.items.properties.no_of_families_in_the_household.type': 'integer',
#  'properties.households.items.properties.no_of_families_in_the_household.title': 'The No_of_families_in_the_household Schema',
#  'properties.households.items.properties.no_of_people_in_the_household.$id': '#/properties/households/items/properties/no_of_people_in_the_household',
#  'properties.households.items.properties.no_of_people_in_the_household.type': 'integer',
#  'properties.households.items.properties.no_of_people_in_the_household.title': 'The No_of_people_in_the_household Schema',
#  'properties.households.items.properties.sanitary_ownership.$id': '#/properties/households/items/properties/sanitary_ownership',
#  'properties.households.items.properties.sanitary_ownership.type': 'string',
#  'properties.households.items.properties.sanitary_ownership.title': 'The Sanitary_ownership Schema',
#  'properties.households.items.properties.sanitary_ownership.pattern': '^(.*)$',
#  'properties.households.items.properties.sanitary_type.$id': '#/properties/households/items/properties/sanitary_type',
#  'properties.households.items.properties.sanitary_type.type': 'array',
#  'properties.households.items.properties.sanitary_type.title': 'The Sanitary_type Schema',
#  'properties.households.items.properties.sanitary_type.items.$id': '#/properties/households/items/properties/sanitary_type/items',
#  'properties.households.items.properties.sanitary_type.items.type': 'string',
#  'properties.households.items.properties.sanitary_type.items.title': 'The Items Schema',
#  'properties.households.items.properties.sanitary_type.items.pattern': '^(.*)$',
#  'properties.households.items.properties.type_of_house.$id': '#/properties/households/items/properties/type_of_house',
#  'properties.households.items.properties.type_of_house.type': 'string',
#  'properties.households.items.properties.type_of_house.title': 'The Type_of_house Schema',
#  'properties.households.items.properties.type_of_house.pattern': '^(.*)$',
#  'properties.identification.$id': '#/properties/identification',
#  'properties.identification.type': 'object',
#  'properties.identification.title': 'The Identification Schema',
#  'properties.identification.properties.id1.$id': '#/properties/identification/properties/id1',
#  'properties.identification.properties.id1.type': 'object',
#  'properties.identification.properties.id1.title': 'The Id1 Schema',
#  'properties.identification.properties.id1.properties.identifier.$id': '#/properties/identification/properties/id1/properties/identifier',
#  'properties.identification.properties.id1.properties.identifier.type': 'null',
#  'properties.identification.properties.id1.properties.identifier.title': 'The Identifier Schema',
#  'properties.identification.properties.id1.properties.type.$id': '#/properties/identification/properties/id1/properties/type',
#  'properties.identification.properties.id1.properties.type.type': 'string',
#  'properties.identification.properties.id1.properties.type.title': 'The Type Schema',
#  'properties.identification.properties.id1.properties.type.pattern': '^(.*)$',
#  'properties.identification.properties.id2.$id': '#/properties/identification/properties/id2',
#  'properties.identification.properties.id2.type': 'object',
#  'properties.identification.properties.id2.title': 'The Id2 Schema',
#  'properties.identification.properties.id2.properties.identifier.$id': '#/properties/identification/properties/id2/properties/identifier',
#  'properties.identification.properties.id2.properties.identifier.type': 'null',
#  'properties.identification.properties.id2.properties.identifier.title': 'The Identifier Schema',
#  'properties.identification.properties.id2.properties.type.$id': '#/properties/identification/properties/id2/properties/type',
#  'properties.identification.properties.id2.properties.type.type': 'string',
#  'properties.identification.properties.id2.properties.type.title': 'The Type Schema',
#  'properties.identification.properties.id2.properties.type.pattern': '^(.*)$',
#  'properties.identification.properties.id3.$id': '#/properties/identification/properties/id3',
#  'properties.identification.properties.id3.type': 'object',
#  'properties.identification.properties.id3.title': 'The Id3 Schema',
#  'properties.identification.properties.id3.properties.identifier.$id': '#/properties/identification/properties/id3/properties/identifier',
#  'properties.identification.properties.id3.properties.identifier.type': 'null',
#  'properties.identification.properties.id3.properties.identifier.title': 'The Identifier Schema',
#  'properties.identification.properties.id3.properties.type.$id': '#/properties/identification/properties/id3/properties/type',
#  'properties.identification.properties.id3.properties.type.type': 'string',
#  'properties.identification.properties.id3.properties.type.title': 'The Type Schema',
#  'properties.identification.properties.id3.properties.type.pattern': '^(.*)$',
#  'properties.last_name.$id': '#/properties/last_name',
#  'properties.last_name.type': 'string',
#  'properties.last_name.title': 'The Last_name Schema',
#  'properties.last_name.pattern': '^(.*)$',
#  'properties.last_name_suffix.$id': '#/properties/last_name_suffix',
#  'properties.last_name_suffix.type': 'string',
#  'properties.last_name_suffix.title': 'The Last_name_suffix Schema',
#  'properties.last_name_suffix.pattern': '^(.*)$',
#  'properties.middle_name.$id': '#/properties/middle_name',
#  'properties.middle_name.type': 'string',
#  'properties.middle_name.title': 'The Middle_name Schema',
#  'properties.middle_name.pattern': '^(.*)$',
#  'properties.nhid.$id': '#/properties/nhid',
#  'properties.nhid.type': 'string',
#  'properties.nhid.title': 'The Nhid Schema',
#  'properties.nhid.pattern': '^(.*)$',
#  'properties.organization.$id': '#/properties/organization',
#  'properties.organization.type': 'string',
#  'properties.organization.title': 'The Organization Schema',
#  'properties.organization.pattern': '^(.*)$',
#  'properties.profile_picture.$id': '#/properties/profile_picture',
#  'properties.profile_picture.type': 'object',
#  'properties.profile_picture.title': 'The Profile_picture Schema',
#  'properties.profile_picture.properties.name.$id': '#/properties/profile_picture/properties/name',
#  'properties.profile_picture.properties.name.type': 'string',
#  'properties.profile_picture.properties.name.title': 'The Name Schema',
#  'properties.profile_picture.properties.name.pattern': '^(.*)$',
#  'properties.profile_picture.properties.path.$id': '#/properties/profile_picture/properties/path',
#  'properties.profile_picture.properties.path.type': 'string',
#  'properties.profile_picture.properties.path.title': 'The Path Schema',
#  'properties.profile_picture.properties.path.pattern': '^(.*)$',
#  'properties.profiles.$id': '#/properties/profiles',
#  'properties.profiles.type': 'array',
#  'properties.profiles.title': 'The Profiles Schema',
#  'properties.profiles.items.$id': '#/properties/profiles/items',
#  'properties.profiles.items.type': 'object',
#  'properties.profiles.items.title': 'The Items Schema',
#  'properties.profiles.items.properties.civil_status.$id': '#/properties/profiles/items/properties/civil_status',
#  'properties.profiles.items.properties.civil_status.type': 'string',
#  'properties.profiles.items.properties.civil_status.title': 'The Civil_status Schema',
#  'properties.profiles.items.properties.civil_status.pattern': '^(.*)$',
#  'properties.profiles.items.properties.date_updated.$id': '#/properties/profiles/items/properties/date_updated',
#  'properties.profiles.items.properties.date_updated.type': 'string',
#  'properties.profiles.items.properties.date_updated.title': 'The Date_updated Schema',
#  'properties.profiles.items.properties.date_updated.pattern': '^(.*)$',
#  'properties.profiles.items.properties.education.$id': '#/properties/profiles/items/properties/education',
#  'properties.profiles.items.properties.education.type': 'string',
#  'properties.profiles.items.properties.education.title': 'The Education Schema',
#  'properties.profiles.items.properties.education.pattern': '^(.*)$',
#  'properties.profiles.items.properties.employment.$id': '#/properties/profiles/items/properties/employment',
#  'properties.profiles.items.properties.employment.type': 'object',
#  'properties.profiles.items.properties.employment.title': 'The Employment Schema',
#  'properties.profiles.items.properties.employment.properties.is_employed.$id': '#/properties/profiles/items/properties/employment/properties/is_employed',
#  'properties.profiles.items.properties.employment.properties.is_employed.type': 'boolean',
#  'properties.profiles.items.properties.employment.properties.is_employed.title': 'The Is_employed Schema',
#  'properties.profiles.items.properties.employment.properties.monthly_income.$id': '#/properties/profiles/items/properties/employment/properties/monthly_income',
#  'properties.profiles.items.properties.employment.properties.monthly_income.type': 'string',
#  'properties.profiles.items.properties.employment.properties.monthly_income.title': 'The Monthly_income Schema',
#  'properties.profiles.items.properties.employment.properties.monthly_income.pattern': '^(.*)$',
#  'properties.profiles.items.properties.employment.properties.nature.$id': '#/properties/profiles/items/properties/employment/properties/nature',
#  'properties.profiles.items.properties.employment.properties.nature.type': 'string',
#  'properties.profiles.items.properties.employment.properties.nature.title': 'The Nature Schema',
#  'properties.profiles.items.properties.employment.properties.nature.pattern': '^(.*)$',
#  'properties.profiles.items.properties.religion.$id': '#/properties/profiles/items/properties/religion',
#  'properties.profiles.items.properties.religion.type': 'string',
#  'properties.profiles.items.properties.religion.title': 'The Religion Schema',
#  'properties.profiles.items.properties.religion.pattern': '^(.*)$',
#  'properties.registered_at.$id': '#/properties/registered_at',
#  'properties.registered_at.type': 'string',
#  'properties.registered_at.title': 'The Registered_at Schema',
#  'properties.registered_at.pattern': '^(.*)$',
#  'properties.type.$id': '#/properties/type',
#  'properties.type.type': 'string',
#  'properties.type.title': 'The Type Schema',
#  'properties.type.pattern': '^(.*)$',
#  'properties.user-cam.$id': '#/properties/user-cam',
#  'properties.user-cam.type': 'object',
#  'properties.user-cam.title': 'The User-cam Schema',
#  'properties.user-cam.properties.id.$id': '#/properties/user-cam/properties/id',
#  'properties.user-cam.properties.id.type': 'string',
#  'properties.user-cam.properties.id.title': 'The Id Schema',
#  'properties.user-cam.properties.id.pattern': '^(.*)$',
#  'properties.user-cam.properties.owner.$id': '#/properties/user-cam/properties/owner',
#  'properties.user-cam.properties.owner.type': 'string',
#  'properties.user-cam.properties.owner.title': 'The Owner Schema',
#  'properties.user-cam.properties.owner.pattern': '^(.*)$'}

# %% [markdown]
# ## Get valid index List only (for JSON Schema Only)

# %%
validIndexLists = []
for indexList in list(schema_df):
    if "._" not in indexList:
        if len(indexList.split(sep='.')) > 2:
            if indexList.split(sep='.')[-1] == 'type' or indexList.split(sep='.')[-1] == 'title':
                validIndexLists.append(indexList)

# %%
required_field_df = pd.DataFrame()
required_field_df = schema_df[validIndexLists]
required_field_df.T
# Out:
#                                                                                  0
# properties.address.items.properties.barangay.title             The Barangay Schema
# properties.address.items.properties.barangay.type                           string
# properties.address.items.properties.country.title               The Country Schema
# properties.address.items.properties.country.type                            string
# properties.address.items.properties.fax_number....         The Country_code Schema
# properties.address.items.properties.fax_number....                          string
# properties.address.items.properties.fax_number....               The Number Schema
# properties.address.items.properties.fax_number....                          string
# properties.address.items.properties.fax_number....                The Items Schema
# properties.address.items.properties.fax_number....                          object
# properties.address.items.properties.fax_number....           The Fax_number Schema
# properties.address.items.properties.fax_number....                           array
# properties.address.items.properties.landline_nu...         The Country_code Schema
# properties.address.items.properties.landline_nu...                          string
# properties.address.items.properties.landline_nu...               The Number Schema
# properties.address.items.properties.landline_nu...                          string
# properties.address.items.properties.landline_nu...                The Items Schema
# properties.address.items.properties.landline_nu...                          object
# properties.address.items.properties.landline_nu...      The Landline_number Schema
# properties.address.items.properties.landline_nu...                           array
# properties.address.items.properties.lot_or_hous...  The Lot_or_house_number Schema
# properties.address.items.properties.lot_or_hous...                          string
# properties.address.items.properties.mobile_numb...         The Country_code Schema
# properties.address.items.properties.mobile_numb...                          string
# properties.address.items.properties.mobile_numb...               The Number Schema
# properties.address.items.properties.mobile_numb...                          string
# properties.address.items.properties.mobile_numb...                The Items Schema
# properties.address.items.properties.mobile_numb...                          object
# properties.address.items.properties.mobile_numb...        The Mobile_number Schema
# properties.address.items.properties.mobile_numb...                           array
# ...                                                                            ...
# properties.profiles.items.properties.civil_stat...         The Civil_status Schema
# properties.profiles.items.properties.civil_stat...                          string
# properties.profiles.items.properties.date_updat...         The Date_updated Schema
# properties.profiles.items.properties.date_updat...                          string
# properties.profiles.items.properties.education....            The Education Schema
# properties.profiles.items.properties.education....                          string
# properties.profiles.items.properties.employment...          The Is_employed Schema
# properties.profiles.items.properties.employment...                         boolean
# properties.profiles.items.properties.employment...       The Monthly_income Schema
# properties.profiles.items.properties.employment...                          string
# properties.profiles.items.properties.employment...               The Nature Schema
# properties.profiles.items.properties.employment...                          string
# properties.profiles.items.properties.employment...           The Employment Schema
# properties.profiles.items.properties.employment...                          object
# properties.profiles.items.properties.religion.t...             The Religion Schema
# properties.profiles.items.properties.religion.type                          string
# properties.profiles.items.title                                   The Items Schema
# properties.profiles.items.type                                              object
# properties.profiles.title                                      The Profiles Schema
# properties.profiles.type                                                     array
# properties.registered_at.title                            The Registered_at Schema
# properties.registered_at.type                                               string
# properties.type.title                                              The Type Schema
# properties.type.type                                                        string
# properties.user-cam.properties.id.title                              The Id Schema
# properties.user-cam.properties.id.type                                      string
# properties.user-cam.properties.owner.title                        The Owner Schema
# properties.user-cam.properties.owner.type                                   string
# properties.user-cam.title                                      The User-cam Schema
# properties.user-cam.type                                                    object
#
# [204 rows x 1 columns]

# %% [markdown]
# ## Clean index

# %%
def clean_value(x):
    return x.lower().replace("/", ".").replace("the", "").replace("schema", "").strip()

def clean_index(x):
    return x.lower().replace("/", ".").replace("properties.", "").replace("items.", "").strip()

newSchema_df = pd.DataFrame()
newSchema_df['value'] = required_field_df.T[0].apply(clean_value)
newSchema_df.reset_index(level=0, inplace=True)
newSchema_df['index'] = newSchema_df['index'].apply(clean_index)
newSchema_df.sort_values(['index'])
newSchema_df.head(60)
# Out:
#                                                 index                value
# 0                              address.barangay.title             barangay
# 1                               address.barangay.type               string
# 2                               address.country.title              country
# 3                                address.country.type               string
# 4               address.fax_number.country_code.title         country_code
# 5                address.fax_number.country_code.type               string
# 6                     address.fax_number.number.title               number
# 7                      address.fax_number.number.type               string
# 8                            address.fax_number.title                items
# 9                             address.fax_number.type               object
# 10                           address.fax_number.title           fax_number
# 11                            address.fax_number.type                array
# 12         address.landline_number.country_code.title         country_code
# 13          address.landline_number.country_code.type               string
# 14               address.landline_number.number.title               number
# 15                address.landline_number.number.type               string
# 16                      address.landline_number.title                items
# 17                       address.landline_number.type               object
# 18                      address.landline_number.title      landline_number
# 19                       address.landline_number.type                array
# 20                  address.lot_or_house_number.title  lot_or_house_number
# 21                   address.lot_or_house_number.type               string
# 22           address.mobile_number.country_code.title         country_code
# 23            address.mobile_number.country_code.type               string
# 24                 address.mobile_number.number.title               number
# 25                  address.mobile_number.number.type               string
# 26                        address.mobile_number.title                items
# 27                         address.mobile_number.type               object
# 28                        address.mobile_number.title        mobile_number
# 29                         address.mobile_number.type                array
# 30                          address.postal_code.title          postal_code
# 31                           address.postal_code.type               string
# 32                             address.province.title             province
# 33                              address.province.type               string
# 34                                      address.title                items
# 35                                       address.type               object
# 36                                      address.title              address
# 37                                       address.type                array
# 38                                    birthdate.title            birthdate
# 39                                     birthdate.type               string
# 40                                email_address.title        email_address
# 41                                 email_address.type                 null
# 42                               family_members.title                items
# 43                                family_members.type               string
# 44                               family_members.title       family_members
# 45                                family_members.type                array
# 46                                   first_name.title           first_name
# 47                                    first_name.type               string
# 48                                       gender.title               gender
# 49                                        gender.type               string
# 50                health_informations.allergies.title            allergies
# 51                 health_informations.allergies.type               string
# 52  health_informations.blood_pressure.first_readi...             diastole
# 53  health_informations.blood_pressure.first_readi...               string
# 54  health_informations.blood_pressure.first_readi...              systole
# 55  health_informations.blood_pressure.first_readi...               string
# 56  health_informations.blood_pressure.first_readi...        first_reading
# 57  health_informations.blood_pressure.first_readi...               object
# 58  health_informations.blood_pressure.second_read...             diastole
# 59  health_informations.blood_pressure.second_read...               string

# %% [markdown]
# ## Create separate CSV files based on array types

# %%
valueSchema_df = pd.DataFrame()

number = len(newSchema_df)
index = 0
counter = 0
counter1 = 1

array_key = []
array_type = []

while (counter < number):
    array_key.append(newSchema_df.iloc[counter]['index'].replace('.title',''))
    counter += 2
        
while (counter1 < number):
    array_type.append(newSchema_df.iloc[counter1]['value'])
    counter1 += 2

valueSchema_df['source_key'] = array_key
valueSchema_df['source_type'] = array_type

valueSchema_df = valueSchema_df.sort_values(['source_key']).reset_index(drop=True)
valueSchema_df.loc[valueSchema_df['source_type'] == 'array']

csv_filename_df = pd.DataFrame()
csv_filename_df = valueSchema_df.loc[valueSchema_df['source_type'] == 'array']
#list(csv_filename_df['source_key'])
csv_filename_df = csv_filename_df.reset_index(drop=True)
csv_filename_df
# Out:
#                                source_key source_type
# 0                                 address       array
# 1                      address.fax_number       array
# 2                 address.landline_number       array
# 3                   address.mobile_number       array
# 4                          family_members       array
# 5                     health_informations       array
# 6           health_informations.diagnosed       array
# 7      health_informations.family_history       array
# 8                              households       array
# 9   households.amenities_present_in_house       array
# 10               households.sanitary_type       array
# 11                               profiles       array

# %% [markdown]
# ## Create all filenames

# %%
for i in list(csv_filename_df['source_key']):
    with open('file/' + i + '.csv', 'w'):
        pass

# %% [markdown]
# ### have default csv filename (e.g. main, resident)

# %%
with open('file/resident.csv', 'w'):
    pass

# %% [markdown]
# ## Skip all object types

# %%
csv_header_name_object_df = pd.DataFrame()
csv_header_name_object_df = valueSchema_df.loc[valueSchema_df['source_type'] == 'object']
list(csv_header_name_object_df['source_key'])
csv_header_name_object_df
# Out:
#                                            source_key source_type
# 1                                             address      object
# 4                                  address.fax_number      object
# 8                             address.landline_number      object
# 13                              address.mobile_number      object
# 25                                health_informations      object
# 28                 health_informations.blood_pressure      object
# 29   health_informations.blood_pressure.first_reading      object
# 32  health_informations.blood_pressure.second_reading      object
# 35   health_informations.blood_pressure.third_reading      object
# 56                                         households      object
# 69                                     identification      object
# 70                                 identification.id1      object
# 73                                 identification.id2      object
# 76                                 identification.id3      object
# 84                                    profile_picture      object
# 88                                           profiles      object
# 92                                profiles.employment      object
# 99                                           user-cam      object

# %%
csv_header_name_df = pd.DataFrame()
csv_header_name_df = valueSchema_df.loc[valueSchema_df['source_type'] == 'string']
csv_header_name_df
# Out:
#                                             source_key source_type
# 2                                     address.barangay      string
# 3                                      address.country      string
# 6                      address.fax_number.country_code      string
# 7                            address.fax_number.number      string
# 10                address.landline_number.country_code      string
# 11                      address.landline_number.number      string
# 12                         address.lot_or_house_number      string
# 15                  address.mobile_number.country_code      string
# 16                        address.mobile_number.number      string
# 17                                 address.postal_code      string
# 18                                    address.province      string
# 19                                           birthdate      string
# 21                                      family_members      string
# 23                                          first_name      string
# 24                                              gender      string
# 27                       health_informations.allergies      string
# 30   health_informations.blood_pressure.first_readi...      string
# 31   health_informations.blood_pressure.first_readi...      string
# 33   health_informations.blood_pressure.second_read...      string
# 34   health_informations.blood_pressure.second_read...      string
# 36   health_informations.blood_pressure.third_readi...      string
# 37   health_informations.blood_pressure.third_readi...      string
# 38                      health_informations.blood_sign      string
# 40                      health_informations.blood_type      string
# 41                    health_informations.date_updated      string
# 42                       health_informations.diagnosed      string
# 44              health_informations.exercise_in_a_week      string
# 45                  health_informations.family_history      string
# 47                health_informations.fruits_in_a_week      string
# 49              health_informations.high_cost_medicine      string
# ..                                                 ...         ...
# 51                   health_informations.smoking_habit      string
# 52            health_informations.vegetables_in_a_week      string
# 57               households.amenities_present_in_house      string
# 59                             households.date_updated      string
# 60                          households.house_ownership      string
# 61                 households.neighborhood_description      string
# 64                       households.sanitary_ownership      string
# 66                            households.sanitary_type      string
# 67                            households.type_of_house      string
# 68                                                  id      string
# 72                             identification.id1.type      string
# 75                             identification.id2.type      string
# 78                             identification.id3.type      string
# 79                                           last_name      string
# 80                                    last_name_suffix      string
# 81                                         middle_name      string
# 82                                                nhid      string
# 83                                        organization      string
# 85                                profile_picture.name      string
# 86                                profile_picture.path      string
# 89                               profiles.civil_status      string
# 90                               profiles.date_updated      string
# 91                                  profiles.education      string
# 94                  profiles.employment.monthly_income      string
# 95                          profiles.employment.nature      string
# 96                                   profiles.religion      string
# 97                                       registered_at      string
# 98                                                type      string
# 100                                        user-cam.id      string
# 101                                     user-cam.owner      string
#
# [61 rows x 2 columns]

# %%
csv_filename_list = []
csv_header_name_list = []
csv_filename_list = list(csv_filename_df['source_key']) #array type
csv_header_name_list = list(csv_header_name_df['source_key']) #string type

main_header = []
array_header = []
object_header = []



        
for header in csv_header_name_list:
    for filename in csv_filename_list:
        tmp_header = header.split(sep='.')
        #print(tmp_header)
        if(len(tmp_header)) > 1:
            #pass
            #print(tmp_header[:-1])
            #tmp_string = '.'.join(tmp_header[:-1])
            tmp_string = header
            
            #print(tmp_string)
            
            
            #print('============')
            if tmp_string == filename: #for array list
                #print('---array_list---')
                #print(header)
                #print('--header/field: ' + tmp_string + ' == --filename: ' + filename)
                array_header.append(header)
        else:
            main_header.append(tmp_header[0])

# %% [markdown]
# ## List CSV

# %%
array_csv = []
array_csv = array_header
array_csv
# Out:
# ['health_informations.diagnosed',
#  'health_informations.family_history',
#  'households.amenities_present_in_house',
#  'households.sanitary_type']

# %%
for header in array_csv:
    #print(header)
    array_csv_df  = pd.DataFrame(columns=['id', header])
    array_csv_df.to_csv('file/' + header + '.csv', encoding='utf-8', mode='a', index=False)
array_csv_df
# Out:
# Empty DataFrame
# Columns: [id, households.sanitary_type]
# Index: []

# %% [markdown]
# ## Array of object CSV

# %%
object_array_csv = set()
object_array_csv = set(csv_header_name_list) - set(csv_filename_list) - set(main_header)
object_array_csv_list = list(object_array_csv)
object_array_csv
# Out:
# {'address.barangay',
#  'address.country',
#  'address.fax_number.country_code',
#  'address.fax_number.number',
#  'address.landline_number.country_code',
#  'address.landline_number.number',
#  'address.lot_or_house_number',
#  'address.mobile_number.country_code',
#  'address.mobile_number.number',
#  'address.postal_code',
#  'address.province',
#  'health_informations.allergies',
#  'health_informations.blood_pressure.first_reading.diastole',
#  'health_informations.blood_pressure.first_reading.systole',
#  'health_informations.blood_pressure.second_reading.diastole',
#  'health_informations.blood_pressure.second_reading.systole',
#  'health_informations.blood_pressure.third_reading.diastole',
#  'health_informations.blood_pressure.third_reading.systole',
#  'health_informations.blood_sign',
#  'health_informations.blood_type',
#  'health_informations.date_updated',
#  'health_informations.exercise_in_a_week',
#  'health_informations.fruits_in_a_week',
#  'health_informations.high_cost_medicine',
#  'health_informations.maintenance_drugs',
#  'health_informations.smoking_habit',
#  'health_informations.vegetables_in_a_week',
#  'households.date_updated',
#  'households.house_ownership',
#  'households.neighborhood_description',
#  'households.sanitary_ownership',
#  'households.type_of_house',
#  'identification.id1.type',
#  'identification.id2.type',
#  'identification.id3.type',
#  'profile_picture.name',
#  'profile_picture.path',
#  'profiles.civil_status',
#  'profiles.date_updated',
#  'profiles.education',
#  'profiles.employment.monthly_income',
#  'profiles.employment.nature',
#  'profiles.religion',
#  'user-cam.id',
#  'user-cam.owner'}

# %% [markdown]
# ## object with filenames

# %%
tmp = object_array_csv_list[0]
tmp
# Out:
# 'health_informations.blood_type'

# %%
other_header_object = []
for name in object_array_csv_list:
    str1 = name.split('.')
    str2 = '.'.join(str1[0:-1])
    if str2 in csv_filename_list:
        
        other_header_object.append(name)
other_header_object
# Out:
# ['health_informations.blood_type',
#  'health_informations.smoking_habit',
#  'health_informations.fruits_in_a_week',
#  'address.mobile_number.number',
#  'health_informations.vegetables_in_a_week',
#  'health_informations.maintenance_drugs',
#  'address.barangay',
#  'health_informations.blood_sign',
#  'health_informations.date_updated',
#  'households.neighborhood_description',
#  'address.landline_number.country_code',
#  'health_informations.exercise_in_a_week',
#  'households.house_ownership',
#  'households.date_updated',
#  'households.type_of_house',
#  'address.landline_number.number',
#  'profiles.religion',
#  'address.country',
#  'address.postal_code',
#  'address.mobile_number.country_code',
#  'address.province',
#  'address.fax_number.country_code',
#  'health_informations.allergies',
#  'health_informations.high_cost_medicine',
#  'profiles.date_updated',
#  'address.lot_or_house_number',
#  'profiles.education',
#  'address.fax_number.number',
#  'households.sanitary_ownership',
#  'profiles.civil_status']

# %%
from collections import defaultdict

philip = defaultdict(list)

for header in other_header_object:
    #bars[filenames] = []
    
    filenames = header.split(sep=".")[0:-1]
    filenames = '.'.join(filenames)
    philip[filenames].append(header)
    #print('headername: ', header)
    #print('filenames: ', filenames)

philip['profiles']
# Out:
# ['profiles.religion',
#  'profiles.date_updated',
#  'profiles.education',
#  'profiles.civil_status']

# %%
bars = { 
    'health_informations': ['health_informations.house_ownership', 'health_informations.type_of_house'],
    'profiles': ['profiles.eduction', 'profiles.religion'],
    'address.mobile_number': ['address.mobile_number.number','address.mobile_number.code']
    }
bars
# Out:
# {'health_informations': ['health_informations.house_ownership',
#   'health_informations.type_of_house'],
#  'profiles': ['profiles.eduction', 'profiles.religion'],
#  'address.mobile_number': ['address.mobile_number.number',
#   'address.mobile_number.code']}

# %%
for header in philip:
    print(philip[header])
    tmp = list(philip[header])
    print(str(tmp))
    object_array_csv_df  = pd.DataFrame(columns= tmp)
    object_array_csv_df.to_csv('file/' + header + '.csv', encoding='utf-8', mode='a', index=False)
object_array_csv_df
# Out:
# ['health_informations.blood_type', 'health_informations.smoking_habit', 'health_informations.fruits_in_a_week', 'health_informations.vegetables_in_a_week', 'health_informations.maintenance_drugs', 'health_informations.blood_sign', 'health_informations.date_updated', 'health_informations.exercise_in_a_week', 'health_informations.allergies', 'health_informations.high_cost_medicine']
# ['health_informations.blood_type', 'health_informations.smoking_habit', 'health_informations.fruits_in_a_week', 'health_informations.vegetables_in_a_week', 'health_informations.maintenance_drugs', 'health_informations.blood_sign', 'health_informations.date_updated', 'health_informations.exercise_in_a_week', 'health_informations.allergies', 'health_informations.high_cost_medicine']
# ['address.mobile_number.number', 'address.mobile_number.country_code']
# ['address.mobile_number.number', 'address.mobile_number.country_code']
# ['address.barangay', 'address.country', 'address.postal_code', 'address.province', 'address.lot_or_house_number']
# ['address.barangay', 'address.country', 'address.postal_code', 'address.province', 'address.lot_or_house_number']
# ['households.neighborhood_description', 'households.house_ownership', 'households.date_updated', 'households.type_of_house', 'households.sanitary_ownership']
# ['households.neighborhood_description', 'households.house_ownership', 'households.date_updated', 'households.type_of_house', 'households.sanitary_ownership']
# ['address.landline_number.country_code', 'address.landline_number.number']
# ['address.landline_number.country_code', 'address.landline_number.number']
# ['profiles.religion', 'profiles.date_updated', 'profiles.education', 'profiles.civil_status']
# ['profiles.religion', 'profiles.date_updated', 'profiles.education', 'profiles.civil_status']
# ['address.fax_number.country_code', 'address.fax_number.number']
# ['address.fax_number.country_code', 'address.fax_number.number']
# Empty DataFrame
# Columns: [address.fax_number.country_code, address.fax_number.number]
# Index: []

# %% [markdown]
# ## object without filenames

# %%
main_header_object = []
for name in object_array_csv_list:
    #print(name)
    if name.split(sep='.')[0] not in csv_filename_list:
        main_header_object.append(name)
main_header_object
# Out:
# ['identification.id2.type',
#  'user-cam.id',
#  'user-cam.owner',
#  'profile_picture.path',
#  'identification.id3.type',
#  'identification.id1.type',
#  'profile_picture.name']

# %% [markdown]
# ## Object CSV

# %%
object_csv = set()
object_csv = set(csv_header_name_object_list) - set(csv_filename_list)
object_csv
# Out:
# {'health_informations.blood_pressure',
#  'health_informations.blood_pressure.first_reading',
#  'health_informations.blood_pressure.second_reading',
#  'health_informations.blood_pressure.third_reading',
#  'identification',
#  'identification.id1',
#  'identification.id2',
#  'identification.id3',
#  'profile_picture',
#  'profiles.employment',
#  'user-cam'}

# %% [markdown]
# ## Main (e.g. resident) csv file

# %%
main_header_list = list(dict.fromkeys(main_header))
main_header_list = main_header_list  + main_header_object
main_header_list
# Out:
# ['birthdate',
#  'family_members',
#  'first_name',
#  'gender',
#  'id',
#  'last_name',
#  'last_name_suffix',
#  'middle_name',
#  'nhid',
#  'organization',
#  'registered_at',
#  'type',
#  'identification.id2.type',
#  'user-cam.id',
#  'user-cam.owner',
#  'profile_picture.path',
#  'identification.id3.type',
#  'identification.id1.type',
#  'profile_picture.name']

# %%
main_resident_df  = pd.DataFrame(columns = main_header_list)
#main_resident_df = main_resident_df.iloc[0:0]
#main_resident_df
#main_resident_df.columns = main_header

#TODO: check if header/columns already exist
main_resident_df.to_csv('file/resident.csv', encoding='utf-8', mode='a', index=False)
main_resident_df
# Out:
# Empty DataFrame
# Columns: [birthdate, family_members, first_name, gender, id, last_name, last_name_suffix, middle_name, nhid, organization, registered_at, type, identification.id2.type, user-cam.id, user-cam.owner, profile_picture.path, identification.id3.type, identification.id1.type, profile_picture.name]
# Index: []

# %% [markdown]
# ## split ang get first string,
# ### if string is equal to csv filename, include as csv header in same csv filename
# ### if string not equal, include as csv header in main csv

# %%
headers = []
headers =  list(csv_header_name_df['source_key'])

empty_df = pd.DataFrame()
empty_df.columns = ["Sequence", "Start", "End", "Coverage"]
#empty_df.to_csv('file/resident.csv', encoding='utf-8', mode='a', header=None, index=False)

# %%
#df.to_csv('file/resident.csv', encoding='utf-8', mode='w', header=header, index=False)

# %%
d = []
with open(input_data_file) as f:
    #d = json.load(f)
    d = json.load(f)
    print('----')
    print(d)
    print('---type--')
print(type(d))

# %% [markdown]
# ## Get input data

# %%
flat_json_0 = {}
flat_json_1 = {}
flat_json_2 = {}

flat_json_0 = flattenDict(d[0])
print('--flatten_dict_type--')
print(type(flat_json_0))
print('--flatten_dict_data--')
flat_json_0

print('--normalize flatten_dict--')
json_flat_norm_0 = json_normalize(flat_json_0)


flat_json_1 = flattenDict(d[1])
json_flat_norm_1 = json_normalize(flat_json_1)

flat_json_2 = flattenDict(d[2])
json_flat_norm_2 = json_normalize(flat_json_2)

# %%
json_flat_norm_0

# %%
json_flat_norm_1

# %%
json_flat_norm_2

# %% [markdown]
# ## TESTING: flattendict with nested array of objects

# %%
dx = []
dx = {}
dx_list = []
dx_dict = {}
dx_normalize_df = pd.DataFrame()

input_data_file_test = 'data/curisData.1-items.json'
with open(input_data_file_test) as f:
    dx_list = json.load(f)
    #dx = json.load(f)

type(dx_list)

# %%
dx_flatten = flatten_json(dx_list[0])
dx_flatten

# %%
dx_normalize_df = json_normalize(dx_flatten)

dx_normalize_df.T.to_csv('processed_data.csv',sep=',')
type(dx_normalize_df)

# %%
list(dx_normalize_df.columns)

# %%
dx_normalize_df

# %% [markdown]
# ## TODO: ITERATE OVER LIST and MERGE normalize headers

# %%
input_data_df = pd.DataFrame()
input_data_df = json_flat_norm_0
input_data_df = input_data_df.append(json_flat_norm_1, sort=True)
input_data_df = input_data_df.append(json_flat_norm_2, sort=True)
input_data_df.sort_values(['demographics.awh_id']).reset_index(drop=True)
#input_data_df.sort_values(p'd)

# %%
type(input_data_df)

# %% [markdown]
# ## Clean input data column header

# %%
input_data_df.columns = input_data_df.columns.str.lower().str.replace('/','.')
input_data_df

# %% [markdown]
# ## Get Mapping

# %%
mapping_df = pd.read_csv(mapping_file, skiprows=0)
mapping_df

# %% [markdown]
# ## Get values input data that are included mapping

# %%
selected_data_df = pd.DataFrame()
selected_data_df = input_data_df[list(mapping_df['source_key'])]
selected_data_df

# %% [markdown]
# ## Renamce source header fields into destination header fields

# %%
selected_data_df.columns = list(mapping_df['destination_key'])
selected_data_df

# %% [markdown]
# ## Encode to as Filesystem (HDFS) or S3 (avro) format)

# %% [markdown]
# ## Decode for cleaning

# %% [markdown]
# ## Decode to for computation

# %% [markdown]
# ## Decode to for analytics transformation

# %% [markdown]
# ## Transform flat file into output schema format

# %%
flat_json = ''
flat_json = selected_data_df.to_json(orient='records')
json_json = json.loads(flat_json)
json_json

# %% [markdown]
# ## Convert dot notated fields into nested json

# %%
input_file = 'data/data.json'
with open(input_file) as f:
    d = (f)

# %%
def dot_to_json(a):
    output = {}
    for key, value in a.items():
        path = key.split('.')[1:]  # ignore the json. prefix
        #path = key
        target = reduce(lambda d, k: d.setdefault(k, {}), path[:-1], output)
        target[path[-1]] = value
    return output
 
data = {'json.message.status.time':50, 'json.message.code.response':80, 'json.time':100}
type(data)


data

# %% [markdown]
# ## data

# %%
data

# %% [markdown]
# ## dot data

# %%
dict_json = dot_to_json(data)
dict_json

# %% [markdown]
# ## dictionary to json

# %%
def _dict2json(results):
    counter = 0
    data = []

    for row in results: 
        data.append(json.dumps(row))
        counter += 1
    
    return data

json_dict = _dict2json(dict_json) 
json_dict

# %%
iris = pd.DataFrame()
iris = pd.read_csv('data/sql.csv')
iris
#iris.to_json(orient='records')
list(iris['0'])

# %%
iris
