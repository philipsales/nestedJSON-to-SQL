# %%
import numpy as np
import pandas as pd
import json
from pandas.io.json import json_normalize 
from pandas import read_csv
import logging
from functools import reduce
import csv
from collections import defaultdict
import os

# %%
## Configuration

# %%
#etl = 'kobo2elastic'
#etl = 'curis2elastic'
#etl = 'oldcuris2newcuris'
etl = 'isabela2newaqm'
#etl = 'cambodia2newaqm'

input_schema_file = ''
input_data_file = ''
mapping_file = ''

root_object = 'resident'

if etl == 'curis2elastic':
    #old curis to elasticsearch
    input_schema_file = 'schema/input/curisSchema.1-item.json'
    input_data_file = 'data/curisData.1-items.json'
    mapping_file = 'schema/map/couchbase2elastic.map.csv'
    output_dir = 'file/curisSchema/'
    
elif etl == 'kobo2elastic':
    #kobo to elasticsearch
    input_schema_file = 'schema/input/koboSchema.1-item.json'
    input_data_file = 'data/koboData.2-items.json'
    mapping_file = 'schema/map/kobo2elastic.map.csv'
    output_dir = 'file/koboSchema/'
    
elif etl == 'oldcuris2newcuris':
    #kobo to elasticsearch
    input_schema_file = 'schema/input/curisSchema.1-item.json'
    input_data_file = 'data/curisData.1-item.json'
    mapping_file = 'schema/map/kobo2elastic.map.csv'
    output_dir = 'file/curisSchema/'
    
elif etl == 'cambodia2newaqm':
    #kobo to elasticsearch
    input_schema_file = 'schema/input/KHMSchema.json'
    input_data_file = 'data/KHM.3-items.json'
    mapping_file = 'schema/map/kobo2elastic.map.csv'
    output_dir = 'file/KHMSchema/'

elif etl == 'isabela2newaqm':
    #kobo to elasticsearch
    input_schema_file = 'schema/input/curisSchema.1-item.json'
    #input_data_file = 'data/Isabela.2-items.json'
    input_data_file = 'data/Isabela.6203-items.json'
    mapping_file = 'schema/map/Isabela2newAQM.map.csv'
    #output_dir = 'file/IsabelaSchema/'
    tmp_dir = 'data/processed/couchbase-curis-2019-06-21/tmp/'
    output_dir = 'data/processed/couchbase-curis-2019-06-21/'

# %%
def _open_file():
    with open(input_data_file) as f:
        return json.load(f)

# %%
def _flatten_json(nested_json):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '.')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + '' + str(i) + '.')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(nested_json)
    return out

# %%
def _dict_to_dataframe(dict_object):
    return pd.DataFrame.from_dict({'value': dict_object})

# %%
## OPTIMIZE TO ACCEPT LIST NOT DATAFRAME
def filter_key(x):
    lists = format_key(x)
    lists = exclude_digit(lists)
    lists = list2string(lists)
    return lists

def filter_index_map(x):
    lists = format_key(x)
    lists = include_digit(lists)
    lists = list2string(lists)
    return lists

def format_key(items):
    #return list(map(lambda x:x.lower().split(sep='.'), items ))
    return items.lower().split(sep='.')

def include_digit(items):
    return [item for item in items if item.isdigit()]

def exclude_digit(items):
    return [item for item in items if not item.isdigit()]

def list2string(lists):
    return '.'.join(lists)

# %%
def _add_custom_colums(dataframe_object):
    dataframe_object['key'] = list(dataframe_object.index)
    dataframe_object['key'] = dataframe_object['key'].apply(filter_key)
    #print('_add_custom_columns ',dataframe_object[dataframe_object['key'] == 'id' ])

    dataframe_object['_index_map'] = list(dataframe_object.index)
    dataframe_object['_index_map'] = dataframe_object['_index_map'].apply(filter_index_map)
    #TODO: musbe adjusted dynamically
    
    #CHECK if single object or array of objects
    #formid == koboschema
    #id == curischema
    #dataframe_object['_id'] = dataframe_object[dataframe_object['key'] == 'formid' ]['value'].values[0]
    
    #IF oldcursi2newcuris
    dataframe_object['_id'] = dataframe_object[dataframe_object['key'] == 'id' ]['value'].values[0]
    #IF KHMSChema
    #dataframe_object['_id'] = dataframe_object[dataframe_object['key'] == '_id' ]['value'].values[0]
    
    #print(dataframe_object)
    dataframe_object = dataframe_object.reset_index(drop=True)

    return dataframe_object

# %%
## File loader

# %%
def _get_mapping_fields():
    _mapping_df = pd.DataFrame()
    _mapping_df = read_csv(mapping_file).sort_values(['source_key'])

    _required_mapping_fields = list(_mapping_df['source_key'])
    return _required_mapping_fields

# %%
def _get_index_map(data_df):
    return list(data_df['_index_map'].unique())

# %%
def _filter_by_indexmap(data_df, index):
    return data_df[data_df['_index_map'] == index ]

# %%
def clean_value(x):
    return x.lower().replace("/", ".").replace("the", "").replace("schema", "").strip()

# %%
def _get_filenames():
    schema_csv = pd.read_csv(output_dir + 'schema.csv', skiprows=0)
    return schema_csv['file_name'].values[0].split(sep=",")

# %%
def _get_csv_headers(filename):
    return pd.read_csv( output_dir + filename + '.csv',nrows=0) #get header only

# %%
def _get_required_data(input_data_df,csv_header_df):
    
    required_header_list = [] 

    for data in input_data_df['key']:
        
        if data in csv_header_df.columns:
            
            required_header_list.append(data)
    
    #print(required_header_list)
    
    return input_data_df[input_data_df['key'].isin(required_header_list)]

# %%
def _rename_index(data_df):
    if 'key' in data_df.columns:
        data_df.index = list(data_df['key'])
        data_df = data_df.drop('key', axis=1)
    return data_df

# %%
def _columnar_to_row(input_data_df,csv_header_df):
    
    for header in list(input_data_df.index):
        if header:
            csv_header_df.at['',header] = input_data_df.loc[header]['value']
    
        csv_header_df.at['','_id'] = input_data_df['_id'][header] 
        csv_header_df.at['','_index_map'] = input_data_df['_index_map'][header] 
         
    return csv_header_df

# %%
def _write_to_csv(data_csv_df, filename):
    return data_csv_df.to_csv(output_dir + filename + '.csv', encoding='utf-8', mode='a', header=False,index=False)

# %%
# Out:
# writing: 1/6203
# writing: 2/6203
# writing: 3/6203
# writing: 4/6203
# writing: 5/6203
# writing: 6/6203
# writing: 7/6203
# writing: 8/6203
# writing: 9/6203
# writing: 10/6203
# writing: 11/6203
# writing: 12/6203
# writing: 13/6203
# writing: 14/6203
# writing: 15/6203
# writing: 16/6203
# writing: 17/6203
# writing: 18/6203
# writing: 19/6203
# writing: 20/6203
# writing: 21/6203
# writing: 22/6203
# writing: 23/6203
# writing: 24/6203
# writing: 25/6203
# writing: 26/6203
# writing: 27/6203
# writing: 28/6203
# writing: 29/6203
# writing: 30/6203
# writing: 31/6203
# writing: 32/6203
# writing: 33/6203
# writing: 34/6203
# writing: 35/6203
# writing: 36/6203
# writing: 37/6203
# writing: 1922/6203
# writing: 1923/6203
# writing: 1924/6203
# writing: 1925/6203
# writing: 1926/6203
# writing: 1927/6203
# writing: 1928/6203
# writing: 1929/6203
# writing: 1930/6203
# writing: 1931/6203
# writing: 1932/6203
# writing: 1933/6203
# writing: 1934/6203
# writing: 1935/6203
# writing: 1936/6203
# writing: 1937/6203
# writing: 1938/6203
# writing: 1939/6203
# writing: 1940/6203
# writing: 1941/6203
# writing: 1942/6203
# writing: 1943/6203
# writing: 1944/6203
# writing: 1945/6203
# writing: 1946/6203
# writing: 1947/6203
# writing: 1948/6203
# writing: 1949/6203
# writing: 1950/6203
# writing: 1951/6203
# writing: 1952/6203
# writing: 1953/6203
# writing: 1954/6203
# writing: 1955/6203
# writing: 1956/6203
# writing: 1957/6203
# writing: 1958/6203
# writing: 1959/6203
# writing: 1960/6203
# writing: 1961/6203
# writing: 1962/6203
# writing: 1963/6203
# writing: 1964/6203
# writing: 1965/6203
# writing: 1966/6203
# writing: 1967/6203
# writing: 1968/6203
# writing: 1969/6203
# writing: 1970/6203
# writing: 1971/6203
# writing: 1972/6203
# writing: 1973/6203
# writing: 1974/6203
# writing: 1975/6203
# writing: 1976/6203
# writing: 1977/6203
# writing: 1978/6203
# writing: 1979/6203
# writing: 1980/6203
# writing: 1981/6203
# writing: 1982/6203
# writing: 1983/6203
# writing: 1984/6203
# writing: 1985/6203
# writing: 1986/6203
# writing: 1987/6203
# writing: 1988/6203
# writing: 1989/6203
# writing: 1990/6203
# writing: 1991/6203
# writing: 1992/6203
# writing: 1993/6203
# writing: 1994/6203
# writing: 1995/6203
# writing: 1996/6203
# writing: 1997/6203
# writing: 1998/6203
# writing: 1999/6203
# writing: 2000/6203
# writing: 2001/6203
# writing: 2002/6203
# writing: 2003/6203
# writing: 2004/6203
# writing: 2005/6203
# writing: 2006/6203
# writing: 2007/6203
# writing: 2008/6203
# writing: 2009/6203
# writing: 2010/6203
# writing: 2011/6203
# writing: 2012/6203
# writing: 2013/6203
# writing: 2014/6203
# writing: 2015/6203
# writing: 2016/6203
# writing: 2017/6203
# writing: 2018/6203
# writing: 2019/6203
# writing: 2020/6203
# writing: 2021/6203
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-245-94a29db34840> in <module>()
#       1 write_testing_csv()
#       2 write_temporary_csv()
# ----> 3 get_required_data_only()
#
# <ipython-input-212-fc6c439cb884> in get_required_data_only()
#      13         test_data_flat_df = _dict_to_dataframe(test_data_flat_dict)
#      14
# ---> 15         _customed_data_flat_df = _add_custom_colums(test_data_flat_df)
#      16
#      17         _filtered_customed_data_flat_df = _customed_data_flat_df[_customed_data_flat_df['key'].isin(_required_mapping_fields)]
#
# <ipython-input-9-db3ad30d0362> in _add_custom_colums(dataframe_object)
#      14
#      15     #IF oldcursi2newcuris
# ---> 16     dataframe_object['_id'] = dataframe_object[dataframe_object['key'] == 'id' ]['value'].values[0]
#      17     #IF KHMSChema
#      18     #dataframe_object['_id'] = dataframe_object[dataframe_object['key'] == '_id' ]['value'].values[0]
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2722             key = check_bool_indexer(self.index, key)
#    2723             indexer = key.nonzero()[0]
# -> 2724             return self._take(indexer, axis=0)
#    2725         else:
#    2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/generic.py in _take(self, indices, axis, is_copy)
#    2787         new_data = self._data.take(indices,
#    2788                                    axis=self._get_block_manager_axis(axis),
# -> 2789                                    verify=True)
#    2790         result = self._constructor(new_data).__finalize__(self)
#    2791
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/internals.py in take(self, indexer, axis, verify, convert)
#    4524                              dtype='int64')
#    4525                    if isinstance(indexer, slice)
# -> 4526                    else np.asanyarray(indexer, dtype='int64'))
#    4527
#    4528         n = self.shape[axis]
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/numpy/core/numeric.py in asanyarray(a, dtype, order)
#     551
#     552     """
# --> 553     return array(a, dtype, copy=False, order=order, subok=True)
#     554
#     555
#
# KeyboardInterrupt:

# %%
# Out:
# Unique index:  17
# writing into filename: households
# writing into filename: profiles
# writing into filename: resident
# writing into filename: households
# writing into filename: profiles
# writing into filename: resident
# writing into filename: households
# writing into filename: profiles
# writing into filename: resident
# writing into filename: households
# writing into filename: profiles
# writing into filename: resident
# writing into filename: households
# writing into filename: profiles
# writing into filename: resident
# writing into filename: households
# writing into filename: profiles
# writing into filename: resident
# writing into filename: households
# writing into filename: profiles
# writing into filename: resident
# writing into filename: households
# writing into filename: profiles
# writing into filename: resident
# writing into filename: households
# writing into filename: profiles
# writing into filename: resident
# writing into filename: households
# writing into filename: profiles
# writing into filename: resident
# writing into filename: households
# writing into filename: profiles
# writing into filename: resident
# writing into filename: households
# writing into filename: profiles
# writing into filename: resident
# writing into filename: households
# writing into filename: profiles
# writing into filename: resident
# writing into filename: households
# writing into filename: profiles
# writing into filename: resident
# writing into filename: households
# writing into filename: profiles
# writing into filename: resident
# writing into filename: households
# writing into filename: profiles
# writing into filename: resident
# writing into filename: households
# writing into filename: profiles
# writing into filename: resident
#
# ---Getting data from masterfile----
# Total file rows 27936
# Total resident: 2021
#
# ---grouping fields----
# Total group permutation: 4355
# converting 1/4355
# converting 2/4355
# converting 3/4355
# converting 4/4355
# converting 5/4355
# converting 6/4355
# converting 7/4355
# converting 8/4355
# converting 9/4355
# converting 10/4355
# converting 11/4355
# converting 12/4355
# converting 13/4355
# converting 14/4355
# converting 15/4355
# converting 16/4355
# converting 17/4355
# converting 18/4355
# converting 19/4355
# converting 20/4355
# converting 21/4355
# converting 22/4355
# converting 23/4355
# converting 24/4355
# converting 25/4355
# converting 26/4355
# converting 27/4355
# converting 28/4355
# converting 29/4355
# converting 30/4355
# converting 31/4355
# converting 32/4355
# converting 33/4355
# converting 34/4355
# converting 35/4355
# converting 36/4355
# converting 37/4355
# converting 38/4355
# converting 39/4355
# converting 40/4355
# converting 41/4355
# converting 42/4355
# converting 43/4355
# converting 44/4355
# converting 45/4355
# converting 46/4355
# converting 47/4355
# converting 48/4355
# converting 49/4355
# converting 50/4355
# converting 51/4355
# converting 52/4355
# converting 53/4355
# converting 54/4355
# converting 55/4355
# converting 56/4355
# converting 57/4355
# converting 58/4355
# converting 59/4355
# converting 60/4355
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-246-ccb7f17a7689> in <module>()
#       1 iterate_data()
#       2 testing_df = read_temporary()
# ----> 3 sort_fieldname_by_filename(testing_df)
#
# <ipython-input-208-bb0fb45d4617> in sort_fieldname_by_filename(testing_df)
#      27                 array_defaultdict[curr_filename] = [r]
#      28
# ---> 29         row_data_csv_df = _new_columnar_to_row(array_defaultdict)
#      30         index += 1
#      31         print('converting ' + str(index) + '/' + str(len(grouped)))
#
# <ipython-input-210-6e0cb878d7d7> in _new_columnar_to_row(defaultdict_test)
#      33
#      34         ## GET HEADER HERE
# ---> 35         csv_df = pd.read_csv(output_dir + file + '.csv', nrows=0)
#      36
#      37         ## MATCH THE CSV HEADER WITH  DATA
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1049             new_rows = len(index)
#    1050
# -> 1051         df = DataFrame(col_dict, columns=columns, index=index)
#    1052
#    1053         self._currow += new_rows
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
#     461     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7357
#    7358     # don't force copy because getting jammed in an ndarray anyway
# -> 7359     arrays = _homogenize(arrays, index, dtype)
#    7360
#    7361     # from BlockManager perspective
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/frame.py in _homogenize(data, index, dtype)
#    7655                 # Forces alignment. No need to copy data since we
#    7656                 # are putting it into an ndarray later
# -> 7657                 v = v.reindex(index, copy=False)
#    7658         else:
#    7659             if isinstance(v, dict):
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/series.py in reindex(self, index, **kwargs)
#    3323     @Appender(generic._shared_docs['reindex'] % _shared_doc_kwargs)
#    3324     def reindex(self, index=None, **kwargs):
# -> 3325         return super(Series, self).reindex(index=index, **kwargs)
#    3326
#    3327     def drop(self, labels=None, axis=0, index=None, columns=None,
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    3687         # perform the reindex on the axes
#    3688         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 3689                                   fill_value, copy).__finalize__(self)
#    3690
#    3691     def _reindex_axes(self, axes, level, limit, tolerance, method, fill_value,
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3700             ax = self._get_axis(a)
#    3701             new_index, indexer = ax.reindex(labels, level=level, limit=limit,
# -> 3702                                             tolerance=tolerance, method=method)
#    3703
#    3704             axis = self._get_axis_number(a)
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in reindex(self, target, method, level, limit, tolerance)
#    3613                                              return_indexers=True)
#    3614         else:
# -> 3615             if self.equals(target):
#    3616                 indexer = None
#    3617             else:
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/indexes/range.py in equals(self, other)
#     327                     self._step == other._step)
#     328
# --> 329         return super(RangeIndex, self).equals(other)
#     330
#     331     def intersection(self, other):
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in equals(self, other)
#    2459         try:
#    2460             return array_equivalent(com._values_from_object(self),
# -> 2461                                     com._values_from_object(other))
#    2462         except Exception:
#    2463             return False
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/dtypes/missing.py in array_equivalent(left, right, strict_nan)
#     413     # Object arrays can contain None, NaN and NaT.
#     414     # string dtypes must be come to this path for NumPy 1.7.1 compat
# --> 415     if is_string_dtype(left) or is_string_dtype(right):
#     416
#     417         if not strict_nan:
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/dtypes/common.py in is_string_dtype(arr_or_dtype)
#     578     try:
#     579         dtype = _get_dtype(arr_or_dtype)
# --> 580         return dtype.kind in ('O', 'S', 'U') and not is_period_dtype(dtype)
#     581     except TypeError:
#     582         return False
#
# KeyboardInterrupt:

# %%
def write_testing_csv():
    #csv_header = {'value': [], 'key': [],  '_index_map':[],'_id': [] }
    empty_df = pd.DataFrame()
    empty_df.to_csv( tmp_dir + 'testing.csv', encoding='utf-8', mode='w',header=True,index=False)

# %%
def write_temporary_csv():
    csv_header = {'value': [], 'key': [],  '_index_map':[],'_id': [] }
    empty_df = pd.DataFrame(csv_header)
    empty_df.to_csv( tmp_dir + 'temporary.csv', encoding='utf-8', mode='w',header=True,index=False)

# %%
def get_required_data_only():
    data_list = _open_file()
    data_list
    
    _required_mapping_fields = []
    _required_mapping_fields = _get_mapping_fields()

    index = 0
    for datum in data_list:
        
        test_data_flat_dict = _flatten_json(datum)  
        
        test_data_flat_df = _dict_to_dataframe(test_data_flat_dict)

        _customed_data_flat_df = _add_custom_colums(test_data_flat_df)

        _filtered_customed_data_flat_df = _customed_data_flat_df[_customed_data_flat_df['key'].isin(_required_mapping_fields)]
        
        _filtered_customed_data_flat_df.to_csv( tmp_dir + 'temporary.csv', encoding='utf-8', mode='a', header=False,index=False)
        index += 1
        print('writing: ' + str(index) + '/' + str(len(data_list)) )

# %%
def iterate_data():
    df = pd.read_csv(tmp_dir + 'temporary.csv', dtype={'_index_map': str})
    df = df.replace(np.nan,'',regex=True)
    df

    test_meta_header_df = pd.read_csv( 'data/processed/couchbase-curis-2019-06-21/_meta.csv')
    test_meta_header_df

    _filename_list = list(test_meta_header_df['file_name'].unique())
    _filename_list

    test_index_map =  list(df['_index_map'].unique())

    test_source_data_df = pd.DataFrame()

    print('Unique index: ',len(test_index_map))
    
    ##DELETE FILE IF EXIST
    os.remove(tmp_dir + 'testing.csv')
    
    for _test_index_map in test_index_map:
        
        
        test_source_data_df = _filter_by_indexmap(df, str(_test_index_map))

        for _filename in _filename_list:
            test_list_field_name = []
            test_list_field_name = list(test_meta_header_df[test_meta_header_df['file_name'] == _filename ]['field_name']) 
            
            test_required_header_list = []
            test_required_header_list = list(set(test_source_data_df['key']) & set(test_list_field_name))
            
            req_test_source_data_df = pd.DataFrame()
            req_test_source_data_df = test_source_data_df[test_source_data_df['key'].isin(test_required_header_list)]

            test_rename_data_df = pd.DataFrame()
            test_rename_data_df = _rename_index(req_test_source_data_df)
            
            print('writing into filename:', _filename)
            
            test_rename_data_df.to_csv( tmp_dir + 'testing.csv', encoding='utf-8', mode='a',header=False,index=True)

# %%
def read_temporary():
    columns = ['key','value','_index_map','_id']
    
    testing_df = pd.read_csv(tmp_dir + 'testing.csv',header=None, names=columns)
    testing_df = testing_df.replace(np.nan,'',regex=True)
    testing_df
    print('\n---Getting data from masterfile----')
    print('Total file rows', len(testing_df))
    print('Total resident:', len(testing_df['_id'].unique()))
    return testing_df

# %%
def sort_fieldname_by_filename(testing_df):
    print('\n---grouping fields----')

    grouped = testing_df.groupby(['_index_map','_id'])
    
    print('Total group permutation:', len(grouped))
    index = 0

    for name, group in grouped:
        array_defaultdict = defaultdict(list)
        
        for r in zip(group['key'],group['value'],group['_index_map'],group['_id']):
            
            field_name = list(r)[0]
            
            test_meta_header_df = pd.read_csv('data/processed/couchbase-curis-2019-06-21/_meta.csv')    
            curr_filename = list(test_meta_header_df[test_meta_header_df['field_name'] == field_name  ]['file_name'])[0]

            array_tuples = []

            if array_defaultdict:
                if curr_filename in array_defaultdict:
                    array_defaultdict[curr_filename].append(r)  
                else:
                    array_defaultdict[curr_filename] = [r]
            else:
                array_defaultdict[curr_filename] = [r]
        
        row_data_csv_df = _new_columnar_to_row(array_defaultdict) 
        index += 1
        print('converting ' + str(index) + '/' + str(len(grouped)))

# %%
def _new_columnar_to_row(defaultdict_test):
    
    for file ,dict_values in defaultdict_test.items():
        #print('inserting into: ', file)
        
        _filename = file
        test_meta_header_df = pd.read_csv( 'data/processed/couchbase-curis-2019-06-21/_meta.csv')    
    
        _id = ''
        _index_map = ''
        array_fields = []

        for tups in dict_values:
            fields = {}
            values = list(tups)

            _key = values[0]
            _value = values[1]
            _index_map = values[2]
            _id = values[3]

            fields = { _key : _value, '_index_map' :_index_map, '_id': _id }
            array_fields.append(fields)

        new_list = {}
        
        if len(array_fields) > 1:
            for d in array_fields:
                new_list.update(d)
        else:
            new_list = array_fields[0]
            
        
        ## GET HEADER HERE
        csv_df = pd.read_csv(output_dir + file + '.csv', nrows=0)

        ## MATCH THE CSV HEADER WITH  DATA
        for key,value in new_list.items():
            csv_df.at['',key] = value
        
        
        csv_df.to_csv(output_dir + file + '.csv', encoding='utf-8', mode='a', header=False,index=False)
         
    return

# %%
write_testing_csv()
write_temporary_csv()
get_required_data_only()
iterate_data()
testing_df = read_temporary()
sort_fieldname_by_filename(testing_df)

# %%
csv_df.to_csv(output_dir + file + '.csv', encoding='utf-8', mode='a', header=False,index=False)

# %% [markdown]
# ## GET REQUIRED MAPPING

# %%
_required_mapping_fields = []
_required_mapping_fields = _get_mapping_fields()
_required_mapping_fields

# %% [markdown]
# ## GET HEADERS THRU META DATA

# %%
test_meta_header_df = pd.read_csv( 'data/processed/couchbase-curis-2019-06-21/_meta.csv')
test_meta_header_df

# %% [markdown]
# ## OPEN DATA FROM FILE

# %%
data_list = []
data_list = _open_file()
data_list

# %% [markdown]
# ## FLATTEN JSON FILE -- ITERATE DATA HERE

# %%
datum = data_list[0]
test_data_flat_dict = _flatten_json(datum)  
test_data_flat_dict

# %% [markdown]
# ## Dictionary TO DATAFRAME

# %%
test_data_flat_df = _dict_to_dataframe(test_data_flat_dict)
test_data_flat_df

# %% [markdown]
# ## ADD CUSTOM COLUMNS WITHOUT MAPPING

# %%
_customed_data_flat_df = _add_custom_colums(test_data_flat_df)
_customed_data_flat_df

# %% [markdown]
# ## FILTER ONLY REQUIRED MAPPING FROM RAW FLAT DATA

# %%
_customed_data_flat_df = _customed_data_flat_df[_customed_data_flat_df['key'].isin(_required_mapping_fields)]
_customed_data_flat_df

# %% [markdown]
# ## GET ALL UNIQUE INDEX MAP

# %%
test_index_map =  list(_customed_data_flat_df['_index_map'].unique())
test_index_map

# %% [markdown]
# ## FILTER BY INDEX_MAP -- ITERATION

# %%
_test_index_map = test_index_map[1]

# %%
test_source_data_df = pd.DataFrame()
test_source_data_df = _filter_by_indexmap(_customed_data_flat_df, _test_index_map)
test_source_data_df

# %% [markdown]
# ## GET UNIQUE FILENAME -- ITERATION

# %%
_filename_list = list(test_meta_header_df['file_name'].unique())
_filename_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-faa29a849344> in <module>()
# ----> 1 _filename_list = list(test_meta_header_df['file_name'].unique())
#       2 _filename_list
#
# NameError: name 'test_meta_header_df' is not defined

# %%
_filename = _filename_list[0]
_filename
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-e309f83b47ba> in <module>()
# ----> 1 _filename = _filename_list[0]
#       2 _filename
#
# NameError: name '_filename_list' is not defined

# %% [markdown]
# ## CLEAN FILTERED BY INDEX_MAP #Cleaning is for '/' in cambodia schema

# %%
test_source_data_df['key'].apply(clean_value)
test_source_data_df

# %% [markdown]
# ## GET CSV HEADERS OF EACH FILENAME -- OPTIONAL

# %%
test_csv_header_df = pd.DataFrame()
test_csv_header_df = _get_csv_headers(_filename)  #Resident,39 #Household,5
test_csv_header_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-8aacf2e0e1ef> in <module>()
#       1 test_csv_header_df = pd.DataFrame()
# ----> 2 test_csv_header_df = _get_csv_headers(_filename)  #Resident,39 #Household,5
#       3 test_csv_header_df
#
# NameError: name '_filename' is not defined

# %% [markdown]
# ## GET FIELDS FOR EACH FILENAME -- ITERATION OF FILENAME

# %%
test_meta_header_df[test_meta_header_df['file_name'] == _filename ]

# %%
test_field_name = test_meta_header_df[test_meta_header_df['file_name'] == _filename ]['field_name']
test_list_field_name = list(test_field_name)
test_list_field_name

# %% [markdown]
# ## *NEW* GET REQUIRED DATA ALGO -- NO ITERATION

# %%
test_required_header_list = [] 
test_required_header_list = set(test_source_data_df['key']) & set(test_list_field_name)
test_source_data_df = test_source_data_df[test_source_data_df['key'].isin(test_required_header_list)]
test_source_data_df

# %% [markdown]
# ## GET REQUIRED DATA -- deprecated

# %%
test_new_data_df = pd.DataFrame()
test_new_data_df = _get_required_data(test_source_data_df, test_csv_header_df)
test_new_data_df

# %% [markdown]
# ## RENAME REQUIRED DATA

# %%
test_new_data_df = _rename_index(test_source_data_df)
test_new_data_df

# %% [markdown]
# ## COLUMNAR TO ROW REQIURED DATA

# %%
test_new_data_df = _new_columnar_to_row(test_new_data_df, test_csv_header_df)
test_new_data_df

# %% [markdown]
# ## WRITE TO CSV

# %%
test_new_data_df = _write_to_csv(test_new_data_df, _filename)
test_new_data_df

# %% [markdown]
# ## MAPPING FIELDS

# %%
## =================================================

# %%
## Get Index_map unique values

# %%
## BUG: IF ADDRESS IS 
'''
    "answers": {
        "Address": [{
            "Location": {
                "Street": ["12312", "234234"],
                "City": "City"
            }
        }],
'''
