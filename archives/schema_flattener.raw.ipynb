# %%
import logging
import json
import csv
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize 
from pandas import read_csv
from functools import reduce
from collections import defaultdict

# %% [markdown]
# ## Configuration

# %%
#etl = 'kobo2elastic'
etl = 'curis2elastic'
#etl = 'oldcuris2newcuris'

input_schema_file = ''
input_data_file = ''
mapping_file = ''

output_dir = 'file/curisSchema/'

if etl == 'curis2elastic':
    #old curis to elasticsearch
    input_schema_file = 'schema/input/curisSchema.1-item.json'
    input_data_file = 'data/curisData.1-items.json'
    mapping_file = 'schema/map/couchbase2elastic.map.csv'
elif etl == 'kobo2elastic':
    #kobo to elasticsearch
    input_schema_file = 'schema/input/aqmSchema.complete.json'
    input_data_file = 'data/aqmData.2-items.json'
    mapping_file = 'schema/map/kobo2elastic.map.csv'
elif etl == 'oldcuris2newcuris':
    #kobo to elasticsearch
    input_schema_file = 'schema/input/curisData.1-Schema.avro.json'
    input_data_file = 'data/curisData.1-items.json'
    mapping_file = 'schema/map/kobo2elastic.map.csv'

# %% [markdown]
# ## Get input JSON Schema (draft 07)

# %%
schema_data = {}
schema_df = pd.DataFrame()

with open(input_schema_file) as f:
    schema_data = json.load(f)

schema_df = json_normalize(schema_data)
schema_df.T
# Out:
#                                                                                                     0
# $id                                                                      http://example.com/root.json
# $schema                                                       http://json-schema.org/draft-07/schema#
# properties.address.$id                                                           #/properties/address
# properties.address.properties.barangay.$id                   #/properties/address/properties/barangay
# properties.address.properties.barangay.pattern                                                 ^(.*)$
# properties.address.properties.barangay.title                                      The Barangay Schema
# properties.address.properties.barangay.type                                                    string
# properties.address.properties.country.$id                     #/properties/address/properties/country
# properties.address.properties.country.pattern                                                  ^(.*)$
# properties.address.properties.country.title                                        The Country Schema
# properties.address.properties.country.type                                                     string
# properties.address.properties.lot_or_house_numb...  #/properties/address/properties/lot_or_house_n...
# properties.address.properties.lot_or_house_numb...                                             ^(.*)$
# properties.address.properties.lot_or_house_numb...                     The Lot_or_house_number Schema
# properties.address.properties.lot_or_house_numb...                                             string
# properties.address.properties.postal_code.$id             #/properties/address/properties/postal_code
# properties.address.properties.postal_code.pattern                                              ^(.*)$
# properties.address.properties.postal_code.title                                The Postal_code Schema
# properties.address.properties.postal_code.type                                                 string
# properties.address.properties.province.$id                   #/properties/address/properties/province
# properties.address.properties.province.pattern                                                 ^(.*)$
# properties.address.properties.province.title                                      The Province Schema
# properties.address.properties.province.type                                                    string
# properties.address.title                                                           The Address Schema
# properties.address.type                                                                        object
# properties.awh_id.$id                                                             #/properties/awh_id
# properties.awh_id.pattern                                                                      ^(.*)$
# properties.awh_id.title                                                             The Awh_id Schema
# properties.awh_id.type                                                                         string
# properties.birthdate.$id                                                       #/properties/birthdate
# ...                                                                                               ...
# properties.profiles.items.properties.employment...                                             object
# properties.profiles.items.properties.religion.$id     #/properties/profiles/items/properties/religion
# properties.profiles.items.properties.religion.p...                                             ^(.*)$
# properties.profiles.items.properties.religion.t...                                The Religion Schema
# properties.profiles.items.properties.religion.type                                             string
# properties.profiles.items.title                                                      The Items Schema
# properties.profiles.items.type                                                                 object
# properties.profiles.title                                                         The Profiles Schema
# properties.profiles.type                                                                        array
# properties.registered_at.$id                                               #/properties/registered_at
# properties.registered_at.pattern                                                               ^(.*)$
# properties.registered_at.title                                               The Registered_at Schema
# properties.registered_at.type                                                                  string
# properties.type.$id                                                                 #/properties/type
# properties.type.pattern                                                                        ^(.*)$
# properties.type.title                                                                 The Type Schema
# properties.type.type                                                                           string
# properties.user-cam.$id                                                         #/properties/user-cam
# properties.user-cam.properties.id.$id                             #/properties/user-cam/properties/id
# properties.user-cam.properties.id.pattern                                                      ^(.*)$
# properties.user-cam.properties.id.title                                                 The Id Schema
# properties.user-cam.properties.id.type                                                         string
# properties.user-cam.properties.owner.$id                       #/properties/user-cam/properties/owner
# properties.user-cam.properties.owner.pattern                                                   ^(.*)$
# properties.user-cam.properties.owner.title                                           The Owner Schema
# properties.user-cam.properties.owner.type                                                      string
# properties.user-cam.title                                                         The User-cam Schema
# properties.user-cam.type                                                                       object
# title                                                                                 The Root Schema
# type                                                                                           object
#
# [348 rows x 1 columns]

# %% [markdown]
# ## Get valid index List only (for JSON Schema Only)

# %%
required_index_list = []
required_field_df = pd.DataFrame()

for indexList in list(schema_df):
    if "._" not in indexList:
        if len(indexList.split(sep='.')) > 2:
            if indexList.split(sep='.')[-1] == 'type' or indexList.split(sep='.')[-1] == 'title':
                required_index_list.append(indexList)

# %%
required_field_df = schema_df[required_index_list]
required_field_df.T
# Out:
#                                                                                  0
# properties.address.properties.barangay.title                   The Barangay Schema
# properties.address.properties.barangay.type                                 string
# properties.address.properties.country.title                     The Country Schema
# properties.address.properties.country.type                                  string
# properties.address.properties.lot_or_house_numb...  The Lot_or_house_number Schema
# properties.address.properties.lot_or_house_numb...                          string
# properties.address.properties.postal_code.title             The Postal_code Schema
# properties.address.properties.postal_code.type                              string
# properties.address.properties.province.title                   The Province Schema
# properties.address.properties.province.type                                 string
# properties.address.title                                        The Address Schema
# properties.address.type                                                     object
# properties.awh_id.title                                          The Awh_id Schema
# properties.awh_id.type                                                      string
# properties.birthdate.title                                    The Birthdate Schema
# properties.birthdate.type                                                   string
# properties.contact_number.properties.country_co...         The Country_code Schema
# properties.contact_number.properties.country_co...                          string
# properties.contact_number.properties.number.title                The Number Schema
# properties.contact_number.properties.number.type                            string
# properties.contact_number.title                          The Contact_number Schema
# properties.contact_number.type                                              object
# properties.date_visits.items.title                                The Items Schema
# properties.date_visits.items.type                                           string
# properties.date_visits.title                                The Date_visits Schema
# properties.date_visits.type                                                  array
# properties.email_address.title                            The Email_address Schema
# properties.email_address.type                                               string
# properties.family_members.items.title                             The Items Schema
# properties.family_members.items.type                                        string
# ...                                                                            ...
# properties.profiles.items.properties.civil_stat...         The Civil_status Schema
# properties.profiles.items.properties.civil_stat...                          string
# properties.profiles.items.properties.date_updat...         The Date_updated Schema
# properties.profiles.items.properties.date_updat...                          string
# properties.profiles.items.properties.education....            The Education Schema
# properties.profiles.items.properties.education....                          string
# properties.profiles.items.properties.employment...          The Is_employed Schema
# properties.profiles.items.properties.employment...                         boolean
# properties.profiles.items.properties.employment...       The Monthly_income Schema
# properties.profiles.items.properties.employment...                          string
# properties.profiles.items.properties.employment...               The Nature Schema
# properties.profiles.items.properties.employment...                          string
# properties.profiles.items.properties.employment...           The Employment Schema
# properties.profiles.items.properties.employment...                          object
# properties.profiles.items.properties.religion.t...             The Religion Schema
# properties.profiles.items.properties.religion.type                          string
# properties.profiles.items.title                                   The Items Schema
# properties.profiles.items.type                                              object
# properties.profiles.title                                      The Profiles Schema
# properties.profiles.type                                                     array
# properties.registered_at.title                            The Registered_at Schema
# properties.registered_at.type                                               string
# properties.type.title                                              The Type Schema
# properties.type.type                                                        string
# properties.user-cam.properties.id.title                              The Id Schema
# properties.user-cam.properties.id.type                                      string
# properties.user-cam.properties.owner.title                        The Owner Schema
# properties.user-cam.properties.owner.type                                   string
# properties.user-cam.title                                      The User-cam Schema
# properties.user-cam.type                                                    object
#
# [188 rows x 1 columns]

# %% [markdown]
# ## Clean value and index

# %%
def clean_value(x):
    return x.lower().replace("/", ".").replace("the", "").replace("schema", "").strip()

def clean_index(x):
    return x.lower().replace("/", ".").replace("properties.", "").replace("items.", "").strip()

newSchema_df = pd.DataFrame()
newSchema_df['value'] = required_field_df.T[0].apply(clean_value)
newSchema_df.reset_index(level=0, inplace=True)
newSchema_df['index'] = newSchema_df['index'].apply(clean_index)
newSchema_df.sort_values(['index'])
newSchema_df.head(60)
# Out:
#                                                 index                value
# 0                              address.barangay.title             barangay
# 1                               address.barangay.type               string
# 2                               address.country.title              country
# 3                                address.country.type               string
# 4                   address.lot_or_house_number.title  lot_or_house_number
# 5                    address.lot_or_house_number.type               string
# 6                           address.postal_code.title          postal_code
# 7                            address.postal_code.type               string
# 8                              address.province.title             province
# 9                               address.province.type               string
# 10                                      address.title              address
# 11                                       address.type               object
# 12                                       awh_id.title               awh_id
# 13                                        awh_id.type               string
# 14                                    birthdate.title            birthdate
# 15                                     birthdate.type               string
# 16                  contact_number.country_code.title         country_code
# 17                   contact_number.country_code.type               string
# 18                        contact_number.number.title               number
# 19                         contact_number.number.type               string
# 20                               contact_number.title       contact_number
# 21                                contact_number.type               object
# 22                                  date_visits.title                items
# 23                                   date_visits.type               string
# 24                                  date_visits.title          date_visits
# 25                                   date_visits.type                array
# 26                                email_address.title        email_address
# 27                                 email_address.type               string
# 28                               family_members.title                items
# 29                                family_members.type               string
# 30                               family_members.title       family_members
# 31                                family_members.type                array
# 32                                   first_name.title           first_name
# 33                                    first_name.type               string
# 34                                       gender.title               gender
# 35                                        gender.type               string
# 36                health_informations.allergies.title            allergies
# 37                 health_informations.allergies.type               string
# 38  health_informations.blood_pressure.first_readi...             diastole
# 39  health_informations.blood_pressure.first_readi...               string
# 40  health_informations.blood_pressure.first_readi...              systole
# 41  health_informations.blood_pressure.first_readi...               string
# 42  health_informations.blood_pressure.first_readi...        first_reading
# 43  health_informations.blood_pressure.first_readi...               object
# 44  health_informations.blood_pressure.second_read...             diastole
# 45  health_informations.blood_pressure.second_read...               string
# 46  health_informations.blood_pressure.second_read...              systole
# 47  health_informations.blood_pressure.second_read...               string
# 48  health_informations.blood_pressure.second_read...       second_reading
# 49  health_informations.blood_pressure.second_read...               object
# 50  health_informations.blood_pressure.third_readi...             diastole
# 51  health_informations.blood_pressure.third_readi...               string
# 52  health_informations.blood_pressure.third_readi...              systole
# 53  health_informations.blood_pressure.third_readi...               string
# 54  health_informations.blood_pressure.third_readi...        third_reading
# 55  health_informations.blood_pressure.third_readi...               object
# 56           health_informations.blood_pressure.title       blood_pressure
# 57            health_informations.blood_pressure.type               object
# 58               health_informations.blood_sign.title           blood_sign
# 59                health_informations.blood_sign.type               string

# %% [markdown]
# ## Create columns for type and key

# %%
valueSchema_df = pd.DataFrame()

number = len(newSchema_df)
index = 0
counter = 0
counter1 = 1

array_key = []
array_type = []

while (counter < number):
    array_key.append(newSchema_df.iloc[counter]['index'].replace('.title',''))
    counter += 2
        
while (counter1 < number):
    array_type.append(newSchema_df.iloc[counter1]['value'])
    counter1 += 2

valueSchema_df['source_key'] = array_key
valueSchema_df['source_type'] = array_type

valueSchema_df = valueSchema_df.sort_values(['source_key']).reset_index(drop=True)
valueSchema_df.loc[valueSchema_df['source_type'] == 'array']

csv_filename_df = pd.DataFrame()
csv_filename_df = valueSchema_df.loc[valueSchema_df['source_type'] == 'array']
#list(csv_filename_df['source_key'])
csv_filename_df = csv_filename_df.reset_index(drop=True)
csv_filename_df
# Out:
#                               source_key source_type
# 0                            date_visits       array
# 1                         family_members       array
# 2                    health_informations       array
# 3          health_informations.diagnosed       array
# 4     health_informations.family_history       array
# 5                             households       array
# 6  households.amenities_present_in_house       array
# 7               households.sanitary_type       array
# 8                               profiles       array

# %% [markdown]
# ## Create root or default file (e.g. main, resident)

# %%
with open(output_dir + 'resident.csv', 'w'):
    pass
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-935-42e8a1855e7b> in <module>()
# ----> 1 with open(output_dir + 'resident.csv', 'w'):
#       2     pass
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file/curisSchema/resident.csv'

# %% [markdown]
# ## Create separate file for each array

# %%
csv_filename_list = []
csv_filename_list = list(csv_filename_df['source_key']) #array type

for i in list(csv_filename_list):
    with open('file/' + i + '.csv', 'w'):
        pass

# %%
csv_header_name_df = pd.DataFrame()
csv_header_name_df = valueSchema_df.loc[valueSchema_df['source_type'] == 'string']

csv_header_name_list = []
csv_header_name_list = list(csv_header_name_df['source_key']) #string type

# %% [markdown]
# ## Segregate headers for every field type

# %%
main_headers = []
array_headers = []
object_header = []

for header in csv_header_name_list:
    for filename in csv_filename_list:
        tmp_header = header.split(sep='.')
        #print(tmp_header)
        if(len(tmp_header)) > 1:
            #pass
            #print(tmp_header[:-1])
            #tmp_string = '.'.join(tmp_header[:-1])
            tmp_string = header
            
            #print(tmp_string)
            
            #print('============')
            if tmp_string == filename: #for array list
                #print('---array_list---')
                #print(header)
                #print('--header/field: ' + tmp_string + ' == --filename: ' + filename)
                array_headers.append(header)
        elif(len(tmp_header)) == 1:
            tmp_string = header
            if tmp_string == filename:
                array_headers.append(header)
            else:
                #print(tmp_header)
                main_headers.append(header)

# %% [markdown]
# ## Write headers for type: lists

# %%
for header in array_headers:
    array_csv_df  = pd.DataFrame(columns=[ header,'_id','_index_map'])
    array_csv_df.to_csv(output_dir + header + '.csv', encoding='utf-8', mode='a', index=False)

# %% [markdown]
# ## TODO filter other primitive type

# %%
primitive_header_list = []
primitive_header_df = pd.DataFrame() 
primitive_header_df = valueSchema_df.loc[valueSchema_df['source_type'] == 'string']
primitive_header_list = list(primitive_header_df['source_key'])
primitive_header_list = set(primitive_header_list) - set(array_headers) #exclude list of string
primitive_header_list

# %% [markdown]
# ## Create headers for type: array of objects and primitive type (int, str) @object level

# %%
array_objects = set()
array_objects = set(csv_header_name_list) - set(csv_filename_list) - set(main_headers)
array_objects_list = list(array_objects)
array_objects_list

# %% [markdown]
# ## TODO: make nested iterative

# %%
non_root_header_object = []
root_header_object = []

for name in array_objects_list:
    str1 = name.split('.')
    str2 = '.'.join(str1[0:-1])
    #print(str2)
    if str2 in csv_filename_list:
        non_root_header_object.append(name)
    else:
        root_header_object.append(name)
        
root_header_object

# %% [markdown]
# ## Non-root object type

# %%
dd_non_root = defaultdict(list)
for header in non_root_header_object:
    filenames = header.split(sep=".")[0:-1]
    filenames = '.'.join(filenames)
    dd_non_root[filenames].append(header)
    
dd_non_root

# %% [markdown]
# ## Root object type

# %%
dd_root = defaultdict(list)
for header in root_header_object:
    filenames = header.split(sep=".")[0:1]
    filenames = '.'.join(filenames)
    
    if filenames in csv_filename_list:
        #print(filenames)
        dd_non_root[filenames].append(header)
    else:
        dd_root['resident'].append(header)

list(dd_root['resident'])

# %% [markdown]
# ## Write headers for type: array of object

# %%
for header in dd:
    columns_list = []
    columns_list = list(dd_non_root[header])
    columns_list.append('_id')
    columns_list.append('_index_map')
    object_array_csv_df  = pd.DataFrame(columns=columns_list)
    object_array_csv_df.to_csv(output_dir + header + '.csv', encoding='utf-8', mode='a', index=False)

# %% [markdown]
# ## Get headers for type: object

# %%
objects_header_list = []
objects_header_df = pd.DataFrame()
objects_header_df = valueSchema_df.loc[valueSchema_df['source_type'] == 'object']
objects_header_list = list(objects_header_df['source_key'])
objects_header_list

# %% [markdown]
# ## Get header for type: string @root level

# %%
main_header_list = []
main_header_list = list(dict.fromkeys(main_headers))
main_header_list =  list(set(main_header_list) - set(array_headers)) #exclude list of string
main_header_list

# %% [markdown]
# ## Combine and Get headers for type: primitive and object @root level

# %%
main_header_list += (list(dd_root['resident']))
main_header_list

# %%
main_header_list.append('_id')
main_header_list.append('_index_map')

# %%
main_resident_df  = pd.DataFrame(columns = main_header_list)
main_resident_df.to_csv(output_dir + 'resident.csv', encoding='utf-8', mode='a', index=False)
main_resident_df

# %% [markdown]
# ## Write schema definitions into a text

# %%
array_headers

# %%
filenames_list = array_headers + list(dd_non_root) 
#filenames_list = list(dd_non_root) 
filenames_list.append('resident')

foo = ",".join(filenames_list)
foo

# %%
schema_desc_df = pd.DataFrame()

# %%
schema_desc_df['file_name'] = [foo]
schema_desc_df['file_count']  = len(filenames_list)
schema_desc_df['date'] = pd.to_datetime('today')
schema_desc_df['source_schema'] = input_schema_file 
schema_desc_df['version'] = '1.0'
schema_desc_df

# %%
schema_desc_df.to_csv(output_dir + 'schema.csv', encoding='utf-8', mode='w', index=False)
