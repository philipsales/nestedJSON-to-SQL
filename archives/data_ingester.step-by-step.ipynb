# %%
import numpy as np
import pandas as pd
import json
from pandas.io.json import json_normalize 
from pandas import read_csv
import logging
from functools import reduce
import csv

# %%
## Configuration

# %%
#etl = 'kobo2elastic'
#etl = 'curis2elastic'
#etl = 'oldcuris2newcuris'
etl = 'isabela2newaqm'
#etl = 'cambodia2newaqm'

input_schema_file = ''
input_data_file = ''
mapping_file = ''

root_object = 'resident'

if etl == 'curis2elastic':
    #old curis to elasticsearch
    input_schema_file = 'schema/input/curisSchema.1-item.json'
    input_data_file = 'data/curisData.1-items.json'
    mapping_file = 'schema/map/couchbase2elastic.map.csv'
    output_dir = 'file/curisSchema/'
    
elif etl == 'kobo2elastic':
    #kobo to elasticsearch
    input_schema_file = 'schema/input/koboSchema.1-item.json'
    input_data_file = 'data/koboData.2-items.json'
    mapping_file = 'schema/map/kobo2elastic.map.csv'
    output_dir = 'file/koboSchema/'
    
elif etl == 'oldcuris2newcuris':
    #kobo to elasticsearch
    input_schema_file = 'schema/input/curisSchema.1-item.json'
    input_data_file = 'data/curisData.1-item.json'
    mapping_file = 'schema/map/kobo2elastic.map.csv'
    output_dir = 'file/curisSchema/'
    
elif etl == 'cambodia2newaqm':
    #kobo to elasticsearch
    input_schema_file = 'schema/input/KHMSchema.json'
    input_data_file = 'data/KHM.3-items.json'
    mapping_file = 'schema/map/kobo2elastic.map.csv'
    output_dir = 'file/KHMSchema/'

elif etl == 'isabela2newaqm':
    #kobo to elasticsearch
    input_schema_file = 'schema/input/curisSchema.1-item.json'
    input_data_file = 'data/Isabela.2-items.json'
    mapping_file = 'schema/map/Isabela2newAQM.map.csv'
    #output_dir = 'file/IsabelaSchema/'
    output_dir = 'data/processed/couchbase-curis-2019-06-21/'

# %%
def _open_file():
    with open(input_data_file) as f:
        return json.load(f)

# %%
def _flatten_json(nested_json):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '.')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + '' + str(i) + '.')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(nested_json)
    return out

# %%
def _dict_to_dataframe(dict_object):
    return pd.DataFrame.from_dict({'value': dict_object})

# %%
## OPTIMIZE TO ACCEPT LIST NOT DATAFRAME
def filter_key(x):
    lists = format_key(x)
    lists = exclude_digit(lists)
    lists = list2string(lists)
    return lists

def filter_index_map(x):
    lists = format_key(x)
    lists = include_digit(lists)
    lists = list2string(lists)
    return lists

def format_key(items):
    #return list(map(lambda x:x.lower().split(sep='.'), items ))
    return items.lower().split(sep='.')

def include_digit(items):
    return [item for item in items if item.isdigit()]

def exclude_digit(items):
    return [item for item in items if not item.isdigit()]

def list2string(lists):
    return '.'.join(lists)

# %%
def _add_custom_colums(dataframe_object):
    dataframe_object['key'] = list(dataframe_object.index)
    dataframe_object['key'] = dataframe_object['key'].apply(filter_key)
    #print('_add_custom_columns ',dataframe_object[dataframe_object['key'] == 'id' ])

    
    #TODO: musbe adjusted dynamically
    
    #CHECK if single object or array of objects
    #formid == koboschema
    #id == curischema
    #dataframe_object['_id'] = dataframe_object[dataframe_object['key'] == 'formid' ]['value'].values[0]
    
    #IF oldcursi2newcuris
    dataframe_object['_id'] = dataframe_object[dataframe_object['key'] == 'id' ]['value'].values[0]
    #IF KHMSChema
    #dataframe_object['_id'] = dataframe_object[dataframe_object['key'] == '_id' ]['value'].values[0]
    
    dataframe_object['_index_map'] = list(dataframe_object.index)
    dataframe_object['_index_map'] = dataframe_object['_index_map'].apply(filter_index_map)
    #print(dataframe_object)
    dataframe_object = dataframe_object.reset_index(drop=True)

    return dataframe_object

# %%
## File loader

# %%
def _get_mapping_fields():
    _mapping_df = pd.DataFrame()
    _mapping_df = read_csv(mapping_file).sort_values(['source_key'])

    _required_mapping_fields = list(_mapping_df['source_key'])
    return _required_mapping_fields

# %%
def _get_index_map(data_df):
    return list(data_df['_index_map'].unique())

# %%
def _filter_by_indexmap(data_df, index):
    return data_df[data_df['_index_map'] == index ]

# %%
def clean_value(x):
    return x.lower().replace("/", ".").replace("the", "").replace("schema", "").strip()

# %%
def _get_filenames():
    schema_csv = pd.read_csv(output_dir + 'schema.csv', skiprows=0)
    return schema_csv['file_name'].values[0].split(sep=",")

# %%
def _get_csv_headers(filename):
    return pd.read_csv( output_dir + filename + '.csv',nrows=0) #get header only

# %%
def _get_required_data(input_data_df,csv_header_df):
    
    required_header_list = [] 

    for data in input_data_df['key']:
        
        if data in csv_header_df.columns:
            
            required_header_list.append(data)
    
    #print(required_header_list)
    
    return input_data_df[input_data_df['key'].isin(required_header_list)]

# %%
def _rename_index(data_df):
    if 'key' in data_df.columns:
        data_df.index = list(data_df['key'])
        data_df = data_df.drop('key', axis=1)
    return data_df

# %%
def _columnar_to_row(input_data_df,csv_header_df):
    
    for header in list(input_data_df.index):
        if header:
            csv_header_df.at['',header] = input_data_df.loc[header]['value'] 
    

        csv_header_df.at['','_id'] = input_data_df['_id'][header] 
        csv_header_df.at['','_index_map'] = input_data_df['_index_map'][header] 
    return csv_header_df

# %%
def _write_to_csv(data_csv_df, filename):
    return data_csv_df.to_csv(output_dir + filename + '.csv', encoding='utf-8', mode='a', header=False,index=False)

# %% [markdown]
# ## OPEN DATA FROM FILE

# %%
data_list = []
data_list = _open_file()
data_list
# Out:
# [{'_sync': {'history': {'channels': [None, None, None, None, None, None],
#     'parents': [5, -1, 1, 2, 3, 4],
#     'revs': ['6-de6706bf00721558205d0f5651901f94',
#      '1-e86d3945fadafa4f84f5e478841809d1',
#      '2-c4096a64f5e91372cc97daeded4955dc',
#      '3-a03d7327410cd5b1e0638a8f9b8bd388',
#      '4-4df5f344f4a781868812806b76e50a87',
#      '5-218399a922e1f7ffbe64107b4508f5a0']},
#    'recent_sequences': [33481],
#    'rev': '6-de6706bf00721558205d0f5651901f94',
#    'sequence': 33481,
#    'time_saved': '2018-08-21T07:42:41.523087917Z'},
#   'address': {'barangay': 'Bangad',
#    'country': 'Philippines',
#    'lot_or_house_number': '',
#    'postal_code': '3330',
#    'province': 'Isabela'},
#   'birthdate': '08/09/1989',
#   'contact_number': {'country_code': '+63', 'number': None},
#   'profiles': [{'civil_status': 'Single',
#     'date_updated': '07/02/2018 at 08:44:13 PM GMT+08:00',
#     'education': 'Masters Level',
#     'employment': {'is_employed': True,
#      'monthly_income': 'Php12.00',
#      'nature': 'empty'},
#     'religion': 'Islam'}],
#   'email_address': None,
#   'family_members': [],
#   'first_name': 'First Name',
#   'gender': 'Female',
#   'health_informations': [],
#   'households': [{'amenities_present_in_house': ['Electricity',
#      'Proper Ventilation',
#      'Water Supply'],
#     'date_updated': '07/02/2018 at 08:44:13 PM GMT+08:00',
#     'house_ownership': 'Owned',
#     'neighborhood_description': 'Rural',
#     'no_of_families_in_the_household': 0,
#     'no_of_people_in_the_household': 0,
#     'sanitary_ownership': 'Owned',
#     'sanitary_type': ['Pail'],
#     'type_of_house': 'Concrete-based'}],
#   'id': '64c2e7de-0cc8-4df5-a54f-02398652c080',
#   'identification': {'id1': {'identifier': None, 'type': '4Ps'},
#    'id2': {'identifier': None, 'type': '4Ps'},
#    'id3': {'identifier': None, 'type': '4Ps'}},
#   'last_name': 'Last Name Jeprox',
#   'last_name_suffix': '',
#   'middle_name': 'Middle Name Jeprox',
#   'nhid': '',
#   'organization': 'Santa Maria Isabela RHU',
#   'profile_picture': {'name': '273381f8-91db-43ab-a246-f3110bb7467f',
#    'path': '/data/data/com.awh.health.curis/app_images/images_resident'},
#   'registered_at': '08/16/2018 at 10:25:07 PM GMT+08:00',
#   'type': 'user-resident',
#   'user-cam': {'id': 'aguzman@gmail.com', 'owner': 'aguzman@gmail.com'}},
#  {'_sync': {'history': {'channels': [None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None],
#     'parents': [10, 11, 5, 0, 7, 1, 12, -1, 4, 8, 9, 3, 2, 6],
#     'revs': ['6-8c1d02c2e0e74568dabbc8eb0395585e',
#      '9-d59d17a4c956ca08f4b53630da3b124f',
#      '11-893d05656f9bc7e6639a111962200da0',
#      '7-cc3cc75985a4f2d0eac45e989fe99ee4',
#      '2-0d245c3d93d995af0224232ff0af02c1',
#      '10-6c066e918950f3cc19c5711d2adf4fb8',
#      '13-1bea5fb37f8073db203f3fcefe0ffe00',
#      '1-324fd52ba47c2f7242a03857407fafaf',
#      '3-8e37fb725ff36449f27dccab0a00ba78',
#      '4-02ced616dbfb339146ed3bc3692b15a1',
#      '5-d216302e71b3a269cdaf826ecaf87132',
#      '8-7565dbaae7992ffff4556fca5fefd470',
#      '12-fdf28a6bc1e13534e679ea0bc396dcbd',
#      '14-967fd34c42dd304a2eb964e0ec4a0ff8']},
#    'recent_sequences': [26439],
#    'rev': '14-967fd34c42dd304a2eb964e0ec4a0ff8',
#    'sequence': 26439,
#    'time_saved': '2018-07-24T08:52:57.462382644Z'},
#   'address': {'barangay': 'Bangad',
#    'country': 'Philippines',
#    'lot_or_house_number': '',
#    'postal_code': '3330',
#    'province': 'Isabela'},
#   'profiles': [{'civil_status': 'Single',
#     'date_updated': '03/02/2008 at 08:44:13 PM GMT+08:00',
#     'education': 'Undergraduate Level',
#     'employment': {'is_employed': False,
#      'monthly_income': '',
#      'nature': 'empty'},
#     'religion': 'Islam'}],
#   'birthdate': '12/23/1975',
#   'contact_number': {'country_code': '+63', 'number': None},
#   'email_address': None,
#   'family_members': ['2f920d39-319e-4bf7-90c8-6133c3337af7'],
#   'first_name': '',
#   'gender': 'Male',
#   'health_informations': [],
#   'households': [{'house_ownership': 'Owned Not',
#     'neighborhood_description': 'Urban',
#     'no_of_families_in_the_household': 0,
#     'no_of_people_in_the_household': 0,
#     'sanitary_ownership': 'Owned Not',
#     'sanitary_type': ['Pail'],
#     'type_of_house': 'Concrete-based'}],
#   'id': '2f920d39-319e-4bf7-90c8-6133c3337af7',
#   'identification': {'id1': {'identifier': None, 'type': '4Ps'},
#    'id2': {'identifier': None, 'type': '4Ps'},
#    'id3': {'identifier': None, 'type': '4Ps'}},
#   'last_name': '"Raphy Canceran TO DELETE"',
#   'last_name_suffix': '',
#   'middle_name': 'Laddran',
#   'nhid': '',
#   'organization': 'Santa Maria Isabela RHU',
#   'profile_picture': {'name': '76f8ac01-f75f-4850-be41-3f368f7b1da7',
#    'path': '/data/data/com.awh.health.curis/app_images/images_resident'},
#   'registered_at': '07/12/2018 at 10:54:14 PM GMT+08:00',
#   'type': 'user-resident',
#   'user-cam': {'id': 'csoriano@gmail.com', 'owner': 'csoriano@gmail.com'}}]

# %% [markdown]
# ## FLATTEN JSON FILE -- ITERATE DATA HERE

# %%
datum = data_list[1]
test_data_flat_dict = _flatten_json(datum)  
test_data_flat_dict
# Out:
# {'_sync.history.channels.0': None,
#  '_sync.history.channels.1': None,
#  '_sync.history.channels.2': None,
#  '_sync.history.channels.3': None,
#  '_sync.history.channels.4': None,
#  '_sync.history.channels.5': None,
#  '_sync.history.channels.6': None,
#  '_sync.history.channels.7': None,
#  '_sync.history.channels.8': None,
#  '_sync.history.channels.9': None,
#  '_sync.history.channels.10': None,
#  '_sync.history.channels.11': None,
#  '_sync.history.channels.12': None,
#  '_sync.history.channels.13': None,
#  '_sync.history.parents.0': 10,
#  '_sync.history.parents.1': 11,
#  '_sync.history.parents.2': 5,
#  '_sync.history.parents.3': 0,
#  '_sync.history.parents.4': 7,
#  '_sync.history.parents.5': 1,
#  '_sync.history.parents.6': 12,
#  '_sync.history.parents.7': -1,
#  '_sync.history.parents.8': 4,
#  '_sync.history.parents.9': 8,
#  '_sync.history.parents.10': 9,
#  '_sync.history.parents.11': 3,
#  '_sync.history.parents.12': 2,
#  '_sync.history.parents.13': 6,
#  '_sync.history.revs.0': '6-8c1d02c2e0e74568dabbc8eb0395585e',
#  '_sync.history.revs.1': '9-d59d17a4c956ca08f4b53630da3b124f',
#  '_sync.history.revs.2': '11-893d05656f9bc7e6639a111962200da0',
#  '_sync.history.revs.3': '7-cc3cc75985a4f2d0eac45e989fe99ee4',
#  '_sync.history.revs.4': '2-0d245c3d93d995af0224232ff0af02c1',
#  '_sync.history.revs.5': '10-6c066e918950f3cc19c5711d2adf4fb8',
#  '_sync.history.revs.6': '13-1bea5fb37f8073db203f3fcefe0ffe00',
#  '_sync.history.revs.7': '1-324fd52ba47c2f7242a03857407fafaf',
#  '_sync.history.revs.8': '3-8e37fb725ff36449f27dccab0a00ba78',
#  '_sync.history.revs.9': '4-02ced616dbfb339146ed3bc3692b15a1',
#  '_sync.history.revs.10': '5-d216302e71b3a269cdaf826ecaf87132',
#  '_sync.history.revs.11': '8-7565dbaae7992ffff4556fca5fefd470',
#  '_sync.history.revs.12': '12-fdf28a6bc1e13534e679ea0bc396dcbd',
#  '_sync.history.revs.13': '14-967fd34c42dd304a2eb964e0ec4a0ff8',
#  '_sync.recent_sequences.0': 26439,
#  '_sync.rev': '14-967fd34c42dd304a2eb964e0ec4a0ff8',
#  '_sync.sequence': 26439,
#  '_sync.time_saved': '2018-07-24T08:52:57.462382644Z',
#  'address.barangay': 'Bangad',
#  'address.country': 'Philippines',
#  'address.lot_or_house_number': '',
#  'address.postal_code': '3330',
#  'address.province': 'Isabela',
#  'profiles.0.civil_status': 'Single',
#  'profiles.0.date_updated': '03/02/2008 at 08:44:13 PM GMT+08:00',
#  'profiles.0.education': 'Undergraduate Level',
#  'profiles.0.employment.is_employed': False,
#  'profiles.0.employment.monthly_income': '',
#  'profiles.0.employment.nature': 'empty',
#  'profiles.0.religion': 'Islam',
#  'birthdate': '12/23/1975',
#  'contact_number.country_code': '+63',
#  'contact_number.number': None,
#  'email_address': None,
#  'family_members.0': '2f920d39-319e-4bf7-90c8-6133c3337af7',
#  'first_name': '',
#  'gender': 'Male',
#  'households.0.house_ownership': 'Owned Not',
#  'households.0.neighborhood_description': 'Urban',
#  'households.0.no_of_families_in_the_household': 0,
#  'households.0.no_of_people_in_the_household': 0,
#  'households.0.sanitary_ownership': 'Owned Not',
#  'households.0.sanitary_type.0': 'Pail',
#  'households.0.type_of_house': 'Concrete-based',
#  'id': '2f920d39-319e-4bf7-90c8-6133c3337af7',
#  'identification.id1.identifier': None,
#  'identification.id1.type': '4Ps',
#  'identification.id2.identifier': None,
#  'identification.id2.type': '4Ps',
#  'identification.id3.identifier': None,
#  'identification.id3.type': '4Ps',
#  'last_name': '"Raphy Canceran TO DELETE"',
#  'last_name_suffix': '',
#  'middle_name': 'Laddran',
#  'nhid': '',
#  'organization': 'Santa Maria Isabela RHU',
#  'profile_picture.name': '76f8ac01-f75f-4850-be41-3f368f7b1da7',
#  'profile_picture.path': '/data/data/com.awh.health.curis/app_images/images_resident',
#  'registered_at': '07/12/2018 at 10:54:14 PM GMT+08:00',
#  'type': 'user-resident',
#  'user-cam.id': 'csoriano@gmail.com',
#  'user-cam.owner': 'csoriano@gmail.com'}

# %% [markdown]
# ## Dictionary TO DATAFRAME

# %%
test_data_flat_df = _dict_to_dataframe(test_data_flat_dict)
test_data_flat_df
# Out:
#                                                                                           value
# _sync.history.channels.0                                                                   None
# _sync.history.channels.1                                                                   None
# _sync.history.channels.10                                                                  None
# _sync.history.channels.11                                                                  None
# _sync.history.channels.12                                                                  None
# _sync.history.channels.13                                                                  None
# _sync.history.channels.2                                                                   None
# _sync.history.channels.3                                                                   None
# _sync.history.channels.4                                                                   None
# _sync.history.channels.5                                                                   None
# _sync.history.channels.6                                                                   None
# _sync.history.channels.7                                                                   None
# _sync.history.channels.8                                                                   None
# _sync.history.channels.9                                                                   None
# _sync.history.parents.0                                                                      10
# _sync.history.parents.1                                                                      11
# _sync.history.parents.10                                                                      9
# _sync.history.parents.11                                                                      3
# _sync.history.parents.12                                                                      2
# _sync.history.parents.13                                                                      6
# _sync.history.parents.2                                                                       5
# _sync.history.parents.3                                                                       0
# _sync.history.parents.4                                                                       7
# _sync.history.parents.5                                                                       1
# _sync.history.parents.6                                                                      12
# _sync.history.parents.7                                                                      -1
# _sync.history.parents.8                                                                       4
# _sync.history.parents.9                                                                       8
# _sync.history.revs.0                                         6-8c1d02c2e0e74568dabbc8eb0395585e
# _sync.history.revs.1                                         9-d59d17a4c956ca08f4b53630da3b124f
# ...                                                                                         ...
# households.0.no_of_families_in_the_household                                                  0
# households.0.no_of_people_in_the_household                                                    0
# households.0.sanitary_ownership                                                       Owned Not
# households.0.sanitary_type.0                                                               Pail
# households.0.type_of_house                                                       Concrete-based
# id                                                         2f920d39-319e-4bf7-90c8-6133c3337af7
# identification.id1.identifier                                                              None
# identification.id1.type                                                                     4Ps
# identification.id2.identifier                                                              None
# identification.id2.type                                                                     4Ps
# identification.id3.identifier                                                              None
# identification.id3.type                                                                     4Ps
# last_name                                                            "Raphy Canceran TO DELETE"
# last_name_suffix
# middle_name                                                                             Laddran
# nhid
# organization                                                            Santa Maria Isabela RHU
# profile_picture.name                                       76f8ac01-f75f-4850-be41-3f368f7b1da7
# profile_picture.path                          /data/data/com.awh.health.curis/app_images/ima...
# profiles.0.civil_status                                                                  Single
# profiles.0.date_updated                                     03/02/2008 at 08:44:13 PM GMT+08:00
# profiles.0.education                                                        Undergraduate Level
# profiles.0.employment.is_employed                                                         False
# profiles.0.employment.monthly_income
# profiles.0.employment.nature                                                              empty
# profiles.0.religion                                                                       Islam
# registered_at                                               07/12/2018 at 10:54:14 PM GMT+08:00
# type                                                                              user-resident
# user-cam.id                                                                  csoriano@gmail.com
# user-cam.owner                                                               csoriano@gmail.com
#
# [90 rows x 1 columns]

# %% [markdown]
# ## ADD CUSTOM COLUMNS WITHOUT MAPPING

# %%
_customed_data_flat_df = _add_custom_colums(test_data_flat_df)
_customed_data_flat_df
# Out:
#                                                 value  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                                 10
# 15                                                 11
# 16                                                  9
# 17                                                  3
# 18                                                  2
# 19                                                  6
# 20                                                  5
# 21                                                  0
# 22                                                  7
# 23                                                  1
# 24                                                 12
# 25                                                 -1
# 26                                                  4
# 27                                                  8
# 28                 6-8c1d02c2e0e74568dabbc8eb0395585e
# 29                 9-d59d17a4c956ca08f4b53630da3b124f
# ..                                                ...
# 60                                                  0
# 61                                                  0
# 62                                          Owned Not
# 63                                               Pail
# 64                                     Concrete-based
# 65               2f920d39-319e-4bf7-90c8-6133c3337af7
# 66                                               None
# 67                                                4Ps
# 68                                               None
# 69                                                4Ps
# 70                                               None
# 71                                                4Ps
# 72                         "Raphy Canceran TO DELETE"
# 73
# 74                                            Laddran
# 75
# 76                            Santa Maria Isabela RHU
# 77               76f8ac01-f75f-4850-be41-3f368f7b1da7
# 78  /data/data/com.awh.health.curis/app_images/ima...
# 79                                             Single
# 80                03/02/2008 at 08:44:13 PM GMT+08:00
# 81                                Undergraduate Level
# 82                                              False
# 83
# 84                                              empty
# 85                                              Islam
# 86                07/12/2018 at 10:54:14 PM GMT+08:00
# 87                                      user-resident
# 88                                 csoriano@gmail.com
# 89                                 csoriano@gmail.com
#
#                                            key  \
# 0                       _sync.history.channels
# 1                       _sync.history.channels
# 2                       _sync.history.channels
# 3                       _sync.history.channels
# 4                       _sync.history.channels
# 5                       _sync.history.channels
# 6                       _sync.history.channels
# 7                       _sync.history.channels
# 8                       _sync.history.channels
# 9                       _sync.history.channels
# 10                      _sync.history.channels
# 11                      _sync.history.channels
# 12                      _sync.history.channels
# 13                      _sync.history.channels
# 14                       _sync.history.parents
# 15                       _sync.history.parents
# 16                       _sync.history.parents
# 17                       _sync.history.parents
# 18                       _sync.history.parents
# 19                       _sync.history.parents
# 20                       _sync.history.parents
# 21                       _sync.history.parents
# 22                       _sync.history.parents
# 23                       _sync.history.parents
# 24                       _sync.history.parents
# 25                       _sync.history.parents
# 26                       _sync.history.parents
# 27                       _sync.history.parents
# 28                          _sync.history.revs
# 29                          _sync.history.revs
# ..                                         ...
# 60  households.no_of_families_in_the_household
# 61    households.no_of_people_in_the_household
# 62               households.sanitary_ownership
# 63                    households.sanitary_type
# 64                    households.type_of_house
# 65                                          id
# 66               identification.id1.identifier
# 67                     identification.id1.type
# 68               identification.id2.identifier
# 69                     identification.id2.type
# 70               identification.id3.identifier
# 71                     identification.id3.type
# 72                                   last_name
# 73                            last_name_suffix
# 74                                 middle_name
# 75                                        nhid
# 76                                organization
# 77                        profile_picture.name
# 78                        profile_picture.path
# 79                       profiles.civil_status
# 80                       profiles.date_updated
# 81                          profiles.education
# 82             profiles.employment.is_employed
# 83          profiles.employment.monthly_income
# 84                  profiles.employment.nature
# 85                           profiles.religion
# 86                               registered_at
# 87                                        type
# 88                                 user-cam.id
# 89                              user-cam.owner
#
#                                      _id _index_map
# 0   2f920d39-319e-4bf7-90c8-6133c3337af7          0
# 1   2f920d39-319e-4bf7-90c8-6133c3337af7          1
# 2   2f920d39-319e-4bf7-90c8-6133c3337af7         10
# 3   2f920d39-319e-4bf7-90c8-6133c3337af7         11
# 4   2f920d39-319e-4bf7-90c8-6133c3337af7         12
# 5   2f920d39-319e-4bf7-90c8-6133c3337af7         13
# 6   2f920d39-319e-4bf7-90c8-6133c3337af7          2
# 7   2f920d39-319e-4bf7-90c8-6133c3337af7          3
# 8   2f920d39-319e-4bf7-90c8-6133c3337af7          4
# 9   2f920d39-319e-4bf7-90c8-6133c3337af7          5
# 10  2f920d39-319e-4bf7-90c8-6133c3337af7          6
# 11  2f920d39-319e-4bf7-90c8-6133c3337af7          7
# 12  2f920d39-319e-4bf7-90c8-6133c3337af7          8
# 13  2f920d39-319e-4bf7-90c8-6133c3337af7          9
# 14  2f920d39-319e-4bf7-90c8-6133c3337af7          0
# 15  2f920d39-319e-4bf7-90c8-6133c3337af7          1
# 16  2f920d39-319e-4bf7-90c8-6133c3337af7         10
# 17  2f920d39-319e-4bf7-90c8-6133c3337af7         11
# 18  2f920d39-319e-4bf7-90c8-6133c3337af7         12
# 19  2f920d39-319e-4bf7-90c8-6133c3337af7         13
# 20  2f920d39-319e-4bf7-90c8-6133c3337af7          2
# 21  2f920d39-319e-4bf7-90c8-6133c3337af7          3
# 22  2f920d39-319e-4bf7-90c8-6133c3337af7          4
# 23  2f920d39-319e-4bf7-90c8-6133c3337af7          5
# 24  2f920d39-319e-4bf7-90c8-6133c3337af7          6
# 25  2f920d39-319e-4bf7-90c8-6133c3337af7          7
# 26  2f920d39-319e-4bf7-90c8-6133c3337af7          8
# 27  2f920d39-319e-4bf7-90c8-6133c3337af7          9
# 28  2f920d39-319e-4bf7-90c8-6133c3337af7          0
# 29  2f920d39-319e-4bf7-90c8-6133c3337af7          1
# ..                                   ...        ...
# 60  2f920d39-319e-4bf7-90c8-6133c3337af7          0
# 61  2f920d39-319e-4bf7-90c8-6133c3337af7          0
# 62  2f920d39-319e-4bf7-90c8-6133c3337af7          0
# 63  2f920d39-319e-4bf7-90c8-6133c3337af7        0.0
# 64  2f920d39-319e-4bf7-90c8-6133c3337af7          0
# 65  2f920d39-319e-4bf7-90c8-6133c3337af7
# 66  2f920d39-319e-4bf7-90c8-6133c3337af7
# 67  2f920d39-319e-4bf7-90c8-6133c3337af7
# 68  2f920d39-319e-4bf7-90c8-6133c3337af7
# 69  2f920d39-319e-4bf7-90c8-6133c3337af7
# 70  2f920d39-319e-4bf7-90c8-6133c3337af7
# 71  2f920d39-319e-4bf7-90c8-6133c3337af7
# 72  2f920d39-319e-4bf7-90c8-6133c3337af7
# 73  2f920d39-319e-4bf7-90c8-6133c3337af7
# 74  2f920d39-319e-4bf7-90c8-6133c3337af7
# 75  2f920d39-319e-4bf7-90c8-6133c3337af7
# 76  2f920d39-319e-4bf7-90c8-6133c3337af7
# 77  2f920d39-319e-4bf7-90c8-6133c3337af7
# 78  2f920d39-319e-4bf7-90c8-6133c3337af7
# 79  2f920d39-319e-4bf7-90c8-6133c3337af7          0
# 80  2f920d39-319e-4bf7-90c8-6133c3337af7          0
# 81  2f920d39-319e-4bf7-90c8-6133c3337af7          0
# 82  2f920d39-319e-4bf7-90c8-6133c3337af7          0
# 83  2f920d39-319e-4bf7-90c8-6133c3337af7          0
# 84  2f920d39-319e-4bf7-90c8-6133c3337af7          0
# 85  2f920d39-319e-4bf7-90c8-6133c3337af7          0
# 86  2f920d39-319e-4bf7-90c8-6133c3337af7
# 87  2f920d39-319e-4bf7-90c8-6133c3337af7
# 88  2f920d39-319e-4bf7-90c8-6133c3337af7
# 89  2f920d39-319e-4bf7-90c8-6133c3337af7
#
# [90 rows x 4 columns]

# %% [markdown]
# ## GET REQUIRED MAPPING

# %%
_required_mapping_fields = []
_required_mapping_fields = _get_mapping_fields()
_required_mapping_fields
# Out:
# ['address.province',
#  'birthdate',
#  'contact_number.number',
#  'email_address',
#  'family_members',
#  'first_name',
#  'gender',
#  'households.house_ownership',
#  'households.neighborhood_description',
#  'households.sanitary_ownership',
#  'id',
#  'last_name',
#  'middle_name',
#  'profiles.civil_status',
#  'registered_at',
#  'user-cam.id',
#  nan]

# %% [markdown]
# ## FILTER ONLY REQUIRED MAPPING FROM RAW FLAT DATA

# %%
_customed_data_flat_df = _customed_data_flat_df[_customed_data_flat_df['key'].isin(_required_mapping_fields)]
_customed_data_flat_df
# Out:
#                                    value                                  key  \
# 50                               Isabela                     address.province
# 51                            12/23/1975                            birthdate
# 53                                  None                contact_number.number
# 54                                  None                        email_address
# 55  2f920d39-319e-4bf7-90c8-6133c3337af7                       family_members
# 56                                                                 first_name
# 57                                  Male                               gender
# 58                             Owned Not           households.house_ownership
# 59                                 Urban  households.neighborhood_description
# 62                             Owned Not        households.sanitary_ownership
# 65  2f920d39-319e-4bf7-90c8-6133c3337af7                                   id
# 72            "Raphy Canceran TO DELETE"                            last_name
# 74                               Laddran                          middle_name
# 79                                Single                profiles.civil_status
# 86   07/12/2018 at 10:54:14 PM GMT+08:00                        registered_at
# 88                    csoriano@gmail.com                          user-cam.id
#
#                                      _id _index_map
# 50  2f920d39-319e-4bf7-90c8-6133c3337af7
# 51  2f920d39-319e-4bf7-90c8-6133c3337af7
# 53  2f920d39-319e-4bf7-90c8-6133c3337af7
# 54  2f920d39-319e-4bf7-90c8-6133c3337af7
# 55  2f920d39-319e-4bf7-90c8-6133c3337af7          0
# 56  2f920d39-319e-4bf7-90c8-6133c3337af7
# 57  2f920d39-319e-4bf7-90c8-6133c3337af7
# 58  2f920d39-319e-4bf7-90c8-6133c3337af7          0
# 59  2f920d39-319e-4bf7-90c8-6133c3337af7          0
# 62  2f920d39-319e-4bf7-90c8-6133c3337af7          0
# 65  2f920d39-319e-4bf7-90c8-6133c3337af7
# 72  2f920d39-319e-4bf7-90c8-6133c3337af7
# 74  2f920d39-319e-4bf7-90c8-6133c3337af7
# 79  2f920d39-319e-4bf7-90c8-6133c3337af7          0
# 86  2f920d39-319e-4bf7-90c8-6133c3337af7
# 88  2f920d39-319e-4bf7-90c8-6133c3337af7

# %% [markdown]
# ## GET HEADERS THRU META DATA

# %%
test_meta_header_df = pd.read_csv( 'data/processed/couchbase-curis-2019-06-21/_meta.csv')
test_meta_header_df
# Out:
#      file_name                           field_name field_type
# 0   households             households.type_of_house     string
# 1   households           households.house_ownership     string
# 2   households        households.sanitary_ownership     string
# 3   households  households.neighborhood_description     string
# 4     profiles                profiles.civil_status     string
# 5     resident                          middle_name     string
# 6     resident                            birthdate     string
# 7     resident                                   id     string
# 8     resident                                 type     string
# 9     resident                           first_name     string
# 10    resident                            last_name     string
# 11    resident                     last_name_suffix     string
# 12    resident                         organization     string
# 13    resident                                 nhid     string
# 14    resident                               gender     string
# 15    resident                        registered_at     string
# 16    resident                  address.postal_code     string
# 17    resident                      address.country     string
# 18    resident                     address.barangay     string
# 19    resident              identification.id3.type     string
# 20    resident          address.lot_or_house_number     string
# 21    resident                     address.province     string
# 22    resident              identification.id1.type     string
# 23    resident              identification.id2.type     string
# 24    resident                 profile_picture.path     string
# 25    resident                contact_number.number     string
# 26    resident                          user-cam.id     string
# 27    resident          contact_number.country_code     string
# 28    resident                 profile_picture.name     string
# 29    resident        identification.id2.identifier     string
# 30    resident        identification.id3.identifier     string
# 31    resident        identification.id1.identifier     string
# 32    resident                       user-cam.owner     string

# %% [markdown]
# ## GET UNIQUE FILENAME -- ITERATION

# %%
_filename_list = list(test_meta_header_df['file_name'].unique())
_filename_list
# Out:
# ['households', 'profiles', 'resident']

# %%
_filename = _filename_list[2]
_filename
# Out:
# 'resident'

# %% [markdown]
# ## GET ALL UNIQUE INDEX MAP -- ITERATION

# %%
test_index_map =  list(_customed_data_flat_df['_index_map'].unique())
test_index_map
# Out:
# ['', '0']

# %%
_test_index_map = test_index_map[0]
_test_index_map
# Out:
# ''

# %% [markdown]
# ## FILTER ONLY REQUIRED  DATA ACCORDING TO INDEX MAP

# %%
test_source_data_df = pd.DataFrame()
test_source_data_df = _filter_by_indexmap(_customed_data_flat_df, _test_index_map)
test_source_data_df
# Out:
#                                    value                    key  \
# 50                               Isabela       address.province
# 51                            12/23/1975              birthdate
# 53                                  None  contact_number.number
# 54                                  None          email_address
# 56                                                   first_name
# 57                                  Male                 gender
# 65  2f920d39-319e-4bf7-90c8-6133c3337af7                     id
# 72            "Raphy Canceran TO DELETE"              last_name
# 74                               Laddran            middle_name
# 86   07/12/2018 at 10:54:14 PM GMT+08:00          registered_at
# 88                    csoriano@gmail.com            user-cam.id
#
#                                      _id _index_map
# 50  2f920d39-319e-4bf7-90c8-6133c3337af7
# 51  2f920d39-319e-4bf7-90c8-6133c3337af7
# 53  2f920d39-319e-4bf7-90c8-6133c3337af7
# 54  2f920d39-319e-4bf7-90c8-6133c3337af7
# 56  2f920d39-319e-4bf7-90c8-6133c3337af7
# 57  2f920d39-319e-4bf7-90c8-6133c3337af7
# 65  2f920d39-319e-4bf7-90c8-6133c3337af7
# 72  2f920d39-319e-4bf7-90c8-6133c3337af7
# 74  2f920d39-319e-4bf7-90c8-6133c3337af7
# 86  2f920d39-319e-4bf7-90c8-6133c3337af7
# 88  2f920d39-319e-4bf7-90c8-6133c3337af7

# %% [markdown]
# ## CLEAN FILTERED BY INDEX_MAP #Cleaning is for '/' in cambodia schema

# %%
test_source_data_df['key'].apply(clean_value)
test_source_data_df
# Out:
#                                    value                    key  \
# 50                               Isabela       address.province
# 51                            12/23/1975              birthdate
# 53                                  None  contact_number.number
# 54                                  None          email_address
# 56                                                   first_name
# 57                                  Male                 gender
# 65  2f920d39-319e-4bf7-90c8-6133c3337af7                     id
# 72            "Raphy Canceran TO DELETE"              last_name
# 74                               Laddran            middle_name
# 86   07/12/2018 at 10:54:14 PM GMT+08:00          registered_at
# 88                    csoriano@gmail.com            user-cam.id
#
#                                      _id _index_map
# 50  2f920d39-319e-4bf7-90c8-6133c3337af7
# 51  2f920d39-319e-4bf7-90c8-6133c3337af7
# 53  2f920d39-319e-4bf7-90c8-6133c3337af7
# 54  2f920d39-319e-4bf7-90c8-6133c3337af7
# 56  2f920d39-319e-4bf7-90c8-6133c3337af7
# 57  2f920d39-319e-4bf7-90c8-6133c3337af7
# 65  2f920d39-319e-4bf7-90c8-6133c3337af7
# 72  2f920d39-319e-4bf7-90c8-6133c3337af7
# 74  2f920d39-319e-4bf7-90c8-6133c3337af7
# 86  2f920d39-319e-4bf7-90c8-6133c3337af7
# 88  2f920d39-319e-4bf7-90c8-6133c3337af7

# %% [markdown]
# ## GET FIELDS FOR EACH FILENAME -- ITERATION OF FILENAME

# %%
test_meta_header_df[test_meta_header_df['file_name'] == _filename ]
# Out:
#    file_name                     field_name field_type
# 5   resident                    middle_name     string
# 6   resident                      birthdate     string
# 7   resident                             id     string
# 8   resident                           type     string
# 9   resident                     first_name     string
# 10  resident                      last_name     string
# 11  resident               last_name_suffix     string
# 12  resident                   organization     string
# 13  resident                           nhid     string
# 14  resident                         gender     string
# 15  resident                  registered_at     string
# 16  resident            address.postal_code     string
# 17  resident                address.country     string
# 18  resident               address.barangay     string
# 19  resident        identification.id3.type     string
# 20  resident    address.lot_or_house_number     string
# 21  resident               address.province     string
# 22  resident        identification.id1.type     string
# 23  resident        identification.id2.type     string
# 24  resident           profile_picture.path     string
# 25  resident          contact_number.number     string
# 26  resident                    user-cam.id     string
# 27  resident    contact_number.country_code     string
# 28  resident           profile_picture.name     string
# 29  resident  identification.id2.identifier     string
# 30  resident  identification.id3.identifier     string
# 31  resident  identification.id1.identifier     string
# 32  resident                 user-cam.owner     string

# %%
test_list_field_name = list(test_meta_header_df[test_meta_header_df['file_name'] == _filename ]['field_name'])
test_list_field_name
# Out:
# ['middle_name',
#  'birthdate',
#  'id',
#  'type',
#  'first_name',
#  'last_name',
#  'last_name_suffix',
#  'organization',
#  'nhid',
#  'gender',
#  'registered_at',
#  'address.postal_code',
#  'address.country',
#  'address.barangay',
#  'identification.id3.type',
#  'address.lot_or_house_number',
#  'address.province',
#  'identification.id1.type',
#  'identification.id2.type',
#  'profile_picture.path',
#  'contact_number.number',
#  'user-cam.id',
#  'contact_number.country_code',
#  'profile_picture.name',
#  'identification.id2.identifier',
#  'identification.id3.identifier',
#  'identification.id1.identifier',
#  'user-cam.owner']

# %% [markdown]
# ## *NEW* GET REQUIRED DATA ALGO -- NO ITERATION

# %%
test_required_header_list = [] 
test_required_header_list = set(test_source_data_df['key']) & set(test_list_field_name)
test_source_data_df = test_source_data_df[test_source_data_df['key'].isin(test_required_header_list)]
test_source_data_df
# Out:
#                                    value                    key  \
# 50                               Isabela       address.province
# 51                            12/23/1975              birthdate
# 53                                  None  contact_number.number
# 56                                                   first_name
# 57                                  Male                 gender
# 65  2f920d39-319e-4bf7-90c8-6133c3337af7                     id
# 72            "Raphy Canceran TO DELETE"              last_name
# 74                               Laddran            middle_name
# 86   07/12/2018 at 10:54:14 PM GMT+08:00          registered_at
# 88                    csoriano@gmail.com            user-cam.id
#
#                                      _id _index_map
# 50  2f920d39-319e-4bf7-90c8-6133c3337af7
# 51  2f920d39-319e-4bf7-90c8-6133c3337af7
# 53  2f920d39-319e-4bf7-90c8-6133c3337af7
# 56  2f920d39-319e-4bf7-90c8-6133c3337af7
# 57  2f920d39-319e-4bf7-90c8-6133c3337af7
# 65  2f920d39-319e-4bf7-90c8-6133c3337af7
# 72  2f920d39-319e-4bf7-90c8-6133c3337af7
# 74  2f920d39-319e-4bf7-90c8-6133c3337af7
# 86  2f920d39-319e-4bf7-90c8-6133c3337af7
# 88  2f920d39-319e-4bf7-90c8-6133c3337af7

# %% [markdown]
# ## ===== WRITE DATA ======

# %% [markdown]
# ## GET CSV HEADERS OF EACH FILENAME

# %%
test_csv_header_df = pd.DataFrame()
test_csv_header_df = _get_csv_headers(_filename)  #Resident,39 #Household,5
test_csv_header_df
# Out:
# Empty DataFrame
# Columns: [_id, _index_map, middle_name, birthdate, id, type, first_name, last_name, last_name_suffix, organization, nhid, gender, registered_at, address.postal_code, address.country, address.barangay, identification.id3.type, address.lot_or_house_number, address.province, identification.id1.type, identification.id2.type, profile_picture.path, contact_number.number, user-cam.id, contact_number.country_code, profile_picture.name, identification.id2.identifier, identification.id3.identifier, identification.id1.identifier, user-cam.owner]
# Index: []
#
# [0 rows x 30 columns]

# %% [markdown]
# ## GET REQUIRED DATA -- deprecated

# %%
#test_new_data_df = pd.DataFrame()
#test_new_data_df = _get_required_data(test_source_data_df, test_csv_header_df)
#test_new_data_df

# %% [markdown]
# ## RENAME REQUIRED DATA

# %%
test_new_data_df = _rename_index(test_source_data_df)
test_new_data_df
# Out:
#                                                       value  \
# address.province                                    Isabela
# birthdate                                        12/23/1975
# contact_number.number                                  None
# first_name
# gender                                                 Male
# id                     2f920d39-319e-4bf7-90c8-6133c3337af7
# last_name                        "Raphy Canceran TO DELETE"
# middle_name                                         Laddran
# registered_at           07/12/2018 at 10:54:14 PM GMT+08:00
# user-cam.id                              csoriano@gmail.com
#
#                                                         _id _index_map
# address.province       2f920d39-319e-4bf7-90c8-6133c3337af7
# birthdate              2f920d39-319e-4bf7-90c8-6133c3337af7
# contact_number.number  2f920d39-319e-4bf7-90c8-6133c3337af7
# first_name             2f920d39-319e-4bf7-90c8-6133c3337af7
# gender                 2f920d39-319e-4bf7-90c8-6133c3337af7
# id                     2f920d39-319e-4bf7-90c8-6133c3337af7
# last_name              2f920d39-319e-4bf7-90c8-6133c3337af7
# middle_name            2f920d39-319e-4bf7-90c8-6133c3337af7
# registered_at          2f920d39-319e-4bf7-90c8-6133c3337af7
# user-cam.id            2f920d39-319e-4bf7-90c8-6133c3337af7

# %% [markdown]
# ## COLUMNAR TO ROW REQIURED DATA

# %%
test_new_data_df = _new_columnar_to_row(test_new_data_df, test_csv_header_df)
test_new_data_df
# Out:
#                                    _id _index_map middle_name   birthdate  \
#   2f920d39-319e-4bf7-90c8-6133c3337af7                Laddran  12/23/1975
#
#                                     id type first_name  \
#   2f920d39-319e-4bf7-90c8-6133c3337af7  NaN
#
#                    last_name last_name_suffix organization      ...        \
#   "Raphy Canceran TO DELETE"              NaN          NaN      ...
#
#  identification.id2.type profile_picture.path contact_number.number  \
#                      NaN                  NaN                  None
#
#          user-cam.id contact_number.country_code profile_picture.name  \
#   csoriano@gmail.com                         NaN                  NaN
#
#  identification.id2.identifier identification.id3.identifier  \
#                            NaN                           NaN
#
#  identification.id1.identifier user-cam.owner
#                            NaN            NaN
#
# [1 rows x 30 columns]

# %% [markdown]
# ## WRITE TO CSV

# %%
test_new_data_df = _write_to_csv(test_new_data_df, _filename)
test_new_data_df

# %% [markdown]
# ## MAPPING FIELDS

# %%
## =================================================

# %%
## Get Index_map unique values

# %%
## BUG: IF ADDRESS IS 
'''
    "answers": {
        "Address": [{
            "Location": {
                "Street": ["12312", "234234"],
                "City": "City"
            }
        }],
'''
# Out:
# '\n    "answers": {\n        "Address": [{\n            "Location": {\n                "Street": ["12312", "234234"],\n                "City": "City"\n            }\n        }],\n'
