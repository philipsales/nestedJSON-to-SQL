# %%
import json

import numpy as np
import pandas as pd
from pandas.io.json import json_normalize 
import logging

from functools import reduce

import itertools
import random
import psycopg2
from psycopg2.extras import Json
from sqlalchemy import create_engine, MetaData
import io
import pandas_profiling

# %% [markdown]
# ## Get output JSON SChema

# %%
with open("schema/output/elasticSchema.json") as f:
    d = json.load(f)

schema_df = pd.DataFrame()
schema_df = json_normalize(d)
schema_df
# Out:
#   demographics.properties.active.type  \
# 0                             boolean
#
#   demographics.properties.address.properties.add_date.type  \
# 0                                               date
#
#   demographics.properties.address.properties.commnty.type  \
# 0                                            keyword
#
#   demographics.properties.address.properties.country.type  \
# 0                                            keyword
#
#   demographics.properties.address.properties.province.type  \
# 0                                            keyword
#
#   demographics.properties.address.properties.zip.type  \
# 0                                            keyword
#
#   demographics.properties.address.type  \
# 0                               object
#
#   demographics.properties.are_you_currently_earning.type  \
# 0                                            keyword
#
#   demographics.properties.awh_id.type  \
# 0                             keyword
#
#   demographics.properties.birth_date.format  \
# 0                  MM/dd/yyyy || yyyy-MM-dd
#
#                        ...                        \
# 0                      ...
#
#   demographics.properties.employed.properties.m_income.type  \
# 0                                              float
#
#   demographics.properties.employed.properties.nature.type  \
# 0                                            keyword
#
#   demographics.properties.employed.type demographics.properties.org.type  \
# 0                                object                          keyword
#
#   demographics.properties.religion.type demographics.properties.sex.type  \
# 0                               keyword                          keyword
#
#   demographics.properties.version.properties.date.type  \
# 0                                               date
#
#   demographics.properties.version.properties.number.type  \
# 0                                            integer
#
#   demographics.properties.version.type  \
# 0                               object
#
#   demographics.properties.where_income_from.type
# 0                                        keyword
#
# [1 rows x 28 columns]

# %%
list(schema_df)
# Out:
# ['$id',
#  '$schema',
#  'items.properties.__version__.pattern',
#  'items.properties.__version__.title',
#  'items.properties.__version__.type',
#  'items.properties._attachments.title',
#  'items.properties._attachments.type',
#  'items.properties._bamboo_dataset_id.pattern',
#  'items.properties._bamboo_dataset_id.title',
#  'items.properties._bamboo_dataset_id.type',
#  'items.properties._geolocation.items.title',
#  'items.properties._geolocation.items.type',
#  'items.properties._geolocation.title',
#  'items.properties._geolocation.type',
#  'items.properties._id.title',
#  'items.properties._id.type',
#  'items.properties._notes.title',
#  'items.properties._notes.type',
#  'items.properties._status.pattern',
#  'items.properties._status.title',
#  'items.properties._status.type',
#  'items.properties._submission_time.pattern',
#  'items.properties._submission_time.title',
#  'items.properties._submission_time.type',
#  'items.properties._submitted_by.title',
#  'items.properties._submitted_by.type',
#  'items.properties._tags.title',
#  'items.properties._tags.type',
#  'items.properties._uuid.pattern',
#  'items.properties._uuid.title',
#  'items.properties._uuid.type',
#  'items.properties._validation_status.title',
#  'items.properties._validation_status.type',
#  'items.properties._version_.pattern',
#  'items.properties._version_.title',
#  'items.properties._version_.type',
#  'items.properties._xform_id_string.pattern',
#  'items.properties._xform_id_string.title',
#  'items.properties._xform_id_string.type',
#  'items.properties.dental_health/family_dental_problems.pattern',
#  'items.properties.dental_health/family_dental_problems.title',
#  'items.properties.dental_health/family_dental_problems.type',
#  'items.properties.dental_health/last_6_months_dental_fam_probl.pattern',
#  'items.properties.dental_health/last_6_months_dental_fam_probl.title',
#  'items.properties.dental_health/last_6_months_dental_fam_probl.type',
#  'items.properties.dental_health/owning_toothbrush.pattern',
#  'items.properties.dental_health/owning_toothbrush.title',
#  'items.properties.dental_health/owning_toothbrush.type',
#  'items.properties.dental_health/times_brush_teeth_daily.pattern',
#  'items.properties.dental_health/times_brush_teeth_daily.title',
#  'items.properties.dental_health/times_brush_teeth_daily.type',
#  'items.properties.dental_health/used_for_cleaning_teeth.pattern',
#  'items.properties.dental_health/used_for_cleaning_teeth.title',
#  'items.properties.dental_health/used_for_cleaning_teeth.type',
#  'items.properties.disability/types_of_disability.pattern',
#  'items.properties.disability/types_of_disability.title',
#  'items.properties.disability/types_of_disability.type',
#  'items.properties.do_you_consent_AWH.pattern',
#  'items.properties.do_you_consent_AWH.title',
#  'items.properties.do_you_consent_AWH.type',
#  'items.properties.end.pattern',
#  'items.properties.end.title',
#  'items.properties.end.type',
#  'items.properties.formhub/uuid.pattern',
#  'items.properties.formhub/uuid.title',
#  'items.properties.formhub/uuid.type',
#  'items.properties.health_information/alcohol_within_week.pattern',
#  'items.properties.health_information/alcohol_within_week.title',
#  'items.properties.health_information/alcohol_within_week.type',
#  'items.properties.health_information/blood_pressure_1st_diastole.pattern',
#  'items.properties.health_information/blood_pressure_1st_diastole.title',
#  'items.properties.health_information/blood_pressure_1st_diastole.type',
#  'items.properties.health_information/blood_pressure_1st_systole.pattern',
#  'items.properties.health_information/blood_pressure_1st_systole.title',
#  'items.properties.health_information/blood_pressure_1st_systole.type',
#  'items.properties.health_information/blood_pressure_2nd_diastole.pattern',
#  'items.properties.health_information/blood_pressure_2nd_diastole.title',
#  'items.properties.health_information/blood_pressure_2nd_diastole.type',
#  'items.properties.health_information/blood_pressure_2nd_systole.pattern',
#  'items.properties.health_information/blood_pressure_2nd_systole.title',
#  'items.properties.health_information/blood_pressure_2nd_systole.type',
#  'items.properties.health_information/considering_self_with_disabili.pattern',
#  'items.properties.health_information/considering_self_with_disabili.title',
#  'items.properties.health_information/considering_self_with_disabili.type',
#  'items.properties.health_information/diagnosed.pattern',
#  'items.properties.health_information/diagnosed.title',
#  'items.properties.health_information/diagnosed.type',
#  'items.properties.health_information/exercise_within_week.pattern',
#  'items.properties.health_information/exercise_within_week.title',
#  'items.properties.health_information/exercise_within_week.type',
#  'items.properties.health_information/family_history.pattern',
#  'items.properties.health_information/family_history.title',
#  'items.properties.health_information/family_history.type',
#  'items.properties.health_information/fruits_within_week.pattern',
#  'items.properties.health_information/fruits_within_week.title',
#  'items.properties.health_information/fruits_within_week.type',
#  'items.properties.health_information/has_health_insurance_plan.pattern',
#  'items.properties.health_information/has_health_insurance_plan.title',
#  'items.properties.health_information/has_health_insurance_plan.type',
#  'items.properties.health_information/height.pattern',
#  'items.properties.health_information/height.title',
#  'items.properties.health_information/height.type',
#  'items.properties.health_information/how_taking_prescribed_dose.pattern',
#  'items.properties.health_information/how_taking_prescribed_dose.title',
#  'items.properties.health_information/how_taking_prescribed_dose.type',
#  'items.properties.health_information/smoking_habit.pattern',
#  'items.properties.health_information/smoking_habit.title',
#  'items.properties.health_information/smoking_habit.type',
#  'items.properties.health_information/taking_long_term_meds.pattern',
#  'items.properties.health_information/taking_long_term_meds.title',
#  'items.properties.health_information/taking_long_term_meds.type',
#  'items.properties.health_information/traditional_medicine.pattern',
#  'items.properties.health_information/traditional_medicine.title',
#  'items.properties.health_information/traditional_medicine.type',
#  'items.properties.health_information/travel_for_medicine.pattern',
#  'items.properties.health_information/travel_for_medicine.title',
#  'items.properties.health_information/travel_for_medicine.type',
#  'items.properties.health_information/vegetable_within_week.pattern',
#  'items.properties.health_information/vegetable_within_week.title',
#  'items.properties.health_information/vegetable_within_week.type',
#  'items.properties.health_information/waist_circumference.pattern',
#  'items.properties.health_information/waist_circumference.title',
#  'items.properties.health_information/waist_circumference.type',
#  'items.properties.health_information/weight.pattern',
#  'items.properties.health_information/weight.title',
#  'items.properties.health_information/weight.type',
#  'items.properties.household/amenities.pattern',
#  'items.properties.household/amenities.title',
#  'items.properties.household/amenities.type',
#  'items.properties.household/ensuring_water_is_safe.pattern',
#  'items.properties.household/ensuring_water_is_safe.title',
#  'items.properties.household/ensuring_water_is_safe.type',
#  'items.properties.household/house_construction.pattern',
#  'items.properties.household/house_construction.title',
#  'items.properties.household/house_construction.type',
#  'items.properties.household/mostly_used_to_wash_hands.pattern',
#  'items.properties.household/mostly_used_to_wash_hands.title',
#  'items.properties.household/mostly_used_to_wash_hands.type',
#  'items.properties.household/no_of_people_household.pattern',
#  'items.properties.household/no_of_people_household.title',
#  'items.properties.household/no_of_people_household.type',
#  'items.properties.household/sanitation_ownership.pattern',
#  'items.properties.household/sanitation_ownership.title',
#  'items.properties.household/sanitation_ownership.type',
#  'items.properties.household/type_of_sanitation.pattern',
#  'items.properties.household/type_of_sanitation.title',
#  'items.properties.household/type_of_sanitation.type',
#  'items.properties.household/water_sources.pattern',
#  'items.properties.household/water_sources.title',
#  'items.properties.household/water_sources.type',
#  'items.properties.identity_consent/cam_account.pattern',
#  'items.properties.identity_consent/cam_account.title',
#  'items.properties.identity_consent/cam_account.type',
#  'items.properties.identity_consent/country.pattern',
#  'items.properties.identity_consent/country.title',
#  'items.properties.identity_consent/country.type',
#  'items.properties.identity_consent/identity_document.pattern',
#  'items.properties.identity_consent/identity_document.title',
#  'items.properties.identity_consent/identity_document.type',
#  'items.properties.identity_consent/organization.pattern',
#  'items.properties.identity_consent/organization.title',
#  'items.properties.identity_consent/organization.type',
#  'items.properties.identity_consent/personal_id_no.pattern',
#  'items.properties.identity_consent/personal_id_no.title',
#  'items.properties.identity_consent/personal_id_no.type',
#  'items.properties.identity_consent/questions_to_be_asked.pattern',
#  'items.properties.identity_consent/questions_to_be_asked.title',
#  'items.properties.identity_consent/questions_to_be_asked.type',
#  'items.properties.identity_consent/region.pattern',
#  'items.properties.identity_consent/region.title',
#  'items.properties.identity_consent/region.type',
#  'items.properties.identity_consent/town.pattern',
#  'items.properties.identity_consent/town.title',
#  'items.properties.identity_consent/town.type',
#  'items.properties.meta/instanceID.pattern',
#  'items.properties.meta/instanceID.title',
#  'items.properties.meta/instanceID.type',
#  'items.properties.personal_info/address_line_1.pattern',
#  'items.properties.personal_info/address_line_1.title',
#  'items.properties.personal_info/address_line_1.type',
#  'items.properties.personal_info/address_line_2.pattern',
#  'items.properties.personal_info/address_line_2.title',
#  'items.properties.personal_info/address_line_2.type',
#  'items.properties.personal_info/civil_status.pattern',
#  'items.properties.personal_info/civil_status.title',
#  'items.properties.personal_info/civil_status.type',
#  'items.properties.personal_info/currency.pattern',
#  'items.properties.personal_info/currency.title',
#  'items.properties.personal_info/currency.type',
#  'items.properties.personal_info/date_of_birth.pattern',
#  'items.properties.personal_info/date_of_birth.title',
#  'items.properties.personal_info/date_of_birth.type',
#  'items.properties.personal_info/first_name.pattern',
#  'items.properties.personal_info/first_name.title',
#  'items.properties.personal_info/first_name.type',
#  'items.properties.personal_info/gender.pattern',
#  'items.properties.personal_info/gender.title',
#  'items.properties.personal_info/gender.type',
#  'items.properties.personal_info/household_monthly_income.pattern',
#  'items.properties.personal_info/household_monthly_income.title',
#  'items.properties.personal_info/household_monthly_income.type',
#  'items.properties.personal_info/is_currently_earning.pattern',
#  'items.properties.personal_info/is_currently_earning.title',
#  'items.properties.personal_info/is_currently_earning.type',
#  'items.properties.personal_info/last_name.pattern',
#  'items.properties.personal_info/last_name.title',
#  'items.properties.personal_info/last_name.type',
#  'items.properties.personal_info/postal_code.pattern',
#  'items.properties.personal_info/postal_code.title',
#  'items.properties.personal_info/postal_code.type',
#  'items.properties.personal_info/source_of_income.pattern',
#  'items.properties.personal_info/source_of_income.title',
#  'items.properties.personal_info/source_of_income.type',
#  'items.properties.personal_info/type_of_registration.pattern',
#  'items.properties.personal_info/type_of_registration.title',
#  'items.properties.personal_info/type_of_registration.type',
#  'items.properties.personal_info/work_nature.pattern',
#  'items.properties.personal_info/work_nature.title',
#  'items.properties.personal_info/work_nature.type',
#  'items.properties.pregnancy/ANC_visits.pattern',
#  'items.properties.pregnancy/ANC_visits.title',
#  'items.properties.pregnancy/ANC_visits.type',
#  'items.properties.pregnancy/Are_you_taking_ferro_hate_with_folic_acid.pattern',
#  'items.properties.pregnancy/Are_you_taking_ferro_hate_with_folic_acid.title',
#  'items.properties.pregnancy/Are_you_taking_ferro_hate_with_folic_acid.type',
#  'items.properties.pregnancy/female_no_of_children.pattern',
#  'items.properties.pregnancy/female_no_of_children.title',
#  'items.properties.pregnancy/female_no_of_children.type',
#  'items.properties.pregnancy/is_first_pregnancy.pattern',
#  'items.properties.pregnancy/is_first_pregnancy.title',
#  'items.properties.pregnancy/is_first_pregnancy.type',
#  'items.properties.pregnancy/is_pregnant_or_have_children.pattern',
#  'items.properties.pregnancy/is_pregnant_or_have_children.title',
#  'items.properties.pregnancy/is_pregnant_or_have_children.type',
#  'items.properties.pregnancy/months_pregnant.pattern',
#  'items.properties.pregnancy/months_pregnant.title',
#  'items.properties.pregnancy/months_pregnant.type',
#  'items.properties.pregnancy/not_rec_ANC_local_health_cente.pattern',
#  'items.properties.pregnancy/not_rec_ANC_local_health_cente.title',
#  'items.properties.pregnancy/not_rec_ANC_local_health_cente.type',
#  'items.properties.pregnancy/place_receive_ANC.pattern',
#  'items.properties.pregnancy/place_receive_ANC.title',
#  'items.properties.pregnancy/place_receive_ANC.type',
#  'items.properties.pregnancy/vaccinated_tetanus_toxoid.pattern',
#  'items.properties.pregnancy/vaccinated_tetanus_toxoid.title',
#  'items.properties.pregnancy/vaccinated_tetanus_toxoid.type',
#  'items.properties.pregnancy/where_to_deliver_baby.pattern',
#  'items.properties.pregnancy/where_to_deliver_baby.title',
#  'items.properties.pregnancy/where_to_deliver_baby.type',
#  'items.properties.pregnancy/why_not_delivr_health_centr.pattern',
#  'items.properties.pregnancy/why_not_delivr_health_centr.title',
#  'items.properties.pregnancy/why_not_delivr_health_centr.type',
#  'items.properties.start.pattern',
#  'items.properties.start.title',
#  'items.properties.start.type',
#  'items.title',
#  'items.type',
#  'title',
#  'type']

# %% [markdown]
# ## Get valid index List only

# %%
validIndexLists = []
for indexList in list(schema_df):
    if "._" not in indexList:
        if len(indexList.split(sep='.')) > 2:
            if indexList.split(sep='.')[-1] == 'type' or indexList.split(sep='.')[-1] == 'title':
                validIndexLists.append(indexList)
validIndexLists[:5]
# Out:
# ['demographics.properties.active.type',
#  'demographics.properties.address.properties.add_date.type',
#  'demographics.properties.address.properties.commnty.type',
#  'demographics.properties.address.properties.country.type',
#  'demographics.properties.address.properties.province.type']

# %%
schema_df[['items.properties.dental_health/owning_toothbrush.title','items.properties.dental_health/owning_toothbrush.type']]
# Out:
#   items.properties.dental_health/owning_toothbrush.title  \
# 0         The Dental_health/owning_toothbrush Schema
#
#   items.properties.dental_health/owning_toothbrush.type
# 0                                             string

# %%
required_field_df = pd.DataFrame()
required_field_df = schema_df[validIndexLists]
required_field_df.T
# Out:
#                                                           0
# demographics.properties.active.type                 boolean
# demographics.properties.address.properties.add_...     date
# demographics.properties.address.properties.comm...  keyword
# demographics.properties.address.properties.coun...  keyword
# demographics.properties.address.properties.prov...  keyword
# demographics.properties.address.properties.zip....  keyword
# demographics.properties.address.type                 object
# demographics.properties.are_you_currently_earni...  keyword
# demographics.properties.awh_id.type                 keyword
# demographics.properties.birth_date.type                date
# demographics.properties.cam_account.type            keyword
# demographics.properties.civil_st.type               keyword
# demographics.properties.deceased.properties.is_...  boolean
# demographics.properties.deceased.properties.yea...  keyword
# demographics.properties.deceased.type                object
# demographics.properties.educ.type                   keyword
# demographics.properties.employed.properties.is_...  boolean
# demographics.properties.employed.properties.m_i...    float
# demographics.properties.employed.properties.nat...  keyword
# demographics.properties.employed.type                object
# demographics.properties.org.type                    keyword
# demographics.properties.religion.type               keyword
# demographics.properties.sex.type                    keyword
# demographics.properties.version.properties.date...     date
# demographics.properties.version.properties.numb...  integer
# demographics.properties.version.type                 object
# demographics.properties.where_income_from.type      keyword

# %% [markdown]
# #### snippet code

# %% [markdown]
# ## Clean values

# %%
def clean_value(x):
    return x.lower().replace("/", ".").replace("the", "").replace("schema", "").strip()



def clean_index(x):
    return x.lower().replace("/", ".").replace(".properties", "").replace("items.", "").strip()

newSchema_df = pd.DataFrame()
newSchema_df['value'] = required_field_df.T[0].apply(clean_value)
#newSchema_df['value'] = newSchema_df['value'].T.head(4)[0].apply(clean_value)

newSchema_df.reset_index(level=0, inplace=True)

newSchema_df.head(4)
# Out:
#                                                index    value
# 0                demographics.properties.active.type  boolean
# 1  demographics.properties.address.properties.add...     date
# 2  demographics.properties.address.properties.com...  keyword
# 3  demographics.properties.address.properties.cou...  keyword

# %%
newSchema_df['index'] = newSchema_df['index'].apply(clean_index)
newSchema_df
# Out:
#                                           index    value
# 0                      demographics.active.type  boolean
# 1            demographics.address.add_date.type     date
# 2             demographics.address.commnty.type  keyword
# 3             demographics.address.country.type  keyword
# 4            demographics.address.province.type  keyword
# 5                 demographics.address.zip.type  keyword
# 6                     demographics.address.type   object
# 7   demographics.are_you_currently_earning.type  keyword
# 8                      demographics.awh_id.type  keyword
# 9                  demographics.birth_date.type     date
# 10                demographics.cam_account.type  keyword
# 11                   demographics.civil_st.type  keyword
# 12           demographics.deceased.is_dead.type  boolean
# 13              demographics.deceased.year.type  keyword
# 14                   demographics.deceased.type   object
# 15                       demographics.educ.type  keyword
# 16           demographics.employed.is_empl.type  boolean
# 17          demographics.employed.m_income.type    float
# 18            demographics.employed.nature.type  keyword
# 19                   demographics.employed.type   object
# 20                        demographics.org.type  keyword
# 21                   demographics.religion.type  keyword
# 22                        demographics.sex.type  keyword
# 23               demographics.version.date.type     date
# 24             demographics.version.number.type  integer
# 25                    demographics.version.type   object
# 26          demographics.where_income_from.type  keyword

# %%
valueSchema_df = pd.DataFrame()

number = len(newSchema_df)
index = 0
counter = 0
counter1 = 1

array_key = []
array_type = []

while (counter < number):
    array_key.append(newSchema_df.iloc[counter]['index'].replace('.title',''))
    counter += 2
        
while (counter1 < number):
    array_type.append(newSchema_df.iloc[counter1]['value'])
    counter1 += 2

valueSchema_df['source_key'] = array_key
valueSchema_df['source_type'] = array_type


valueSchema_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-65936b95feee> in <module>()
#      18
#      19 valueSchema_df['source_key'] = array_key
# ---> 20 valueSchema_df['source_type'] = array_type
#      21
#      22
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3192
#    3193         self._ensure_valid_index(value)
# -> 3194         value = self._sanitize_column(key, value)
#    3195         NDFrame._set_item(self, key, value)
#    3196
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3389
#    3390             # turn me into an ndarray
# -> 3391             value = _sanitize_index(value, self.index, copy=False)
#    3392             if not isinstance(value, (np.ndarray, Index)):
#    3393                 if isinstance(value, list) and len(value) > 0:
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/series.py in _sanitize_index(data, index, copy)
#    3999
#    4000     if len(data) != len(index):
# -> 4001         raise ValueError('Length of values does not match length of ' 'index')
#    4002
#    4003     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %% [markdown]
# ## Get input data

# %%
with open("data/aqmData.partial.json") as f:
    d = json.load(f)

input_data = json_normalize(d)
input_data = input_data.fillna('no answer')
input_data
# Out:
#               __version__ _attachments _bamboo_dataset_id  _geolocation   _id  \
# 0  vEo56thCPymxS2RDBK2its           []                     [None, None]  4296
#
#   _notes            _status     _submission_time _submitted_by _tags  \
# 0     []  submitted_via_web  2019-03-26T03:36:06     no answer    []
#
#                ...               identity_consent/town  \
# 0              ...                                   _
#
#                              meta/instanceID personal_info/address_line_1  \
# 0  uuid:cfdfbff0-c6b5-4007-b20a-5f4794391ce9                    Siam Reap
#
#   personal_info/civil_status personal_info/date_of_birth  \
# 0                         SI                  2019-03-27
#
#   personal_info/first_name personal_info/gender personal_info/last_name  \
# 0                     Houn                    F                     Hen
#
#   personal_info/type_of_registration                          start
# 0                                  S  2019-03-26T11:38:36.149+08:00
#
# [1 rows x 39 columns]

# %% [markdown]
# ## Get Mapping

# %%
mapping_df = pd.read_csv('schema/map/map.csv', skiprows=0)
mapping_df
# Out:
#                     source_key         destination_key
# 0  personal_info.date_of_birth  demographics.birthdate
# 1   personal_info.civil_status   demographics.civil_st

# %%
source_mapping_fields_l = list(mapping_df['source_key'])
source_mapping_fields_l
# Out:
# ['personal_info.date_of_birth', 'personal_info.civil_status']

# %% [markdown]
# ## Get values input data that are included mapping

# %%
input_data[['personal_info.date_of_birth', 'personal_info.civil_status']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-723872f82af6> in <module>()
# ----> 1 input_data[['personal_info.date_of_birth', 'personal_info.civil_status']]
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ~/src/virtual_env/jupyther3.6/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['personal_info.date_of_birth' 'personal_info.civil_status'] not in index"
